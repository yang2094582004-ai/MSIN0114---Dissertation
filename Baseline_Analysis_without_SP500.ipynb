# %% [markdown]
# # Baseline Analysis without S&P 500
#
# Analysis of Asian market returns and Chinese investor sentiment before the inclusion of the S&P 500.

# %% [markdown]
# # 1. Data Preparation
#
# Import packages, merge the included frozen source datasets, and construct monthly market returns. The submitted sample ends in 2023-08; no online download is required. Saved notebook outputs allow the results to be viewed without rerunning the notebook.

# %% [markdown]
# ## 1.1. Package Imports
#
# Load the Python packages used for data handling, plotting, correlation tests, and VAR analysis.

# %%
from pathlib import Path

import numpy as np
import openpyxl
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import scipy
import statsmodels

from IPython.display import display, HTML
from scipy.stats import norm, pearsonr
from sklearn.decomposition import PCA
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller

print("All packages imported successfully.")
# Out:
# All packages imported successfully.

# %% [markdown]
# ## 1.2. Data Merging
#
# Read stock price CSV files and the monthly sentiment Excel file, clean them, merge by month, and export the merged dataset.

# %%
# Locate the repository from the current working directory (portable across computers).
PROJECT_ROOT = next(
    (path for path in (Path.cwd(), *Path.cwd().parents) if (path / "dataset").is_dir()),
    None,
)
if PROJECT_ROOT is None:
    raise FileNotFoundError("Could not locate the project dataset directory. Open this notebook from the repository.")
DATA_DIR = PROJECT_ROOT / "dataset"
STOCK_DIR = DATA_DIR / "stock" / "monthly"
OUTPUT_PATH = PROJECT_ROOT / "dataset" / "outputs" / "stock_sentiment_dataset.xlsx"

# Input files
STOCK_FILES = {
    "shanghai_price": STOCK_DIR / "Shanghai Composite Monthly Historical Results Price Data (1).csv",
    "nikkei_price": STOCK_DIR / "Nikkei 225 Monthly Historical Results Price Data (1).csv",
    "kospi_price": STOCK_DIR / "KOSPI Monthly Historical Results Price Data (1).csv",
    "hang_seng_price": STOCK_DIR / "Hang Seng Monthly Historical Results Price Data (1).csv",
    "singapore_sti_price": STOCK_DIR / "FTSE Straits Times Singapore Monthly Historical Results Price Data (2).csv",
}

SENTIMENT_FILE = DATA_DIR / "Investor_Sentiment_Monthly.xlsx.xlsx"

# Settings
CUTOFF_MONTH = "2023-08"
SENTIMENT_COLUMNS = ["month", "DCEF", "RIPO", "NIPO", "NA", "TURN", "CCI", "ISI", "StdISI"]


def load_stock_price(file_path: Path, price_column_name: str) -> pd.DataFrame:
    stock = pd.read_csv(file_path)

    # Parse stock dates as dd/mm/yyyy
    stock["Date"] = pd.to_datetime(stock["Date"], format="%d/%m/%Y")

    # Convert to monthly format YYYY-MM
    stock["month"] = stock["Date"].dt.strftime("%Y-%m")

    # Keep only observations up to 2023-08 and only the Price column
    stock = stock.loc[
        stock["month"] <= CUTOFF_MONTH,
        ["month", "Price"]
    ].copy()

    # Rename Price column
    stock = stock.rename(columns={"Price": price_column_name})

    # Sort by month
    stock = stock.sort_values("month").reset_index(drop=True)

    return stock


def load_sentiment(file_path: Path) -> pd.DataFrame:
    sentiment = pd.read_excel(file_path, sheet_name="sheet1")

    # Remove first two metadata/unit rows
    sentiment = sentiment.iloc[2:].copy()

    # Rename monthly date column
    sentiment = sentiment.rename(columns={"SgnMonth": "month"})

    # Convert to monthly format YYYY-MM
    sentiment["month"] = pd.to_datetime(
        sentiment["month"],
        format="%Y-%m"
    ).dt.strftime("%Y-%m")

    # Keep only required sentiment variables
    sentiment = sentiment[SENTIMENT_COLUMNS].copy()

    # Convert sentiment variables to numeric
    for column in SENTIMENT_COLUMNS[1:]:
        sentiment[column] = pd.to_numeric(sentiment[column], errors="coerce")

    sentiment = sentiment.sort_values("month").reset_index(drop=True)

    return sentiment


# Read and clean stock datasets
stock_dataframes = [
    load_stock_price(file_path, price_column_name)
    for price_column_name, file_path in STOCK_FILES.items()
]

# Merge stock datasets
master_df = stock_dataframes[0]

for stock_df in stock_dataframes[1:]:
    master_df = master_df.merge(stock_df, on="month", how="inner")

# Read and clean sentiment dataset
sentiment_df = load_sentiment(SENTIMENT_FILE)

# Merge stock data with sentiment data
master_df = master_df.merge(sentiment_df, on="month", how="inner")

# Sort final dataset
master_df = master_df.sort_values("month").reset_index(drop=True)

# Export final dataset
OUTPUT_PATH.parent.mkdir(parents=True, exist_ok=True)
master_df.to_excel(OUTPUT_PATH, index=False)

# Notebook outputs
print(f"Exported master dataset to: {OUTPUT_PATH}")

print(f"\nFinal row count: {len(master_df):,}")
print(f"Date range: {master_df['month'].min()} to {master_df['month'].max()}")

print("\nMissing value summary:")
print(master_df.isna().sum())

print("\nColumn names:")
print(list(master_df.columns))

# Show first few rows
master_df.head()
# Out:
# Exported master dataset to: C:\Users\20945\Desktop\data\project\dataset\outputs\stock_sentiment_dataset.xlsx
#
# Final row count: 248
# Date range: 2003-01 to 2023-08
#
# Missing value summary:
# month                  0
# shanghai_price         0
# nikkei_price           0
# kospi_price            0
# hang_seng_price        0
# singapore_sti_price    0
# DCEF                   0
# RIPO                   0
# NIPO                   0
# NA                     0
# TURN                   0
# CCI                    0
# ISI                    0
# StdISI                 0
# dtype: int64
#
# Column names:
# ['month', 'shanghai_price', 'nikkei_price', 'kospi_price', 'hang_seng_price', 'singapore_sti_price', 'DCEF', 'RIPO', 'NIPO', 'NA', 'TURN', 'CCI', 'ISI', 'StdISI']
#      month shanghai_price nikkei_price kospi_price hang_seng_price  \
# 0  2003-01       1,499.82     8,339.94      591.86        9,258.95
# 1  2003-02       1,511.93     8,363.04      575.43        9,122.66
# 2  2003-03       1,510.58     7,972.71      535.70        8,634.45
# 3  2003-04       1,521.44     7,831.42      599.35        8,717.22
# 4  2003-05       1,576.26     8,424.51      633.42        9,487.38
#
#   singapore_sti_price    DCEF    RIPO  NIPO    NA    TURN   CCI    ISI  StdISI
# 0            1,253.98 -0.1034  0.9050     5  3.97  0.1054  97.5  26.44   -1.26
# 1            1,236.36 -0.1117  0.7691     3  2.85  0.1928  97.7  25.30   -1.05
# 2            1,235.25 -0.0941  0.6831     6  3.26  0.1328  97.8  26.20   -1.27
# 3            1,251.60 -0.1399  1.1853     5  5.69  0.1218  97.6  27.69   -1.07
# 4            1,324.56 -0.1892  1.0623     2  4.21  0.3197  88.7  24.05   -0.70

# %% [markdown]
# ## 1.3. Return Construction
#
# Convert stock price columns to numeric values, calculate monthly log returns, and create the analysis dataset.

# %%
# Convert stock price columns from string to numeric
price_vars = [
    "shanghai_price",
    "nikkei_price",
    "kospi_price",
    "hang_seng_price",
    "singapore_sti_price"
]

for col in price_vars:
    master_df[col] = (
        master_df[col]
        .astype(str)
        .str.replace(",", "", regex=False)
        .pipe(pd.to_numeric, errors="coerce")
    )

# Generate monthly log return variables
master_df["r_shanghai"] = np.log(master_df["shanghai_price"] / master_df["shanghai_price"].shift(1)) * 100
master_df["r_nikkei"] = np.log(master_df["nikkei_price"] / master_df["nikkei_price"].shift(1)) * 100
master_df["r_kospi"] = np.log(master_df["kospi_price"] / master_df["kospi_price"].shift(1)) * 100
master_df["r_hangseng"] = np.log(master_df["hang_seng_price"] / master_df["hang_seng_price"].shift(1)) * 100
master_df["r_singapore"] = np.log(master_df["singapore_sti_price"] / master_df["singapore_sti_price"].shift(1)) * 100

# Create analysis dataset and remove missing values
analysis_vars = [
    "month",
    "shanghai_price",
    "nikkei_price",
    "kospi_price",
    "hang_seng_price",
    "singapore_sti_price",
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "DCEF",
    "RIPO",
    "NIPO",
    "NA",
    "TURN",
    "CCI",
    "ISI",
    "StdISI"
]

analysis_df = master_df[analysis_vars].dropna().copy()
analysis_df["month_dt"] = pd.to_datetime(analysis_df["month"])

print(f"Rows before dropping missing values: {len(master_df)}")
print(f"Rows after dropping missing values: {len(analysis_df)}")
print(f"Date range: {analysis_df['month'].min()} to {analysis_df['month'].max()}")

analysis_df.head()
# Out:
# Rows before dropping missing values: 248
# Rows after dropping missing values: 247
# Date range: 2003-02 to 2023-08
#      month  shanghai_price  nikkei_price  kospi_price  hang_seng_price  \
# 1  2003-02         1511.93       8363.04       575.43          9122.66
# 2  2003-03         1510.58       7972.71       535.70          8634.45
# 3  2003-04         1521.44       7831.42       599.35          8717.22
# 4  2003-05         1576.26       8424.51       633.42          9487.38
# 5  2003-06         1486.02       9083.11       669.93          9577.12
#
#    singapore_sti_price  r_shanghai  r_nikkei    r_kospi  r_hangseng  \
# 1              1236.36    0.804188  0.276598  -2.815253   -1.482922
# 2              1235.25   -0.089330 -4.779754  -7.154328   -5.500141
# 3              1251.60    0.716357 -1.788061  11.227143    0.954036
# 4              1324.56    3.539770  7.300147   5.528797    8.466211
# 5              1425.24   -5.895355  7.527133   5.603952    0.941443
#
#    r_singapore    DCEF    RIPO  NIPO    NA    TURN   CCI    ISI  StdISI  \
# 1    -1.415091 -0.1117  0.7691     3  2.85  0.1928  97.7  25.30   -1.05
# 2    -0.089820 -0.0941  0.6831     6  3.26  0.1328  97.8  26.20   -1.27
# 3     1.314935 -0.1399  1.1853     5  5.69  0.1218  97.6  27.69   -1.07
# 4     5.665760 -0.1892  1.0623     2  4.21  0.3197  88.7  24.05   -0.70
# 5     7.325989 -0.1962  0.8507     7  5.35  0.2558  85.7  25.10   -1.11
#
#     month_dt
# 1 2003-02-01
# 2 2003-03-01
# 3 2003-04-01
# 4 2003-05-01
# 5 2003-06-01

# %% [markdown]
# # 2. Descriptive and Preliminary Analysis
#
# Summarize the data, visualize the main series, examine correlations, and select candidate lag orders.

# %% [markdown]
# ## 2.1. Descriptive Statistics
#
# Summarize the monthly return variables.

# %%
return_vars = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore"
]

summary_returns = pd.DataFrame({
    "Obs": analysis_df[return_vars].count(),
    "Mean": analysis_df[return_vars].mean(),
    "Std. dev.": analysis_df[return_vars].std(ddof=1),
    "Min": analysis_df[return_vars].min(),
    "Max": analysis_df[return_vars].max()
})

summary_returns = summary_returns.reset_index().rename(columns={"index": "Variable"})

summary_returns
# Out:
#       Variable  Obs      Mean  Std. dev.        Min        Max
# 0   r_shanghai  247  0.296538   7.327552 -28.277937  24.252587
# 1     r_nikkei  247  0.552166   5.332271 -27.216232  14.013731
# 2      r_kospi  247  0.592322   5.402741 -26.311175  13.365158
# 3   r_hangseng  247  0.277646   6.403286 -25.445494  23.604853
# 4  r_singapore  247  0.383474   4.829061 -27.364041  19.300233

# %% [markdown]
# ## 2.2. Stationarity Tests
#
# Use Augmented Dickey-Fuller (ADF) tests with zero lags to examine whether the return and sentiment variables used in the VAR models are stationary, consistent with the Stata `dfuller` specification.

# %%
# Augmented Dickey-Fuller stationarity tests with zero lags, matching Stata dfuller.
def adf_test_table(df, variables):
    rows = []

    for variable in variables:
        series = df[variable].replace([np.inf, -np.inf], np.nan).dropna()
        result = adfuller(
            series,
            maxlag=0,
            regression="c",
            autolag=None
        )

        rows.append({
            "Variable": variable,
            "ADF statistic": result[0],
            "p-value": result[1],
            "Lags used": result[2],
            "Observations": result[3],
            "Stationary at 5%": result[1] < 0.05
        })

    return pd.DataFrame(rows)


adf_vars = return_vars + [col for col in ["r_sp500", "ISI", "StdISI"] if col in analysis_df.columns and col not in return_vars]
adf_results = adf_test_table(analysis_df, adf_vars)
display(adf_results.round({"ADF statistic": 4, "p-value": 4}))
# Out:
#       Variable  ADF statistic  p-value  Lags used  Observations  \
# 0   r_shanghai       -13.9735   0.0000          0           246
# 1     r_nikkei       -13.9964   0.0000          0           246
# 2      r_kospi       -16.1475   0.0000          0           246
# 3   r_hangseng       -16.3855   0.0000          0           246
# 4  r_singapore       -14.0112   0.0000          0           246
# 5          ISI        -5.0020   0.0000          0           246
# 6       StdISI        -4.2221   0.0006          0           246
#
#    Stationary at 5%
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# 5              True
# 6              True

# %% [markdown]
# ## 2.2. EDA: StdISI Time Series
#
# Plot the standardized investor sentiment index over time.

# %%
plt.figure(figsize=(10, 5))
plt.plot(analysis_df["month_dt"], analysis_df["StdISI"], color="dodgerblue", linewidth=1)
plt.xlabel("month")
plt.ylabel("StdISI")
plt.grid(True, linestyle="--", alpha=0.3)
plt.show()

# %% [markdown]
# ## 2.3. EDA: Shanghai Return and StdISI
#
# Compare Shanghai monthly returns with standardized investor sentiment.

# %%
plt.figure(figsize=(10, 5))
plt.plot(analysis_df["month_dt"], analysis_df["r_shanghai"], label="r_shanghai", color="dodgerblue", linewidth=1)
plt.plot(analysis_df["month_dt"], analysis_df["StdISI"], label="StdISI", color="crimson", linewidth=1)
plt.xlabel("month")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.3)
plt.show()

# %% [markdown]
# ## 2.4. EDA: Shanghai Return and ISI
#
# Compare Shanghai monthly returns with the original investor sentiment index.

# %%
plt.figure(figsize=(10, 5))
plt.plot(analysis_df["month_dt"], analysis_df["r_shanghai"], label="r_shanghai", color="dodgerblue", linewidth=1)
plt.plot(analysis_df["month_dt"], analysis_df["ISI"], label="ISI", color="crimson", linewidth=1)
plt.xlabel("month")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.3)
plt.show()

# %% [markdown]
# ## 2.5. EDA: Shanghai Price and ISI
#
# Compare Shanghai index price with the original investor sentiment index.

# %%
plt.figure(figsize=(10, 5))
plt.plot(analysis_df["month_dt"], analysis_df["shanghai_price"], label="Shanghai_Price", color="dodgerblue", linewidth=1)
plt.plot(analysis_df["month_dt"], analysis_df["ISI"], label="ISI", color="crimson", linewidth=1)
plt.xlabel("month")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.3)
plt.show()

# %% [markdown]
# ## 2.6. Correlation Table Function
#
# Define a reusable HTML correlation table with p-values and significance stars.

# %%
def correlation_table_html(df, variables, star_level=0.05):
    corr_display = pd.DataFrame("", index=variables, columns=variables)

    for row_var in variables:
        for col_var in variables:
            row_index = variables.index(row_var)
            col_index = variables.index(col_var)

            # Only show the lower triangle.
            if col_index > row_index:
                continue

            if row_var == col_var:
                corr_display.loc[row_var, col_var] = "1.0000"
            else:
                temp = df[[row_var, col_var]].dropna()
                corr, p_value = pearsonr(temp[row_var], temp[col_var])

                star = "*" if p_value < star_level else ""
                corr_display.loc[row_var, col_var] = (
                    f"{corr:.4f}{star}<br>"
                    f"{p_value:.4f}"
                )

    html = corr_display.to_html(escape=False)
    display(HTML(html))

    return corr_display

# %% [markdown]
# ## 2.7. Correlation: Returns and StdISI
#
# Compute pairwise correlations between market returns and StdISI.

# %%
corr_vars_stdisi = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "StdISI"
]

corr_stdisi_table = correlation_table_html(
    analysis_df,
    corr_vars_stdisi,
    star_level=0.05
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>r_shanghai</th>
#       <th>r_nikkei</th>
#       <th>r_kospi</th>
#       <th>r_hangseng</th>
#       <th>r_singapore</th>
#       <th>StdISI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>r_shanghai</th>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_nikkei</th>
#       <td>0.3477*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_kospi</th>
#       <td>0.4113*<br>0.0000</td>
#       <td>0.6068*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_hangseng</th>
#       <td>0.5592*<br>0.0000</td>
#       <td>0.4680*<br>0.0000</td>
#       <td>0.5589*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_singapore</th>
#       <td>0.4491*<br>0.0000</td>
#       <td>0.6292*<br>0.0000</td>
#       <td>0.6957*<br>0.0000</td>
#       <td>0.7031*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>StdISI</th>
#       <td>0.1079<br>0.0906</td>
#       <td>-0.0214<br>0.7385</td>
#       <td>0.0271<br>0.6714</td>
#       <td>-0.0108<br>0.8659</td>
#       <td>0.0002<br>0.9972</td>
#       <td>1.0000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 2.8. Correlation: Returns and ISI
#
# Compute pairwise correlations between market returns and ISI.

# %%
corr_vars_isi = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "ISI"
]

corr_isi_table = correlation_table_html(
    analysis_df,
    corr_vars_isi,
    star_level=0.05
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>r_shanghai</th>
#       <th>r_nikkei</th>
#       <th>r_kospi</th>
#       <th>r_hangseng</th>
#       <th>r_singapore</th>
#       <th>ISI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>r_shanghai</th>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_nikkei</th>
#       <td>0.3477*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_kospi</th>
#       <td>0.4113*<br>0.0000</td>
#       <td>0.6068*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_hangseng</th>
#       <td>0.5592*<br>0.0000</td>
#       <td>0.4680*<br>0.0000</td>
#       <td>0.5589*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_singapore</th>
#       <td>0.4491*<br>0.0000</td>
#       <td>0.6292*<br>0.0000</td>
#       <td>0.6957*<br>0.0000</td>
#       <td>0.7031*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>ISI</th>
#       <td>0.1824*<br>0.0040</td>
#       <td>-0.0436<br>0.4955</td>
#       <td>0.0513<br>0.4222</td>
#       <td>0.0559<br>0.3814</td>
#       <td>0.0113<br>0.8593</td>
#       <td>1.0000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 2.9. EDA: Distribution Diagnostics
#
# Report dissertation-ready descriptive statistics, including skewness, excess kurtosis and the Jarque–Bera normality test. Use the compact table in the main text and retain the full table for the appendix.

# %%
# Distribution diagnostics for monthly returns and StdISI.
eda_vars = ["r_shanghai", "r_nikkei", "r_kospi", "r_hangseng", "r_singapore", "StdISI"]
eda_labels = {
    "r_shanghai": "Shanghai Composite return",
    "r_nikkei": "Nikkei 225 return",
    "r_kospi": "KOSPI return",
    "r_hangseng": "Hang Seng return",
    "r_singapore": "Singapore STI return",
    "StdISI": "Chinese investor sentiment (StdISI)"
}
eda_rows = []
for variable in eda_vars:
    series = analysis_df[variable].dropna()
    jb = scipy.stats.jarque_bera(series)
    eda_rows.append({
        "Variable": eda_labels[variable], "N": len(series),
        "Mean": series.mean(), "Std. dev.": series.std(ddof=1),
        "Minimum": series.min(), "Maximum": series.max(),
        "Skewness": series.skew(), "Excess kurtosis": series.kurt(),
        "Jarque-Bera": jb.statistic, "JB p-value": jb.pvalue
    })
eda_descriptive_table = pd.DataFrame(eda_rows).set_index("Variable")
display(eda_descriptive_table.round(4))
# Out:
#                                        N    Mean  Std. dev.  Minimum  Maximum  \
# Variable
# Shanghai Composite return            247  0.2965     7.3276 -28.2779  24.2526
# Nikkei 225 return                    247  0.5522     5.3323 -27.2162  14.0137
# KOSPI return                         247  0.5923     5.4027 -26.3112  13.3652
# Hang Seng return                     247  0.2776     6.4033 -25.4455  23.6049
# Singapore STI return                 247  0.3835     4.8291 -27.3640  19.3002
# Chinese investor sentiment (StdISI)  247  0.0050     1.4646  -2.4800   5.9300
#
#                                      Skewness  Excess kurtosis  Jarque-Bera  \
# Variable
# Shanghai Composite return             -0.5576           2.4545      70.9872
# Nikkei 225 return                     -0.8677           2.5493      93.6023
# KOSPI return                          -0.7262           2.5492      84.4225
# Hang Seng return                      -0.3132           2.1365      48.0569
# Singapore STI return                  -1.0150           6.2247     421.7496
# Chinese investor sentiment (StdISI)    1.0085           1.7107      69.4473
#
#                                      JB p-value
# Variable
# Shanghai Composite return                   0.0
# Nikkei 225 return                           0.0
# KOSPI return                                0.0
# Hang Seng return                            0.0
# Singapore STI return                        0.0
# Chinese investor sentiment (StdISI)         0.0

# %% [markdown]
# ## 2.10. EDA: Correlation Heatmap
#
# Visualise the Pearson correlation matrix with thesis-ready labels. Use either this heatmap or the numerical correlation matrix in the main text; the other can be placed in the appendix.

# %%
corr_matrix = analysis_df[eda_vars].corr()
short_labels = ["Shanghai", "Nikkei 225", "KOSPI", "Hang Seng", "STI", "StdISI"]
fig, ax = plt.subplots(figsize=(8.5, 7))
image = ax.imshow(corr_matrix, vmin=-1, vmax=1, cmap="RdBu_r")
ax.set_xticks(range(len(short_labels)), short_labels, rotation=40, ha="right")
ax.set_yticks(range(len(short_labels)), short_labels)
for row in range(len(short_labels)):
    for column in range(len(short_labels)):
        value = corr_matrix.iloc[row, column]
        ax.text(column, row, f"{value:.2f}", ha="center", va="center",
                color="white" if abs(value) > 0.55 else "black", fontsize=9)
ax.set_title("Correlation Matrix: Asian Market Returns and Chinese Investor Sentiment", pad=14)
fig.colorbar(image, ax=ax, label="Pearson correlation coefficient")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 2.11. EDA: Return Dynamics and Distributions
#
# Plot all monthly return series and use boxplots to identify heavy tails and extreme observations. These figures are descriptive and do not by themselves establish contagion or causality.

# %%
return_plot_vars = eda_vars[:-1]
return_plot_labels = short_labels[:-1]
fig, axes = plt.subplots(3, 2, figsize=(12, 9), sharex=True)
for ax, variable, label in zip(axes.ravel(), return_plot_vars, return_plot_labels):
    ax.plot(analysis_df["month_dt"], analysis_df[variable], linewidth=0.8, label=label)
    ax.axhline(0, color="black", linewidth=0.6)
    ax.set_title(f"{label} Monthly Log Return")
    ax.set_ylabel("Log return (%)")
    ax.legend(frameon=False, loc="upper right")
axes.ravel()[-1].axis("off")
fig.suptitle("Monthly Asian Stock-Market Returns, February 2003–August 2023", y=1.01)
fig.supxlabel("Month")
fig.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(9, 5))
ax.boxplot([analysis_df[v].dropna() for v in return_plot_vars], tick_labels=return_plot_labels, showfliers=True)
ax.set_title("Distribution of Monthly Asian Stock-Market Returns")
ax.set_xlabel("Market")
ax.set_ylabel("Log return (%)")
ax.tick_params(axis="x", rotation=25)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 2.12. VAR Lag Selection: ISI, Max Lag 4
#
# Select lag order for the VAR model using returns and ISI with maximum lag 4.

# %%
# ISI VAR lag-order selection with maximum lag 4.
var_vars_isi = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "ISI"
]

var_data_isi = analysis_df[var_vars_isi].dropna().copy()
var_model_isi = VAR(var_data_isi)

lag_order_isi_4 = var_model_isi.select_order(maxlags=4)
lag_order_isi_4.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## 2.13. VAR Lag Selection: ISI, Max Lag 6
#
# Repeat lag-order selection for the ISI model with maximum lag 6.

# %%
# ISI VAR lag-order selection with maximum lag 6.
var_vars_isi = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "ISI"
]

var_data_isi = analysis_df[var_vars_isi].dropna().copy()
var_model_isi = VAR(var_data_isi)

lag_order_isi_6 = var_model_isi.select_order(maxlags=6)
lag_order_isi_6.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## 2.14. VAR Lag Selection: StdISI, Max Lag 6
#
# Select lag order for the VAR model using returns and StdISI with maximum lag 6.

# %%
# StdISI VAR lag-order selection with maximum lag 6.
var_vars_stdisi = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "StdISI"
]

var_data_stdisi = analysis_df[var_vars_stdisi].dropna().copy()
var_model_stdisi = VAR(var_data_stdisi)

lag_order_stdisi_6 = var_model_stdisi.select_order(maxlags=6)
lag_order_stdisi_6.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# # 3. Alternative Sentiment Measure: StdISI VAR(2)
#
# Estimate the alternative VAR(2) specification using the externally sourced standardized investor sentiment index (StdISI).

# %% [markdown]
# ## 3.1. Alternative VAR(2) Model with StdISI
#
# Estimate the VAR model with two lags using market returns and StdISI.

# %%
# Estimate the VAR(2) model with StdISI.
var_vars_stdisi = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "StdISI"
]

var_data_stdisi = analysis_df[var_vars_stdisi].dropna().copy()
var_model_stdisi = VAR(var_data_stdisi)

# fit(2) includes lag 1 and lag 2.
var_results_stdisi_lag2 = var_model_stdisi.fit(2)

print(var_results_stdisi_lag2.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 31, Jul, 2026
# Time:                     23:11:22
# --------------------------------------------------------------------
# No. of Equations:         6.00000    BIC:                    15.4958
# Nobs:                     245.000    HQIC:                   14.8300
# Log likelihood:          -3769.53    FPE:                1.76161e+06
# AIC:                      14.3811    Det(Omega_mle):     1.29178e+06
# --------------------------------------------------------------------
# Results for equation r_shanghai
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.222186         0.475252            0.468           0.640
# L1.r_shanghai          0.112169         0.080740            1.389           0.165
# L1.r_nikkei           -0.078217         0.120835           -0.647           0.517
# L1.r_kospi             0.031788         0.130903            0.243           0.808
# L1.r_hangseng         -0.038283         0.116887           -0.328           0.743
# L1.r_singapore         0.070577         0.172441            0.409           0.682
# L1.StdISI             -0.739772         0.751959           -0.984           0.325
# L2.r_shanghai          0.138769         0.089625            1.548           0.122
# L2.r_nikkei           -0.258566         0.122264           -2.115           0.034
# L2.r_kospi             0.125476         0.129869            0.966           0.334
# L2.r_hangseng         -0.047529         0.112821           -0.421           0.674
# L2.r_singapore         0.239378         0.168016            1.425           0.154
# L2.StdISI              0.417989         0.705866            0.592           0.554
# =================================================================================
#
# Results for equation r_nikkei
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.005602         0.040823            0.137           0.891
# L1.r_shanghai          0.061711         0.006935            8.898           0.000
# L1.r_nikkei           -0.014687         0.010379           -1.415           0.157
# L1.r_kospi            -0.008533         0.011244           -0.759           0.448
# L1.r_hangseng         -0.008308         0.010040           -0.827           0.408
# L1.r_singapore         0.000562         0.014812            0.038           0.970
# L1.StdISI              0.609620         0.064591            9.438           0.000
# L2.r_shanghai          0.003390         0.007699            0.440           0.660
# L2.r_nikkei           -0.016645         0.010502           -1.585           0.113
# L2.r_kospi             0.010303         0.011155            0.924           0.356
# L2.r_hangseng         -0.003614         0.009691           -0.373           0.709
# L2.r_singapore         0.007813         0.014432            0.541           0.588
# L2.StdISI              0.244102         0.060632            4.026           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                r_shanghai  r_nikkei   r_kospi  r_hangseng  r_singapore    StdISI
# r_shanghai       1.000000  0.321601  0.408054    0.549329     0.423312  0.190831
# r_nikkei         0.321601  1.000000  0.612813    0.475166     0.612528 -0.006784
# r_kospi          0.408054  0.612813  1.000000    0.579978     0.696137  0.049003
# r_hangseng       0.549329  0.475166  0.579978    1.000000     0.720916  0.016654
# r_singapore      0.423312  0.612528  0.696137    0.720916     1.000000  0.028265
# StdISI           0.190831 -0.006784  0.049003    0.016654     0.028265  1.000000

# %% [markdown]
# ## 3.2. Full VAR Coefficient Table
#
# Create a complete coefficient table for the VAR(2) model.

# %%
# Complete coefficient table for the VAR(2) model.
params = var_results_stdisi_lag2.params
stderr = var_results_stdisi_lag2.stderr
zvalues = var_results_stdisi_lag2.tvalues
pvalues = var_results_stdisi_lag2.pvalues

z_crit = norm.ppf(0.975)

base_variables = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "StdISI"
]

ordered_parameters = []
for base_var in base_variables:
    ordered_parameters.append(f"L1.{base_var}")
    ordered_parameters.append(f"L2.{base_var}")
ordered_parameters.append("const")

rows = []

for equation in params.columns:
    for variable in ordered_parameters:
        if variable not in params.index:
            continue

        coef = params.loc[variable, equation]
        se = stderr.loc[variable, equation]
        z = zvalues.loc[variable, equation]
        p = pvalues.loc[variable, equation]
        ci_lower = coef - z_crit * se
        ci_upper = coef + z_crit * se

        if variable == "const":
            lag = "const"
            variable_name = "const"
        else:
            lag, variable_name = variable.split(".", 1)

        rows.append({
            "Equation": equation,
            "Variable": variable_name,
            "Lag": lag,
            "Coefficient": coef,
            "Std. err.": se,
            "z": z,
            "P>|z|": p,
            "95% CI lower": ci_lower,
            "95% CI upper": ci_upper
        })

var_stdisi_lag2_full_table = pd.DataFrame(rows)

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

display(var_stdisi_lag2_full_table)
# Out:
#        Equation     Variable    Lag  Coefficient  Std. err.         z  \
# 0    r_shanghai   r_shanghai     L1     0.112169   0.080740  1.389262
# 1    r_shanghai   r_shanghai     L2     0.138769   0.089625  1.548332
# 2    r_shanghai     r_nikkei     L1    -0.078217   0.120835 -0.647305
# 3    r_shanghai     r_nikkei     L2    -0.258566   0.122264 -2.114813
# 4    r_shanghai      r_kospi     L1     0.031788   0.130903  0.242838
# 5    r_shanghai      r_kospi     L2     0.125476   0.129869  0.966168
# 6    r_shanghai   r_hangseng     L1    -0.038283   0.116887 -0.327518
# 7    r_shanghai   r_hangseng     L2    -0.047529   0.112821 -0.421274
# 8    r_shanghai  r_singapore     L1     0.070577   0.172441  0.409284
# 9    r_shanghai  r_singapore     L2     0.239378   0.168016  1.424735
# 10   r_shanghai       StdISI     L1    -0.739772   0.751959 -0.983793
# 11   r_shanghai       StdISI     L2     0.417989   0.705866  0.592166
# 12   r_shanghai        const  const     0.222186   0.475252  0.467513
# 13     r_nikkei   r_shanghai     L1     0.075443   0.058475  1.290178
# 14     r_nikkei   r_shanghai     L2     0.080279   0.064910  1.236784
# 15     r_nikkei     r_nikkei     L1     0.044822   0.087513  0.512175
# 16     r_nikkei     r_nikkei     L2    -0.129003   0.088548 -1.456866
# 17     r_nikkei      r_kospi     L1    -0.032235   0.094805 -0.340011
# 18     r_nikkei      r_kospi     L2     0.102069   0.094056  1.085192
# 19     r_nikkei   r_hangseng     L1     0.061574   0.084654  0.727356
# 20     r_nikkei   r_hangseng     L2     0.016639   0.081710  0.203634
# 21     r_nikkei  r_singapore     L1    -0.008474   0.124888 -0.067855
# 22     r_nikkei  r_singapore     L2     0.015571   0.121684  0.127963
# 23     r_nikkei       StdISI     L1    -0.272865   0.544598 -0.501039
# 24     r_nikkei       StdISI     L2    -0.178739   0.511215 -0.349635
# 25     r_nikkei        const  const     0.508233   0.344196  1.476580
# 26      r_kospi   r_shanghai     L1    -0.046266   0.058787 -0.787023
# 27      r_kospi   r_shanghai     L2     0.060600   0.065256  0.928654
# 28      r_kospi     r_nikkei     L1    -0.006161   0.087980 -0.070032
# 29      r_kospi     r_nikkei     L2    -0.199896   0.089021 -2.245499
# 30      r_kospi      r_kospi     L1    -0.100381   0.095311 -1.053198
# 31      r_kospi      r_kospi     L2    -0.025055   0.094558 -0.264968
# 32      r_kospi   r_hangseng     L1     0.018307   0.085106  0.215111
# 33      r_kospi   r_hangseng     L2     0.128064   0.082145  1.558995
# 34      r_kospi  r_singapore     L1     0.128966   0.125554  1.027172
# 35      r_kospi  r_singapore     L2     0.080287   0.122333  0.656296
# 36      r_kospi       StdISI     L1     0.465981   0.547503  0.851103
# 37      r_kospi       StdISI     L2    -0.612236   0.513942 -1.191254
# 38      r_kospi        const  const     0.698931   0.346032  2.019845
# 39   r_hangseng   r_shanghai     L1    -0.041900   0.068717 -0.609748
# 40   r_hangseng   r_shanghai     L2     0.198971   0.076279  2.608460
# 41   r_hangseng     r_nikkei     L1    -0.136150   0.102842 -1.323878
# 42   r_hangseng     r_nikkei     L2    -0.263909   0.104058 -2.536163
# 43   r_hangseng      r_kospi     L1     0.159279   0.111411  1.429649
# 44   r_hangseng      r_kospi     L2     0.302059   0.110531  2.732801
# 45   r_hangseng   r_hangseng     L1    -0.097518   0.099482 -0.980253
# 46   r_hangseng   r_hangseng     L2    -0.161047   0.096022 -1.677199
# 47   r_hangseng  r_singapore     L1     0.073721   0.146763  0.502311
# 48   r_hangseng  r_singapore     L2     0.164956   0.142997  1.153559
# 49   r_hangseng       StdISI     L1    -0.740309   0.639988 -1.156753
# 50   r_hangseng       StdISI     L2     0.303307   0.600758  0.504874
# 51   r_hangseng        const  const     0.195433   0.404484  0.483165
# 52  r_singapore   r_shanghai     L1     0.008147   0.052074  0.156458
# 53  r_singapore   r_shanghai     L2     0.105017   0.057805  1.816763
# 54  r_singapore     r_nikkei     L1     0.090897   0.077934  1.166336
# 55  r_singapore     r_nikkei     L2    -0.259290   0.078856 -3.288163
# 56  r_singapore      r_kospi     L1    -0.038542   0.084428 -0.456510
# 57  r_singapore      r_kospi     L2     0.090461   0.083761  1.079997
# 58  r_singapore   r_hangseng     L1     0.027116   0.075388  0.359688
# 59  r_singapore   r_hangseng     L2    -0.013768   0.072765 -0.189213
# 60  r_singapore  r_singapore     L1     0.044618   0.111218  0.401175
# 61  r_singapore  r_singapore     L2     0.151444   0.108364  1.397554
# 62  r_singapore       StdISI     L1    -0.099407   0.484985 -0.204970
# 63  r_singapore       StdISI     L2    -0.244419   0.455256 -0.536883
# 64  r_singapore        const  const     0.343076   0.306519  1.119265
# 65       StdISI   r_shanghai     L1     0.061711   0.006935  8.898079
# 66       StdISI   r_shanghai     L2     0.003390   0.007699  0.440388
# 67       StdISI     r_nikkei     L1    -0.014687   0.010379 -1.414989
# 68       StdISI     r_nikkei     L2    -0.016645   0.010502 -1.584908
# 69       StdISI      r_kospi     L1    -0.008533   0.011244 -0.758835
# 70       StdISI      r_kospi     L2     0.010303   0.011155  0.923560
# 71       StdISI   r_hangseng     L1    -0.008308   0.010040 -0.827489
# 72       StdISI   r_hangseng     L2    -0.003614   0.009691 -0.372925
# 73       StdISI  r_singapore     L1     0.000562   0.014812  0.037953
# 74       StdISI  r_singapore     L2     0.007813   0.014432  0.541392
# 75       StdISI       StdISI     L1     0.609620   0.064591  9.438136
# 76       StdISI       StdISI     L2     0.244102   0.060632  4.025965
# 77       StdISI        const  const     0.005602   0.040823  0.137239
#
#            P>|z|  95% CI lower  95% CI upper
# 0   1.647531e-01     -0.046078      0.270415
# 1   1.215425e-01     -0.036892      0.314430
# 2   5.174344e-01     -0.315048      0.158615
# 3   3.444591e-02     -0.498199     -0.018932
# 4   8.081307e-01     -0.224778      0.288354
# 5   3.339599e-01     -0.129064      0.380015
# 6   7.432760e-01     -0.267377      0.190812
# 7   6.735550e-01     -0.268655      0.173597
# 8   6.823315e-01     -0.267401      0.408555
# 9   1.542338e-01     -0.089927      0.568683
# 10  3.252171e-01     -2.213585      0.734040
# 11  5.537396e-01     -0.965482      1.801461
# 12  6.401331e-01     -0.709290      1.153663
# 13  1.969888e-01     -0.039166      0.190051
# 14  2.161674e-01     -0.046941      0.207500
# 15  6.085288e-01     -0.126701      0.216344
# 16  1.451533e-01     -0.302555      0.044549
# 17  7.338481e-01     -0.218050      0.153580
# 18  2.778368e-01     -0.082278      0.286416
    "Modulus": np.abs(eigenvalues)
})

stability_table = stability_table.sort_values(
    by="Modulus",
    ascending=False
).reset_index(drop=True)

display(stability_table)

if np.all(stability_table["Modulus"] < 1):
    print("All eigenvalue moduli are less than 1.")
    print("VAR satisfies stability condition.")
else:
    print("At least one eigenvalue modulus is greater than or equal to 1.")
    print("VAR does not satisfy stability condition.")
# Out:
#             Eigenvalue   Modulus
# 0   0.882698+0.000000j  0.882698
# 1  -0.107598-0.544328j  0.554860
# 2  -0.107598+0.544328j  0.554860
# 3  -0.405282-0.033640j  0.406675
# 4  -0.405282+0.033640j  0.406675
# 5   0.371653-0.041134j  0.373923
# 6   0.371653+0.041134j  0.373923
# 7   0.020774-0.258450j  0.259283
# 8   0.020774+0.258450j  0.259283
# 9  -0.199688-0.000000j  0.199688
# 10  0.149344+0.000000j  0.149344
# 11  0.021880+0.000000j  0.021880
# All eigenvalue moduli are less than 1.
# VAR satisfies stability condition.

# %% [markdown]
# ## 3.4. Granger Causality Tests
#
# Run Wald tests for Granger causality among the VAR variables.

# %%
# Granger causality Wald tests using statsmodels.
var_names = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "StdISI"
]

granger_rows = []

for equation in var_names:
    excluded_vars = [var for var in var_names if var != equation]

    # Test each excluded variable one by one.
    for excluded in excluded_vars:
        test_result = var_results_stdisi_lag2.test_causality(
            caused=equation,
            causing=excluded,
            kind="wald"
        )

        granger_rows.append({
            "Equation": equation,
            "Excluded": excluded,
            "chi2": test_result.test_statistic,
            "df": test_result.df,
            "Prob > chi2": test_result.pvalue
        })

    # Test all other variables jointly.
    test_all = var_results_stdisi_lag2.test_causality(
        caused=equation,
        causing=excluded_vars,
        kind="wald"
    )

    granger_rows.append({
        "Equation": equation,
        "Excluded": "ALL",
        "chi2": test_all.test_statistic,
        "df": test_all.df,
        "Prob > chi2": test_all.pvalue
    })

granger_table = pd.DataFrame(granger_rows)

granger_table_formatted = granger_table.copy()
granger_table_formatted["chi2"] = granger_table_formatted["chi2"].map(lambda x: f"{x:.4f}")
granger_table_formatted["Prob > chi2"] = granger_table_formatted["Prob > chi2"].map(lambda x: f"{x:.3f}")

display(granger_table_formatted)
# Out:
#        Equation     Excluded     chi2  df Prob > chi2
# 0    r_shanghai     r_nikkei   4.9368   2       0.085
# 1    r_shanghai      r_kospi   0.9621   2       0.618
# 2    r_shanghai   r_hangseng   0.2601   2       0.878
# 3    r_shanghai  r_singapore   2.1559   2       0.340
# 4    r_shanghai       StdISI   1.3418   2       0.511
# 5    r_shanghai          ALL   7.7945  10       0.649
# 6      r_nikkei   r_shanghai   3.2733   2       0.195
# 7      r_nikkei      r_kospi   1.3578   2       0.507
# 8      r_nikkei   r_hangseng   0.5467   2       0.761
# 9      r_nikkei  r_singapore   0.0217   2       0.989
# 10     r_nikkei       StdISI   3.2335   2       0.199
# 11     r_nikkei          ALL  12.4789  10       0.254
# 12      r_kospi   r_shanghai   1.4473   2       0.485
# 13      r_kospi     r_nikkei   5.0535   2       0.080
# 14      r_kospi   r_hangseng   2.4343   2       0.296
# 15      r_kospi  r_singapore   1.4363   2       0.488
# 16      r_kospi       StdISI   1.6208   2       0.445
# 17      r_kospi          ALL  17.2575  10       0.069
# 18   r_hangseng   r_shanghai   7.1031   2       0.029
# 19   r_hangseng     r_nikkei   8.2950   2       0.016
# 20   r_hangseng      r_kospi   8.9658   2       0.011
# 21   r_hangseng  r_singapore   1.5409   2       0.463
# 22   r_hangseng       StdISI   2.6265   2       0.269
# 23   r_hangseng          ALL  24.6034  10       0.006
# 24  r_singapore   r_shanghai   3.3408   2       0.188
# 25  r_singapore     r_nikkei  12.0520   2       0.002
# 26  r_singapore      r_kospi   1.4590   2       0.482
# 27  r_singapore   r_hangseng   0.1803   2       0.914
# 28  r_singapore       StdISI   2.4837   2       0.289
# 29  r_singapore          ALL  19.3454  10       0.036
# 30       StdISI   r_shanghai  79.6058   2       0.000
# 31       StdISI     r_nikkei   4.5875   2       0.101
# 32       StdISI      r_kospi   1.5453   2       0.462
# 33       StdISI   r_hangseng   0.7706   2       0.680
# 34       StdISI  r_singapore   0.2934   2       0.864
# 35       StdISI          ALL  96.3527  10       0.000

# %% [markdown]
# # 4. Lag-Length Robustness Check: StdISI VAR(4)
#
# Assess the lag-length sensitivity of the alternative StdISI specification using four lags.

# %% [markdown]
# ## 4.1. VAR(4) Model with StdISI
#
# Estimate the VAR model with four lags using market returns and StdISI.

# %%
# Estimate the VAR(4) model with StdISI.
var_vars_stdisi = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "StdISI"
]

var_data_stdisi = analysis_df[var_vars_stdisi].dropna().copy()
var_model_stdisi = VAR(var_data_stdisi)

# fit(4) includes lag 1, lag 2, lag 3, and lag 4.
var_results_stdisi_lag4 = var_model_stdisi.fit(4)

print(var_results_stdisi_lag4.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 31, Jul, 2026
# Time:                     23:11:23
# --------------------------------------------------------------------
# No. of Equations:         6.00000    BIC:                    16.5695
# Nobs:                     243.000    HQIC:                   15.2818
# Log likelihood:          -3670.03    FPE:                1.82614e+06
# AIC:                      14.4133    Det(Omega_mle):     1.01476e+06
# --------------------------------------------------------------------
# Results for equation r_shanghai
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.154659         0.472724            0.327           0.744
# L1.r_shanghai          0.105026         0.079782            1.316           0.188
# L1.r_nikkei           -0.116411         0.120665           -0.965           0.335
# L1.r_kospi             0.079250         0.135911            0.583           0.560
# L1.r_hangseng         -0.050863         0.120552           -0.422           0.673
# L1.r_singapore         0.064874         0.172956            0.375           0.708
# L1.StdISI             -0.942591         0.789514           -1.194           0.233
# L2.r_shanghai          0.159362         0.094675            1.683           0.092
# L2.r_nikkei           -0.268877         0.122595           -2.193           0.028
# L2.r_kospi             0.167953         0.133897            1.254           0.210
# L2.r_hangseng         -0.108259         0.120458           -0.899           0.369
# L2.r_singapore         0.243251         0.171755            1.416           0.157
# L2.StdISI              0.329044         0.891094            0.369           0.712
# L3.r_shanghai          0.044914         0.094335            0.476           0.634
# L3.r_hangseng         -0.168000         0.074562           -2.253           0.024
# L3.r_singapore         0.095193         0.107356            0.887           0.375
# L3.StdISI             -1.026748         0.563047           -1.824           0.068
# L4.r_shanghai          0.233735         0.056501            4.137           0.000
# L4.r_nikkei           -0.053542         0.079066           -0.677           0.498
# L4.r_kospi             0.186331         0.084889            2.195           0.028
# L4.r_hangseng         -0.283449         0.072983           -3.884           0.000
# L4.r_singapore         0.065381         0.105829            0.618           0.537
# L4.StdISI              1.270364         0.464249            2.736           0.006
# =================================================================================
#
# Results for equation StdISI
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -0.009664         0.040838           -0.237           0.813
# L1.r_shanghai          0.064965         0.006892            9.426           0.000
# L1.r_nikkei           -0.016697         0.010424           -1.602           0.109
# L1.r_kospi             0.004034         0.011741            0.344           0.731
# L1.r_hangseng         -0.016583         0.010414           -1.592           0.111
# L1.r_singapore         0.001572         0.014942            0.105           0.916
# L1.StdISI              0.527600         0.068206            7.735           0.000
# L2.r_shanghai          0.012404         0.008179            1.517           0.129
# L2.r_nikkei           -0.015761         0.010591           -1.488           0.137
# L2.r_kospi             0.011923         0.011567            1.031           0.303
# L2.r_hangseng         -0.010076         0.010406           -0.968           0.333
# L2.r_singapore         0.009194         0.014838            0.620           0.536
# L2.StdISI              0.116925         0.076981            1.519           0.129
# L3.r_shanghai          0.009890         0.008150            1.214           0.225
# L3.r_nikkei            0.008999         0.010852            0.829           0.407
# L3.r_kospi             0.009452         0.011591            0.815           0.415
# L3.r_hangseng         -0.021458         0.010225           -2.099           0.036
# L3.r_singapore        -0.004105         0.014722           -0.279           0.780
# L3.StdISI              0.122422         0.077210            1.586           0.113
# L4.r_shanghai          0.001031         0.007748            0.133           0.894
# L4.r_nikkei            0.004306         0.010842            0.397           0.691
# L4.r_kospi            -0.013809         0.011641           -1.186           0.236
# L4.r_hangseng         -0.006287         0.010008           -0.628           0.530
# L4.r_singapore         0.026440         0.014512            1.822           0.068
# L4.StdISI              0.096523         0.063662            1.516           0.129
# =================================================================================
#
# Correlation matrix of residuals
#                r_shanghai  r_nikkei   r_kospi  r_hangseng  r_singapore    StdISI
# r_shanghai       1.000000  0.277700  0.383263    0.553145     0.401822  0.185599
# r_nikkei         0.277700  1.000000  0.599895    0.453758     0.602991 -0.018881
# r_kospi          0.383263  0.599895  1.000000    0.564074     0.696191  0.038479
# r_hangseng       0.553145  0.453758  0.564074    1.000000     0.681921 -0.012308
# r_singapore      0.401822  0.602991  0.696191    0.681921     1.000000 -0.008969
# StdISI           0.185599 -0.018881  0.038479   -0.012308    -0.008969  1.000000

# %% [markdown]
# ## 4.2. Full VAR(4) Coefficient Table
#
# Create a complete coefficient table for the VAR(4) model.

# %%
# Complete coefficient table for the VAR(4) model.
params = var_results_stdisi_lag4.params
stderr = var_results_stdisi_lag4.stderr
zvalues = var_results_stdisi_lag4.tvalues
pvalues = var_results_stdisi_lag4.pvalues

z_crit = norm.ppf(0.975)

base_variables = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "StdISI"
]

ordered_parameters = []
for base_var in base_variables:
    for lag_number in range(1, 5):
        ordered_parameters.append(f"L{lag_number}.{base_var}")
ordered_parameters.append("const")

rows = []

for equation in params.columns:
    for variable in ordered_parameters:
        if variable not in params.index:
            continue

        coef = params.loc[variable, equation]
        se = stderr.loc[variable, equation]
        z = zvalues.loc[variable, equation]
        p = pvalues.loc[variable, equation]
        ci_lower = coef - z_crit * se
        ci_upper = coef + z_crit * se

        if variable == "const":
            lag = "const"
            variable_name = "const"
        else:
            lag, variable_name = variable.split(".", 1)

        rows.append({
            "Equation": equation,
            "Variable": variable_name,
            "Lag": lag,
            "Coefficient": coef,
            "Std. err.": se,
            "z": z,
            "P>|z|": p,
            "95% CI lower": ci_lower,
            "95% CI upper": ci_upper
        })

var_stdisi_lag4_full_table = pd.DataFrame(rows)

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

display(var_stdisi_lag4_full_table)
# Out:
#         Equation     Variable    Lag  Coefficient  Std. err.         z  \
# 0     r_shanghai   r_shanghai     L1     0.105026   0.079782  1.316415
# 1     r_shanghai   r_shanghai     L2     0.159362   0.094675  1.683259
# 2     r_shanghai   r_shanghai     L3     0.044914   0.094335  0.476108
# 3     r_shanghai   r_shanghai     L4     0.363120   0.089687  4.048767
# 4     r_shanghai     r_nikkei     L1    -0.116411   0.120665 -0.964749
# 5     r_shanghai     r_nikkei     L2    -0.268877   0.122595 -2.193209
# 6     r_shanghai     r_nikkei     L3    -0.102295   0.125615 -0.814359
# 7     r_shanghai     r_nikkei     L4     0.048904   0.125505  0.389657
# 8     r_shanghai      r_kospi     L1     0.079250   0.135911  0.583099
# 9     r_shanghai      r_kospi     L2     0.167953   0.133897  1.254346
# 10    r_shanghai      r_kospi     L3     0.369037   0.134172  2.750488
# 11    r_shanghai      r_kospi     L4    -0.158152   0.134748 -1.173689
# 12    r_shanghai   r_hangseng     L1    -0.050863   0.120552 -0.421918
# 13    r_shanghai   r_hangseng     L2    -0.108259   0.120458 -0.898723
# 14    r_shanghai   r_hangseng     L3    -0.073902   0.118356 -0.624409
# 15    r_shanghai   r_hangseng     L4    -0.123789   0.115850 -1.068530
# 16    r_shanghai  r_singapore     L1     0.064874   0.172956  0.375090
# 17    r_shanghai  r_singapore     L2     0.243251   0.171755  1.416267
# 18    r_shanghai  r_singapore     L3    -0.226832   0.170411 -1.331088
# 19    r_shanghai  r_singapore     L4    -0.067927   0.167987 -0.404361
# 20    r_shanghai       StdISI     L1    -0.942591   0.789514 -1.193888
# 21    r_shanghai       StdISI     L2     0.329044   0.891094  0.369259
# 22    r_shanghai       StdISI     L3    -0.776281   0.893748 -0.868568
# 23    r_shanghai       StdISI     L4     0.534294   0.736922  0.725035
# 24    r_shanghai        const  const     0.154659   0.472724  0.327165
# 25      r_nikkei   r_shanghai     L1     0.064593   0.057999  1.113692
# 26      r_nikkei   r_shanghai     L2     0.062864   0.068825  0.913378
# 27      r_nikkei   r_shanghai     L3     0.052600   0.068579  0.767000
# 28      r_nikkei   r_shanghai     L4     0.185084   0.065199  2.838750
# 29      r_nikkei     r_nikkei     L1     0.030075   0.087719  0.342860
# 30      r_nikkei     r_nikkei     L2    -0.155808   0.089123 -1.748243
# 31      r_nikkei     r_nikkei     L3     0.032511   0.091317  0.356019
# 32      r_nikkei     r_nikkei     L4    -0.083703   0.091238 -0.917417
# 33      r_nikkei      r_kospi     L1    -0.045690   0.098803 -0.462440
# 34      r_nikkei      r_kospi     L2     0.181812   0.097338  1.867836
# 35      r_nikkei      r_kospi     L3     0.245536   0.097538  2.517338
# 36      r_nikkei      r_kospi     L4     0.146664   0.097957  1.497234
# 37      r_nikkei   r_hangseng     L1     0.026395   0.087637  0.301187
# 38      r_nikkei   r_hangseng     L2    -0.026629   0.087569 -0.304087
# 39      r_nikkei   r_hangseng     L3    -0.146309   0.086040 -1.700467
# 40      r_nikkei   r_hangseng     L4    -0.029212   0.084219 -0.346855
# 41      r_nikkei  r_singapore     L1     0.037901   0.125733  0.301440
# 42      r_nikkei  r_singapore     L2    -0.018668   0.124860 -0.149514
# 43      r_nikkei  r_singapore     L3    -0.078141   0.123883 -0.630766
# 44      r_nikkei  r_singapore     L4    -0.154966   0.122121 -1.268958
# 45      r_nikkei       StdISI     L1    -0.229204   0.573949 -0.399346
# 46      r_nikkei       StdISI     L2     0.031556   0.647794  0.048713
# 47      r_nikkei       StdISI     L3    -1.304850   0.649724 -2.008315
# 48      r_nikkei       StdISI     L4     0.707783   0.535717  1.321190
# 49      r_nikkei        const  const     0.358283   0.343654  1.042568
# 50       r_kospi   r_shanghai     L1    -0.055302   0.058660 -0.942764
# 51       r_kospi   r_shanghai     L2     0.054747   0.069610  0.786475
# 52       r_kospi   r_shanghai     L3     0.074573   0.069361  1.075145
# 53       r_kospi   r_shanghai     L4     0.117700   0.065942  1.784883
# 54       r_kospi     r_nikkei     L1    -0.018889   0.088719 -0.212908
# 55       r_kospi     r_nikkei     L2    -0.227131   0.090139 -2.519792
# 56       r_kospi     r_nikkei     L3    -0.089545   0.092359 -0.969539
# 57       r_kospi     r_nikkei     L4    -0.029719   0.092278 -0.322056
# 58       r_kospi      r_kospi     L1    -0.066031   0.099929 -0.660777
# 59       r_kospi      r_kospi     L2     0.070358   0.098448  0.714675
# 60       r_kospi      r_kospi     L3     0.309663   0.098650  3.138993
# 61       r_kospi      r_kospi     L4     0.108375   0.099074  1.093881
# 62       r_kospi   r_hangseng     L1    -0.025002   0.088636 -0.282077
# 63       r_kospi   r_hangseng     L2     0.056296   0.088568  0.635626
# 64       r_kospi   r_hangseng     L3    -0.168996   0.087021 -1.941998
# 65       r_kospi   r_hangseng     L4    -0.115189   0.085179 -1.352321
# 66       r_kospi  r_singapore     L1     0.115295   0.127167  0.906646
# 67       r_kospi  r_singapore     L2     0.093829   0.126284  0.743004
# 68       r_kospi  r_singapore     L3    -0.060727   0.125295 -0.484675
# 69       r_kospi  r_singapore     L4    -0.017808   0.123513 -0.144176
# 70       r_kospi       StdISI     L1     0.389534   0.580494  0.671038
# 71       r_kospi       StdISI     L2    -0.468165   0.655181 -0.714558
# 72       r_kospi       StdISI     L3    -0.785429   0.657133 -1.195236
# 73       r_kospi       StdISI     L4     0.426734   0.541826  0.787585
# 74       r_kospi        const  const     0.487237   0.347573  1.401826
# 75    r_hangseng   r_shanghai     L1    -0.052170   0.066669 -0.782527
# 76    r_hangseng   r_shanghai     L2     0.225670   0.079114  2.852453
# 77    r_hangseng   r_shanghai     L3     0.006836   0.078831  0.086716
# 78    r_hangseng   r_shanghai     L4     0.259919   0.074946  3.468083
# 79    r_hangseng     r_nikkei     L1    -0.154740   0.100832 -1.534620
# 80    r_hangseng     r_nikkei     L2    -0.291248   0.102446 -2.842947
# 81    r_hangseng     r_nikkei     L3    -0.136811   0.104969 -1.303345
# 82    r_hangseng     r_nikkei     L4    -0.068631   0.104878 -0.654395
# 83    r_hangseng      r_kospi     L1     0.160922   0.113573  1.416902
# 84    r_hangseng      r_kospi     L2     0.439272   0.111890  3.925937
# 85    r_hangseng      r_kospi     L3     0.310519   0.112120  2.769535
# 86    r_hangseng      r_kospi     L4     0.193694   0.112601  1.720181
# 87    r_hangseng   r_hangseng     L1    -0.137632   0.100738 -1.366231
# 88    r_hangseng   r_hangseng     L2    -0.312740   0.100660 -3.106893
# 89    r_hangseng   r_hangseng     L3    -0.173949   0.098903 -1.758781
# 90    r_hangseng   r_hangseng     L4    -0.375779   0.096809 -3.881657
# 91    r_hangseng  r_singapore     L1     0.050862   0.144529  0.351912
# 92    r_hangseng  r_singapore     L2     0.189240   0.143526  1.318505
# 93    r_hangseng  r_singapore     L3     0.126587   0.142402  0.888936
# 94    r_hangseng  r_singapore     L4     0.185914   0.140377  1.324387
# 95    r_hangseng       StdISI     L1    -1.261160   0.659752 -1.911567
# 96    r_hangseng       StdISI     L2     0.677819   0.744636  0.910268
# 97    r_hangseng       StdISI     L3    -1.599532   0.746854 -2.141692
# 98    r_hangseng       StdISI     L4     1.346701   0.615804  2.186901
# 99    r_hangseng        const  const    -0.061558   0.395029 -0.155832
# 100  r_singapore   r_shanghai     L1    -0.005810   0.050261 -0.115599
# 101  r_singapore   r_shanghai     L2     0.140140   0.059644  2.349622
# 102  r_singapore   r_shanghai     L3     0.079539   0.059430  1.338378
# 103  r_singapore   r_shanghai     L4     0.233735   0.056501  4.136824
# 104  r_singapore     r_nikkei     L1     0.073987   0.076017  0.973304
# 105  r_singapore     r_nikkei     L2    -0.293272   0.077233 -3.797233
# 106  r_singapore     r_nikkei     L3    -0.085277   0.079135 -1.077617
# 107  r_singapore     r_nikkei     L4    -0.053542   0.079066 -0.677181
# 108  r_singapore      r_kospi     L1    -0.037427   0.085622 -0.437119
# 109  r_singapore      r_kospi     L2     0.199335   0.084353  2.363120
# 110  r_singapore      r_kospi     L3     0.177351   0.084526  2.098186
# 111  r_singapore      r_kospi     L4     0.186331   0.084889  2.194999
# 112  r_singapore   r_hangseng     L1     0.003504   0.075946  0.046140
# 113  r_singapore   r_hangseng     L2    -0.132464   0.075887 -1.745551
# 114  r_singapore   r_hangseng     L3    -0.168000   0.074562 -2.253153
# 115  r_singapore   r_hangseng     L4    -0.283449   0.072983 -3.883754
# 116  r_singapore  r_singapore     L1     0.030004   0.108959  0.275371
# 117  r_singapore  r_singapore     L2     0.170825   0.108203  1.578744
# 118  r_singapore  r_singapore     L3     0.095193   0.107356  0.886702
# 119  r_singapore  r_singapore     L4     0.065381   0.105829  0.617802
# 120  r_singapore       StdISI     L1    -0.591125   0.497381 -1.188475
# 121  r_singapore       StdISI     L2    -0.382188   0.561375 -0.680808
# 122  r_singapore       StdISI     L3    -1.026748   0.563047 -1.823557
# 123  r_singapore       StdISI     L4     1.270364   0.464249  2.736386
# 124  r_singapore        const  const     0.158499   0.297809  0.532219
# 125       StdISI   r_shanghai     L1     0.064965   0.006892  9.425743
# 126       StdISI   r_shanghai     L2     0.012404   0.008179  1.516611
# 127       StdISI   r_shanghai     L3     0.009890   0.008150  1.213539
# 128       StdISI   r_shanghai     L4     0.001031   0.007748  0.133013
# 129       StdISI     r_nikkei     L1    -0.016697   0.010424 -1.601770
# 130       StdISI     r_nikkei     L2    -0.015761   0.010591 -1.488170
# 131       StdISI     r_nikkei     L3     0.008999   0.010852  0.829300
# 132       StdISI     r_nikkei     L4     0.004306   0.010842  0.397185
# 133       StdISI      r_kospi     L1     0.004034   0.011741  0.343534
# 134       StdISI      r_kospi     L2     0.011923   0.011567  1.030716
# 135       StdISI      r_kospi     L3     0.009452   0.011591  0.815427
# 136       StdISI      r_kospi     L4    -0.013809   0.011641 -1.186265
# 137       StdISI   r_hangseng     L1    -0.016583   0.010414 -1.592294
# 138       StdISI   r_hangseng     L2    -0.010076   0.010406 -0.968225
# 139       StdISI   r_hangseng     L3    -0.021458   0.010225 -2.098685
# 140       StdISI   r_hangseng     L4    -0.006287   0.010008 -0.628154
# 141       StdISI  r_singapore     L1     0.001572   0.014942  0.105222
# 142       StdISI  r_singapore     L2     0.009194   0.014838  0.619615
# 143       StdISI  r_singapore     L3    -0.004105   0.014722 -0.278833
# 144       StdISI  r_singapore     L4     0.026440   0.014512  1.821888
# 145       StdISI       StdISI     L1     0.527600   0.068206  7.735445
# 146       StdISI       StdISI     L2     0.116925   0.076981  1.518888
# 147       StdISI       StdISI     L3     0.122422   0.077210  1.585561
# 148       StdISI       StdISI     L4     0.096523   0.063662  1.516173
# 149       StdISI        const  const    -0.009664   0.040838 -0.236650
#
#             P>|z|  95% CI lower  95% CI upper
# 0    1.880349e-01     -0.051344      0.261395
# 1    9.232500e-02     -0.026197      0.344921
# 2    6.339975e-01     -0.139980      0.229808
# 3    5.148816e-05      0.187337      0.538902
# 4    3.346704e-01     -0.352909      0.120087
# 5    2.829235e-02     -0.509160     -0.028595
# 6    4.154393e-01     -0.348495      0.143905
# 7    6.967904e-01     -0.197082      0.294890
# 8    5.598263e-01     -0.187131      0.345631
# 9    2.097162e-01     -0.094480      0.430385
# 10   5.950660e-03      0.106066      0.632009
# 11   2.405197e-01     -0.422253      0.105949
# 12   6.730850e-01     -0.287140      0.185414
# 13   3.688001e-01     -0.344353      0.127835
# 147  1.128390e-01     -0.028908      0.273751
# 148  1.294756e-01     -0.028253      0.221298
# 149  8.129281e-01     -0.089706      0.070377

# %% [markdown]
# ## 4.3. VAR(4) Stability Test
#
# Check whether the VAR(4) model satisfies the stability condition.

# %%
# Stability test using companion-matrix eigenvalues.
# The VAR is stable when all eigenvalue moduli are less than 1.
eigenvalues_lag4 = 1 / var_results_stdisi_lag4.roots

stability_table_lag4 = pd.DataFrame({
    "Eigenvalue": eigenvalues_lag4,
    "Modulus": np.abs(eigenvalues_lag4)
})

stability_table_lag4 = stability_table_lag4.sort_values(
    by="Modulus",
    ascending=False
).reset_index(drop=True)

display(stability_table_lag4)

if np.all(stability_table_lag4["Modulus"] < 1):
    print("All eigenvalue moduli are less than 1.")
    print("VAR(4) satisfies stability condition.")
else:
    print("At least one eigenvalue modulus is greater than or equal to 1.")
    print("VAR(4) does not satisfy stability condition.")
# Out:
#             Eigenvalue   Modulus
# 0   0.859690+0.000000j  0.859690
# 1   0.764000+0.000000j  0.764000
# 2  -0.395392-0.650287j  0.761057
# 3  -0.395392+0.650287j  0.761057
# 4   0.030069-0.725058j  0.725681
# 5   0.030069+0.725058j  0.725681
# 6   0.140029-0.697939j  0.711848
# 7   0.140029+0.697939j  0.711848
# 8  -0.651852-0.000000j  0.651852
# 9  -0.342665-0.537365j  0.637323
# 10 -0.342665+0.537365j  0.637323
# 11  0.548810-0.297170j  0.624101
# 12  0.548810+0.297170j  0.624101
# 13  0.543551+0.200711j  0.579424
# 14  0.543551-0.200711j  0.579424
# 15 -0.538356+0.181514j  0.568132
# 16 -0.538356-0.181514j  0.568132
# 17 -0.414820-0.000000j  0.414820
# 18 -0.199704-0.361305j  0.412823
# 19 -0.199704+0.361305j  0.412823
# 20  0.155506+0.377784j  0.408538
# 21  0.155506-0.377784j  0.408538
# 22  0.349934+0.000000j  0.349934
# 23 -0.301604-0.000000j  0.301604
# All eigenvalue moduli are less than 1.
# VAR(4) satisfies stability condition.

# %% [markdown]
# ## 4.4. VAR(4) Granger Causality Tests
#
# Run Wald tests for Granger causality using the VAR(4) model.

# %%
# Granger causality Wald tests using the VAR(4) model.
var_names = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "StdISI"
]

granger_lag4_rows = []

for equation in var_names:
    excluded_vars = [var for var in var_names if var != equation]

    # Test each excluded variable one by one.
    for excluded in excluded_vars:
        test_result = var_results_stdisi_lag4.test_causality(
            caused=equation,
            causing=excluded,
            kind="wald"
        )

        granger_lag4_rows.append({
            "Equation": equation,
            "Excluded": excluded,
            "chi2": test_result.test_statistic,
            "df": test_result.df,
            "Prob > chi2": test_result.pvalue
        })

    # Test all other variables jointly.
    test_all = var_results_stdisi_lag4.test_causality(
        caused=equation,
        causing=excluded_vars,
        kind="wald"
    )

    granger_lag4_rows.append({
        "Equation": equation,
        "Excluded": "ALL",
        "chi2": test_all.test_statistic,
        "df": test_all.df,
        "Prob > chi2": test_all.pvalue
    })

granger_lag4_table = pd.DataFrame(granger_lag4_rows)

granger_lag4_table_formatted = granger_lag4_table.copy()
granger_lag4_table_formatted["chi2"] = granger_lag4_table_formatted["chi2"].map(lambda x: f"{x:.4f}")
granger_lag4_table_formatted["Prob > chi2"] = granger_lag4_table_formatted["Prob > chi2"].map(lambda x: f"{x:.3f}")

display(granger_lag4_table_formatted)
# Out:
#        Equation     Excluded      chi2  df Prob > chi2
# 0    r_shanghai     r_nikkei    6.4942   4       0.165
# 1    r_shanghai      r_kospi   11.1560   4       0.025
# 2    r_shanghai   r_hangseng    1.9237   4       0.750
# 3    r_shanghai  r_singapore    3.9483   4       0.413
# 4    r_shanghai       StdISI    5.9803   4       0.201
# 5    r_shanghai          ALL   26.9324  20       0.137
# 6      r_nikkei   r_shanghai   11.1150   4       0.025
# 7      r_nikkei      r_kospi   10.2805   4       0.036
# 8      r_nikkei   r_hangseng    3.2764   4       0.513
# 9      r_nikkei  r_singapore    2.0220   4       0.732
# 10     r_nikkei       StdISI   11.5592   4       0.021
# 11     r_nikkei          ALL   33.8868  20       0.027
# 12      r_kospi   r_shanghai    5.4915   4       0.240
# 13      r_kospi     r_nikkei    7.6504   4       0.105
# 14      r_kospi   r_hangseng    6.2892   4       0.179
# 15      r_kospi  r_singapore    1.5402   4       0.819
# 16      r_kospi       StdISI    4.8964   4       0.298
# 17      r_kospi          ALL   30.1781  20       0.067
# 18   r_hangseng   r_shanghai   19.9352   4       0.001
# 19   r_hangseng     r_nikkei   13.2762   4       0.010
# 20   r_hangseng      r_kospi   22.8798   4       0.000
# 21   r_hangseng  r_singapore    4.6992   4       0.320
# 22   r_hangseng       StdISI   13.5541   4       0.009
# 23   r_hangseng          ALL   60.5956  20       0.000
# 24  r_singapore   r_shanghai   23.8410   4       0.000
# 25  r_singapore     r_nikkei   17.2668   4       0.002
# 26  r_singapore      r_kospi   12.0726   4       0.017
# 27  r_singapore   r_hangseng   19.4164   4       0.001
# 28  r_singapore       StdISI   16.1548   4       0.003
# 29  r_singapore          ALL   57.0425  20       0.000
# 30       StdISI   r_shanghai   93.9554   4       0.000
# 31       StdISI     r_nikkei    5.3166   4       0.256
# 32       StdISI      r_kospi    3.5810   4       0.466
# 33       StdISI   r_hangseng    6.4247   4       0.170
# 34       StdISI  r_singapore    4.1111   4       0.391
# 35       StdISI          ALL  117.6419  20       0.000

# %% [markdown]
# # 5. PCA Sentiment Index Construction
#
# Construct an alternative investor sentiment index from the six sentiment proxy variables.

# %% [markdown]
# ## 5.1. Descriptive Statistics and Standardisation
#
# Report descriptive statistics for the six sentiment proxies, then standardise them for PCA.

# %%
# Descriptive statistics for the six sentiment proxies used in PCA.
sentiment_pca_vars = ["DCEF", "RIPO", "NIPO", "NA", "TURN", "CCI"]

summary_sentiment = pd.DataFrame({
    "N": master_df[sentiment_pca_vars].count(),
    "Mean": master_df[sentiment_pca_vars].mean(),
    "Std. dev.": master_df[sentiment_pca_vars].std(ddof=1),
    "Minimum": master_df[sentiment_pca_vars].min(),
    "Maximum": master_df[sentiment_pca_vars].max()
})

summary_sentiment.index.name = "Variable"
display(summary_sentiment.round(4))
# Out:
#             N      Mean  Std. dev.  Minimum   Maximum
# Variable
# DCEF      248   -0.1211     0.1301  -0.3321    0.4414
# RIPO      248    0.6191     0.6737  -0.0521    6.2674
# NIPO      248   17.3185    15.8620   0.0000   82.0000
# NA        248   40.2921    41.6088   2.3000  297.4700
# TURN      248    0.2562     0.1226   0.0852    0.8247
# CCI       248  104.0109    11.1870  85.5000  127.0000

# %%
# Sentiment variables used for PCA.
sentiment_pca_vars = ["DCEF", "RIPO", "NIPO", "NA", "TURN", "CCI"]

# Use the full merged monthly dataset for PCA because these sentiment variables
# do not lose the first return observation.
pca_df = master_df[["month"] + sentiment_pca_vars].copy()

for col in sentiment_pca_vars:
    pca_df[f"z_{col}"] = (
        pca_df[col] - pca_df[col].mean()
    ) / pca_df[col].std(ddof=1)

z_sentiment_vars = [f"z_{col}" for col in sentiment_pca_vars]

print(f"PCA observations: {len(pca_df)}")
print("Standardized variables:")
print(z_sentiment_vars)

pca_df[["month"] + z_sentiment_vars].head()
# Out:
# PCA observations: 248
# Standardized variables:
# ['z_DCEF', 'z_RIPO', 'z_NIPO', 'z_NA', 'z_TURN', 'z_CCI']
#      month    z_DCEF    z_RIPO    z_NIPO      z_NA    z_TURN     z_CCI
# 0  2003-01  0.135937  0.424325 -0.776608 -0.872941 -1.230155 -0.582007
# 1  2003-02  0.072138  0.222611 -0.902696 -0.899858 -0.517233 -0.564129
# 2  2003-03  0.207424  0.094962 -0.713564 -0.890005 -1.006653 -0.555190
# 3  2003-04 -0.144628  0.840370 -0.776608 -0.831604 -1.096380 -0.573068
# 4  2003-05 -0.523585  0.657803 -0.965740 -0.867173  0.517891 -1.368638

# %% [markdown]
# ## 5.2. PCA for Sentiment Variables
#
# Run PCA using the standardized sentiment variables and report eigenvalues, explained variance, and loadings.

# %%
# PCA on standardized sentiment variables.
X_pca = pca_df[z_sentiment_vars].dropna().copy()

pca_model = PCA()
pca_scores = pca_model.fit_transform(X_pca)

component_names = [f"Comp{i}" for i in range(1, len(z_sentiment_vars) + 1)]

eigenvalues = pca_model.explained_variance_
proportion = pca_model.explained_variance_ratio_
cumulative = np.cumsum(proportion)
difference = np.r_[eigenvalues[:-1] - eigenvalues[1:], np.nan]

pca_summary = pd.DataFrame({
    "Component": component_names,
    "Eigenvalue": eigenvalues,
    "Difference": difference,
    "Proportion": proportion,
    "Cumulative": cumulative
})

loadings = pd.DataFrame(
    pca_model.components_.T,
    index=z_sentiment_vars,
    columns=component_names
)

print(f"Number of obs: {len(X_pca)}")
print(f"Number of components: {len(component_names)}")
print(f"Trace: {eigenvalues.sum():.4f}")

print("\nPCA summary:")
display(pca_summary)

print("\nPCA loadings:")
display(loadings)
# Out:
# Number of obs: 248
# Number of components: 6
# Trace: 6.0000
#
# PCA summary:
#   Component  Eigenvalue  Difference  Proportion  Cumulative
# 0     Comp1    2.011522    0.386965    0.335254    0.335254
# 1     Comp2    1.624557    0.753347    0.270759    0.606013
# 2     Comp3    0.871209    0.157553    0.145202    0.751215
# 3     Comp4    0.713657    0.291885    0.118943    0.870157
# 4     Comp5    0.421772    0.064488    0.070295    0.940453
# 5     Comp6    0.357284         NaN    0.059547    1.000000
# PCA loadings:
#            Comp1     Comp2     Comp3     Comp4     Comp5     Comp6
# z_DCEF  0.341958 -0.511647 -0.378379 -0.254048 -0.569954 -0.297866
# z_RIPO  0.382240  0.288762  0.590574 -0.570780 -0.005691 -0.309692
# z_NIPO  0.492592 -0.380654 -0.175388 -0.148589  0.726318  0.179107
# z_NA    0.519818  0.377823 -0.109996  0.061359 -0.335532  0.677195
# z_TURN  0.325851  0.512176 -0.420775  0.343762  0.154014 -0.559064
# z_CCI   0.343398 -0.323824  0.536786  0.682388 -0.106211 -0.110190

# %% [markdown]
# ## 5.3. Scree Plot
#
# Plot PCA eigenvalues and add a reference line at eigenvalue 1.

# %%
# Scree plot for PCA eigenvalues.
component_numbers = np.arange(1, len(eigenvalues) + 1)

plt.figure(figsize=(8, 5))
plt.plot(
    component_numbers,
    eigenvalues,
    marker="o",
    color="dodgerblue",
    linewidth=1.5
)

plt.axhline(
    y=1,
    color="crimson",
    linestyle="--",
    linewidth=1,
    label="Eigenvalue = 1"
)

plt.xticks(component_numbers)
plt.xlabel("Principal component")
plt.ylabel("Eigenvalue")
plt.title("Scree Plot")
plt.grid(True, linestyle="--", alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# ## 5.4. PCA Loadings
#
# Display the PCA loading matrix for the standardized sentiment variables.

# %%
# Display PCA loadings separately.
loadings
# Out:
#            Comp1     Comp2     Comp3     Comp4     Comp5     Comp6
# z_DCEF  0.341958 -0.511647 -0.378379 -0.254048 -0.569954 -0.297866
# z_RIPO  0.382240  0.288762  0.590574 -0.570780 -0.005691 -0.309692
# z_NIPO  0.492592 -0.380654 -0.175388 -0.148589  0.726318  0.179107
# z_NA    0.519818  0.377823 -0.109996  0.061359 -0.335532  0.677195
# z_TURN  0.325851  0.512176 -0.420775  0.343762  0.154014 -0.559064
# z_CCI   0.343398 -0.323824  0.536786  0.682388 -0.106211 -0.110190

# %% [markdown]
# ## 5.5. Generate PCA1 and PCA2
#
# Create the first two principal component score variables.

# %%
# Align PCA signs so higher component scores have a consistent sentiment direction.
# PCA signs are arbitrary, so multiplying a component by -1 is still the same PCA solution.
if loadings.loc["z_DCEF", "Comp1"] < 0:
    loadings["Comp1"] = -loadings["Comp1"]
    pca_scores[:, 0] = -pca_scores[:, 0]

if loadings.loc["z_DCEF", "Comp2"] < 0:
    loadings["Comp2"] = -loadings["Comp2"]
    pca_scores[:, 1] = -pca_scores[:, 1]

# Add aligned PCA scores to the PCA dataset.
pca_df["pca1"] = pca_scores[:, 0]
pca_df["pca2"] = pca_scores[:, 1]

pca_df[["month", "pca1", "pca2"]].head()
# Out:
#      month      pca1      pca2
# 0  2003-01 -1.228350  0.422810
# 1  2003-02 -1.164926  0.051236
# 2  2003-03 -1.225578  0.479150
# 3  2003-04 -1.097114  0.077882
# 4  2003-05 -1.155325 -1.206262

# %% [markdown]
# ## 5.6. Construct Final Sentiment Index
#
# Construct the final sentiment index using the first two PCA components weighted by their explained variance shares.

# %%
# Construct final sentiment index using PCA1 and PCA2.
pca1_weight = proportion[0]
pca2_weight = proportion[1]
total_weight = pca1_weight + pca2_weight

pca_df["sen"] = (
    (pca1_weight / total_weight) * pca_df["pca1"]
    + (pca2_weight / total_weight) * pca_df["pca2"]
)

# Remove previous PCA columns so this cell can be run repeatedly without suffixes.
analysis_df = analysis_df.drop(
    columns=[
        "pca1", "pca2", "sen",
        "pca1_x", "pca1_y", "pca2_x", "pca2_y",
        "sen_x", "sen_y"
    ],
    errors="ignore"
)

analysis_df = analysis_df.merge(
    pca_df[["month", "pca1", "pca2", "sen"]],
    on="month",
    how="left"
)

print(f"PCA1 weight: {pca1_weight / total_weight:.4f}")
print(f"PCA2 weight: {pca2_weight / total_weight:.4f}")

analysis_df[["month", "pca1", "pca2", "sen"]].head()
# Out:
# PCA1 weight: 0.5532
# PCA2 weight: 0.4468
#      month      pca1      pca2       sen
# 0  2003-02 -1.164926  0.051236 -0.621559
# 1  2003-03 -1.225578  0.479150 -0.463925
# 2  2003-04 -1.097114  0.077882 -0.572140
# 3  2003-05 -1.155325 -1.206262 -1.178083
# 4  2003-06 -1.386193 -0.853339 -1.148120

# %% [markdown]
# ## 5.7. Descriptive Statistics of Sentiment Indices
#
# Summarise StdISI and the PCA-constructed sentiment index using the common return-analysis sample.

# %%
# Descriptive statistics for the original and PCA-constructed sentiment indices.
sentiment_index_vars = ["StdISI", "sen"]

sentiment_index_summary = pd.DataFrame({
    "N": analysis_df[sentiment_index_vars].count(),
    "Mean": analysis_df[sentiment_index_vars].mean(),
    "Std. dev.": analysis_df[sentiment_index_vars].std(ddof=1),
    "Minimum": analysis_df[sentiment_index_vars].min(),
    "Maximum": analysis_df[sentiment_index_vars].max()
})

sentiment_index_summary.index.name = "Variable"
display(sentiment_index_summary.round(4))
# Out:
#             N   Mean  Std. dev.  Minimum  Maximum
# Variable
# StdISI    247  0.005     1.4646  -2.4800   5.9300
# sen       247  0.002     0.9710  -1.7175   2.9189

# %% [markdown]
# ## 5.8. Stationarity Test for Constructed Sentiment Index
#
# Apply the ADF test to the PCA-constructed sentiment index using zero lags, consistent with the Stata `dfuller sen` specification.

# %%
# ADF test for sen with zero lags, matching Stata: dfuller sen.
sen_series = analysis_df["sen"].replace([np.inf, -np.inf], np.nan).dropna()
sen_adf = adfuller(
    sen_series,
    maxlag=0,
    regression="c",
    autolag=None
)

adf_sen_results = pd.DataFrame([{
    "Variable": "sen",
    "ADF statistic": sen_adf[0],
    "p-value": sen_adf[1],
    "Lags used": sen_adf[2],
    "Observations": sen_adf[3],
    "Stationary at 5%": sen_adf[1] < 0.05
}])

display(adf_sen_results.round({"ADF statistic": 4, "p-value": 4}))
# Out:
#   Variable  ADF statistic  p-value  Lags used  Observations  Stationary at 5%
# 0      sen         -3.156   0.0227          0           246              True

# %% [markdown]
# ## 5.9. Dissertation Figure: Shanghai Return and SEN
#
# Plot the Shanghai Composite monthly return together with the PCA-constructed sentiment index used in the main VAR and Granger-causality models.

# %%
# Dissertation figure: Shanghai monthly return and PCA-based SEN.
import matplotlib.dates as mdates
plt.style.use("default")
# Separate y-axes are used because returns and SEN have different units and scales.
fig, ax_return = plt.subplots(figsize=(10, 5.4), facecolor="white")
ax_sen = ax_return.twinx()
ax_return.set_facecolor("white")
ax_sen.set_facecolor("none")

return_line = ax_return.plot(
    analysis_df["month_dt"],
    analysis_df["r_shanghai"],
    color="#0072B2",
    linewidth=1.15,
    label="Shanghai monthly return"
)
sen_line = ax_sen.plot(
    analysis_df["month_dt"],
    analysis_df["sen"],
    color="#D55E00",
    linewidth=1.65,
    label="SEN"
)

ax_return.axhline(0, color="#666666", linewidth=0.7, linestyle="--")
ax_sen.axhline(0, color="#D55E00", linewidth=0.6, linestyle=":", alpha=0.55)
ax_return.set_xlabel("Month")
ax_return.set_ylabel("Shanghai monthly log return (%)", color="#0072B2")
ax_sen.set_ylabel("PCA-based sentiment index (SEN)", color="#D55E00")
ax_return.tick_params(axis="both", colors="#222222", labelsize=10)
ax_sen.tick_params(axis="y", colors="#222222", labelsize=10)
ax_return.xaxis.set_major_locator(mdates.YearLocator(4))
ax_return.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))
ax_return.grid(axis="both", color="#D9D9D9", linewidth=0.6, alpha=0.75)
ax_return.set_axisbelow(True)
for axis in (ax_return, ax_sen):
    for spine in axis.spines.values():
        spine.set_color("#444444")
        spine.set_linewidth(0.8)

lines = return_line + sen_line
legend = ax_return.legend(
    lines,
    [line.get_label() for line in lines],
    loc="upper right",
    frameon=True,
    facecolor="white",
    edgecolor="#B0B0B0"
)
for text in legend.get_texts():
    text.set_color("#222222")
fig.tight_layout()

figure_path = PROJECT_ROOT / "dataset" / "outputs" / "figure_4_1_shanghai_return_sen.png"
fig.savefig(figure_path, dpi=300, bbox_inches="tight", facecolor="white")
plt.show()

print(f"Saved dissertation figure to: {figure_path}")
# Out:
# Saved dissertation figure to: C:\Users\20945\Desktop\data\project\dataset\outputs\figure_4_1_shanghai_return_sen.png

# %% [markdown]
# ## 5.10. Dissertation Figure: Correlations between Asian Market Returns and SEN
#
# Display the contemporaneous Pearson correlations between the five Asian monthly return series and the PCA-constructed sentiment index used in the main models.

# %%
# Dissertation heatmap: baseline monthly returns and PCA-based SEN.
plt.style.use("default")
heatmap_vars = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "sen"
]
heatmap_labels = ["Shanghai", "Nikkei 225", "KOSPI", "Hang Seng", "STI", "SEN"]
sen_corr_matrix = analysis_df[heatmap_vars].corr()

fig, ax = plt.subplots(figsize=(8.2, 6.7), facecolor="white")
ax.set_facecolor("white")
image = ax.imshow(sen_corr_matrix, vmin=-1, vmax=1, cmap="RdBu_r")
ax.set_xticks(range(len(heatmap_labels)), heatmap_labels, rotation=35, ha="right")
ax.set_yticks(range(len(heatmap_labels)), heatmap_labels)

for row in range(len(heatmap_labels)):
    for column in range(len(heatmap_labels)):
        value = sen_corr_matrix.iloc[row, column]
        ax.text(
            column,
            row,
            f"{value:.2f}",
            ha="center",
            va="center",
            fontsize=10,
            color="white" if abs(value) >= 0.55 else "black"
        )

ax.tick_params(axis="both", colors="#222222", labelsize=10)
for spine in ax.spines.values():
    spine.set_color("#555555")
    spine.set_linewidth(0.8)
colorbar = fig.colorbar(image, ax=ax, fraction=0.046, pad=0.04)
colorbar.set_label("Pearson correlation coefficient", color="#222222")
colorbar.ax.tick_params(colors="#222222", labelsize=9)
fig.tight_layout()

heatmap_path = PROJECT_ROOT / "dataset" / "outputs" / "figure_4_2_returns_sen_heatmap.png"
fig.savefig(heatmap_path, dpi=300, bbox_inches="tight", facecolor="white")
plt.show()

print(f"Saved dissertation heatmap to: {heatmap_path}")
# Out:
# Saved dissertation heatmap to: C:\Users\20945\Desktop\data\project\dataset\outputs\figure_4_2_returns_sen_heatmap.png

# %% [markdown]
# # 6. Main Baseline VAR Analysis: PCA-Based SEN
#
# Estimate the main baseline correlation, VAR and Granger-causality analysis using the PCA-constructed sentiment index (SEN).

# %% [markdown]
# ## 6.1. Main-Model Correlation: Returns and SEN
#
# Compute pairwise correlations between market returns and the constructed sentiment index.

# %%
corr_vars_sen = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "sen"
]

corr_sen_table = correlation_table_html(
    analysis_df,
    corr_vars_sen,
    star_level=0.05
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>r_shanghai</th>
#       <th>r_nikkei</th>
#       <th>r_kospi</th>
#       <th>r_hangseng</th>
#       <th>r_singapore</th>
#       <th>sen</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>r_shanghai</th>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_nikkei</th>
#       <td>0.3477*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_kospi</th>
#       <td>0.4113*<br>0.0000</td>
#       <td>0.6068*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_hangseng</th>
#       <td>0.5592*<br>0.0000</td>
#       <td>0.4680*<br>0.0000</td>
#       <td>0.5589*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_singapore</th>
#       <td>0.4491*<br>0.0000</td>
#       <td>0.6292*<br>0.0000</td>
#       <td>0.6957*<br>0.0000</td>
#       <td>0.7031*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>sen</th>
#       <td>-0.0207<br>0.7464</td>
#       <td>-0.0141<br>0.8257</td>
#       <td>-0.0625<br>0.3277</td>
#       <td>-0.0928<br>0.1459</td>
#       <td>-0.0334<br>0.6016</td>
#       <td>1.0000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 6.2. Main-Model VAR Lag Selection: SEN, Max Lag 6
#
# Select lag order for the VAR model using returns and the constructed sentiment index.

# %%
# sen VAR lag-order selection with maximum lag 6.
var_vars_sen = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "sen"
]

var_data_sen = analysis_df[var_vars_sen].dropna().copy()
var_model_sen = VAR(var_data_sen)

lag_order_sen_6 = var_model_sen.select_order(maxlags=6)
lag_order_sen_6.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## 6.3. Main Baseline VAR(2) Model with SEN
#
# Estimate the VAR model with two lags using market returns and the constructed sentiment index.

# %%
# Estimate the VAR(2) model with sen.
var_vars_sen = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "sen"
]

var_data_sen = analysis_df[var_vars_sen].dropna().copy()
var_model_sen = VAR(var_data_sen)

# fit(2) includes lag 1 and lag 2.
var_results_sen_lag2 = var_model_sen.fit(2)

print(var_results_sen_lag2.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 31, Jul, 2026
# Time:                     23:11:36
# --------------------------------------------------------------------
# No. of Equations:         6.00000    BIC:                    14.3983
# Nobs:                     245.000    HQIC:                   13.7325
# Log likelihood:          -3635.08    FPE:                    587847.
# AIC:                      13.2836    Det(Omega_mle):         431065.
# --------------------------------------------------------------------
# Results for equation r_shanghai
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.223811         0.474997            0.471           0.638
# L1.r_shanghai          0.099709         0.080184            1.244           0.214
# L1.r_nikkei           -0.062858         0.120372           -0.522           0.602
# L1.r_kospi             0.015493         0.130499            0.119           0.905
# L1.r_hangseng         -0.045233         0.118067           -0.383           0.702
# L1.r_singapore         0.082162         0.173489            0.474           0.636
# L1.sen                -0.680670         1.311445           -0.519           0.604
# L2.r_shanghai          0.098437         0.079684            1.235           0.217
# L2.r_nikkei           -0.238102         0.121590           -1.958           0.050
# L2.r_kospi             0.119586         0.129889            0.921           0.357
# L2.r_hangseng         -0.051573         0.113488           -0.454           0.650
# L2.r_singapore         0.251825         0.168264            1.497           0.134
# L2.sen                 0.069904         1.312498            0.053           0.958
# =================================================================================
#
# Results for equation r_nikkei
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.507655         0.346473            1.465           0.143
# L1.r_shanghai          0.073908         0.058488            1.264           0.206
# L1.r_nikkei            0.059778         0.087802            0.681           0.496
# L1.r_kospi            -0.049791         0.095189           -0.523           0.601
# L1.r_hangseng          0.058662         0.086120            0.681           0.496
# L1.r_singapore         0.001955         0.126546            0.015           0.988
# L1.sen                -0.353693         0.956597           -0.370           0.712
# L2.r_shanghai          0.052650         0.058123            0.906           0.365
# L2.r_nikkei           -0.116948         0.088690           -1.319           0.187
# L2.r_kospi             0.096722         0.094744            1.021           0.307
# L2.r_hangseng          0.026481         0.082781            0.320           0.749
# L2.r_singapore         0.018073         0.122735            0.147           0.883
# L2.sen                 0.272064         0.957365            0.284           0.776
# =================================================================================
#
# Results for equation r_kospi
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.703692         0.345596            2.036           0.042
# L1.r_shanghai         -0.043703         0.058340           -0.749           0.454
# L1.r_nikkei            0.005534         0.087579            0.063           0.950
# L1.r_kospi            -0.111166         0.094948           -1.171           0.242
# L1.r_hangseng          0.017615         0.085902            0.205           0.838
# L1.r_singapore         0.124235         0.126226            0.984           0.325
# L1.sen                 0.523906         0.954176            0.549           0.583
# L2.r_shanghai          0.077282         0.057976            1.333           0.183
# L2.r_nikkei           -0.203730         0.088466           -2.303           0.021
# L2.r_kospi            -0.038677         0.094504           -0.409           0.682
# L2.r_hangseng          0.116918         0.082571            1.416           0.157
# L2.r_singapore         0.090128         0.122425            0.736           0.462
# L2.sen                -0.977929         0.954942           -1.024           0.306
# =================================================================================
#
# Results for equation r_hangseng
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                
# Create a complete coefficient table for the VAR(2) model using sen.

# %%
# Complete coefficient table for the VAR(2) model with sen.
params = var_results_sen_lag2.params
stderr = var_results_sen_lag2.stderr
zvalues = var_results_sen_lag2.tvalues
pvalues = var_results_sen_lag2.pvalues

z_crit = norm.ppf(0.975)

base_variables = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "sen"
]

ordered_parameters = []
for base_var in base_variables:
    ordered_parameters.append(f"L1.{base_var}")
    ordered_parameters.append(f"L2.{base_var}")
ordered_parameters.append("const")

rows = []

for equation in params.columns:
    for variable in ordered_parameters:
        if variable not in params.index:
            continue

        coef = params.loc[variable, equation]
        se = stderr.loc[variable, equation]
        z = zvalues.loc[variable, equation]
        p = pvalues.loc[variable, equation]
        ci_lower = coef - z_crit * se
        ci_upper = coef + z_crit * se

        if variable == "const":
            lag = "const"
            variable_name = "const"
        else:
            lag, variable_name = variable.split(".", 1)

        rows.append({
            "Equation": equation,
            "Variable": variable_name,
            "Lag": lag,
            "Coefficient": coef,
            "Std. err.": se,
            "z": z,
            "P>|z|": p,
            "95% CI lower": ci_lower,
            "95% CI upper": ci_upper
        })

var_sen_lag2_full_table = pd.DataFrame(rows)

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

display(var_sen_lag2_full_table)
# Out:
#        Equation     Variable    Lag  Coefficient  Std. err.          z  \
# 0    r_shanghai   r_shanghai     L1     0.099709   0.080184   1.243505
# 1    r_shanghai   r_shanghai     L2     0.098437   0.079684   1.235341
# 2    r_shanghai     r_nikkei     L1    -0.062858   0.120372  -0.522203
# 3    r_shanghai     r_nikkei     L2    -0.238102   0.121590  -1.958234
# 4    r_shanghai      r_kospi     L1     0.015493   0.130499   0.118724
# 5    r_shanghai      r_kospi     L2     0.119586   0.129889   0.920685
# 6    r_shanghai   r_hangseng     L1    -0.045233   0.118067  -0.383115
# 7    r_shanghai   r_hangseng     L2    -0.051573   0.113488  -0.454430
# 8    r_shanghai  r_singapore     L1     0.082162   0.173489   0.473588
# 9    r_shanghai  r_singapore     L2     0.251825   0.168264   1.496611
# 10   r_shanghai          sen     L1    -0.680670   1.311445  -0.519023
# 11   r_shanghai          sen     L2     0.069904   1.312498   0.053261
# 12   r_shanghai        const  const     0.223811   0.474997   0.471184
# 13     r_nikkei   r_shanghai     L1     0.073908   0.058488   1.263642
# 14     r_nikkei   r_shanghai     L2     0.052650   0.058123   0.905831
# 15     r_nikkei     r_nikkei     L1     0.059778   0.087802   0.680834
# 16     r_nikkei     r_nikkei     L2    -0.116948   0.088690  -1.318610
# 17     r_nikkei      r_kospi     L1    -0.049791   0.095189  -0.523080
# 18     r_nikkei      r_kospi     L2     0.096722   0.094744   1.020881
# 19     r_nikkei   r_hangseng     L1     0.058662   0.086120   0.681159
# 20     r_nikkei   r_hangseng     L2     0.026481   0.082781   0.319886
# 21     r_nikkei  r_singapore     L1     0.001955   0.126546   0.015453
# 22     r_nikkei  r_singapore     L2     0.018073   0.122735   0.147249
# 23     r_nikkei          sen     L1    -0.353693   0.956597  -0.369742
# 24     r_nikkei          sen     L2     0.272064   0.957365   0.284180
# 25     r_nikkei        const  const     0.507655   0.346473   1.465206
# 26      r_kospi   r_shanghai     L1    -0.043703   0.058340  -0.749103
# 27      r_kospi   r_shanghai     L2     0.077282   0.057976   1.332989
# 28      r_kospi     r_nikkei     L1     0.005534   0.087579   0.063193
# 29      r_kospi     r_nikkei     L2    -0.203730   0.088466  -2.302920
# 30      r_kospi      r_kospi     L1    -0.111166   0.094948  -1.170814
# 31      r_kospi      r_kospi     L2    -0.038677   0.094504  -0.409265
# 32      r_kospi   r_hangseng     L1     0.017615   0.085902   0.205063
# 33      r_kospi   r_hangseng     L2     0.116918   0.082571   1.415964
# 34      r_kospi  r_singapore     L1     0.124235   0.126226   0.984228
# 35      r_kospi  r_singapore     L2     0.090128   0.122425   0.736188
# 36      r_kospi          sen     L1     0.523906   0.954176   0.549066
# 37      r_kospi          sen     L2    -0.977929   0.954942  -1.024072
# 38      r_kospi        const  const     0.703692   0.345596   2.036168
# 39   r_hangseng   r_shanghai     L1    -0.055306   0.068370  -0.808921
# 40   r_hangseng   r_shanghai     L2     0.153769   0.067944   2.263188
# 41   r_hangseng     r_nikkei     L1    -0.116482   0.102636  -1.134904
# 42   r_hangseng     r_nikkei     L2    -0.242228   0.103675  -2.336420
# 43   r_hangseng      r_kospi     L1     0.139313   0.111271   1.252012
# 44   r_hangseng      r_kospi     L2     0.293993   0.110751   2.654547
# 45   r_hangseng   r_hangseng     L1    -0.102766   0.100671  -1.020815
# 46   r_hangseng   r_hangseng     L2    -0.163240   0.096767  -1.686940
# 47   r_hangseng  r_singapore     L1     0.084980   0.147927   0.574472
# 48   r_hangseng  r_singapore     L2     0.178443   0.143472   1.243749
# 49   r_hangseng          sen     L1    -0.560386   1.118216  -0.501143
# 50   r_hangseng          sen     L2    -0.032949   1.119114  -0.029442
# 51   r_hangseng        const  const     0.197103   0.405011   0.486662
# 52  r_singapore   r_shanghai     L1     0.006587   0.051909   0.126895
# 53  r_singapore   r_shanghai     L2     0.089989   0.051585   1.744473
# 54  r_singapore     r_nikkei     L1     0.105471   0.077925   1.353488
# 55  r_singapore     r_nikkei     L2    -0.250708   0.078714  -3.185049
# 56  r_singapore      r_kospi     L1    -0.054676   0.084482  -0.647198
# 57  r_singapore      r_kospi     L2     0.081771   0.084086   0.972464
# 58  r_singapore   r_hangseng     L1     0.023521   0.076433   0.307735
# 59  r_singapore   r_hangseng     L2    -0.013240   0.073469  -0.180209
# 60  r_singapore  r_singapore     L1     0.050985   0.112312   0.453955
# 61  r_singapore  r_singapore     L2     0.158304   0.108929   1.453268
# 62  r_singapore          sen     L1    -0.153417   0.848994  -0.180705
# 63  r_singapore          sen     L2    -0.167729   0.849676  -0.197404
# 64  r_singapore        const  const     0.344780   0.307500   1.121235
# 65          sen   r_shanghai     L1     0.010199   0.003947   2.584353
# 66          sen   r_shanghai     L2    -0.005339   0.003922  -1.361392
# 67          sen     r_nikkei     L1     0.006370   0.005925   1.075113
# 53  8.107671e-02     -0.011116      0.191095
# 54  1.758998e-01     -0.047260      0.258202
# 55  1.447293e-03     -0.404985     -0.096431
# 56  5.175037e-01     -0.220257      0.110905
# 57  3.308196e-01     -0.083035      0.246577
# 58  7.582843e-01     -0.126285      0.173327
# 59  8.569887e-01     -0.157237      0.130758
# 60  6.498614e-01     -0.169143      0.271112
# 61  1.461493e-01     -0.055194      0.371801
# 62  8.565994e-01     -1.817415      1.510580
# 63  8.435115e-01     -1.833063      1.497604
# 64  2.621876e-01     -0.257909      0.947470
# 65  9.756180e-03      0.002464      0.017935
# 66  1.733899e-01     -0.013026      0.002348
# 67  2.823240e-01     -0.005242      0.017982
# 68  9.784907e-01     -0.011568      0.011891
# 69  8.880265e-01     -0.013493      0.011685
# 70  8.244384e-01     -0.011112      0.013948
# 71  6.845341e-01     -0.009029      0.013751
# 72  7.112085e-01     -0.008880      0.013016
# 73  9.548076e-01     -0.017220      0.016252
# 74  8.470592e-01     -0.017829      0.014635
# 75  1.248827e-26      0.562933      0.815960
# 76  6.346102e-05      0.131759      0.384988
# 77  9.554269e-01     -0.047129      0.044516

# %% [markdown]
# ## 6.5. Main-Model VAR(2) Stability Test with SEN
#
# Check whether the VAR(2) model with sen satisfies the stability condition.

# %%
# Stability test using companion-matrix eigenvalues.
# The VAR is stable when all eigenvalue moduli are less than 1.
eigenvalues_sen_lag2 = 1 / var_results_sen_lag2.roots

stability_table_sen_lag2 = pd.DataFrame({
    "Eigenvalue": eigenvalues_sen_lag2,
    "Modulus": np.abs(eigenvalues_sen_lag2)
})

stability_table_sen_lag2 = stability_table_sen_lag2.sort_values(
    by="Modulus",
    ascending=False
).reset_index(drop=True)

display(stability_table_sen_lag2)

if np.all(stability_table_sen_lag2["Modulus"] < 1):
    print("All eigenvalue moduli are less than 1.")
    print("VAR(2) with sen satisfies stability condition.")
else:
    print("At least one eigenvalue modulus is greater than or equal to 1.")
    print("VAR(2) with sen does not satisfy stability condition.")
# Out:
#             Eigenvalue   Modulus
# 0   0.951628+0.000000j  0.951628
# 1  -0.095578-0.545266j  0.553579
# 2  -0.095578+0.545266j  0.553579
# 3  -0.425628-0.000000j  0.425628
# 4  -0.390756-0.000000j  0.390756
# 5   0.374935+0.000000j  0.374935
# 6   0.346250+0.000000j  0.346250
# 7   0.006160-0.215535j  0.215623
# 8   0.006160+0.215535j  0.215623
# 9  -0.201817-0.000000j  0.201817
# 10  0.105104-0.125604j  0.163778
# 11  0.105104+0.125604j  0.163778
# All eigenvalue moduli are less than 1.
# VAR(2) with sen satisfies stability condition.

# %% [markdown]
# ## 6.6. Main-Model VAR(2) Granger Causality Tests with SEN
#
# Run Wald tests for Granger causality using the VAR(2) model with sen.

# %%
# Granger causality Wald tests using the VAR(2) model with sen.
var_names_sen = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "sen"
]

granger_sen_lag2_rows = []

for equation in var_names_sen:
    excluded_vars = [var for var in var_names_sen if var != equation]

    # Test each excluded variable one by one.
    for excluded in excluded_vars:
        test_result = var_results_sen_lag2.test_causality(
            caused=equation,
            causing=excluded,
            kind="wald"
        )

        granger_sen_lag2_rows.append({
            "Equation": equation,
            "Excluded": excluded,
            "chi2": test_result.test_statistic,
            "df": test_result.df,
            "Prob > chi2": test_result.pvalue
        })

    # Test all other variables jointly.
    test_all = var_results_sen_lag2.test_causality(
        caused=equation,
        causing=excluded_vars,
        kind="wald"
    )

    granger_sen_lag2_rows.append({
        "Equation": equation,
        "Excluded": "ALL",
        "chi2": test_all.test_statistic,
        "df": test_all.df,
        "Prob > chi2": test_all.pvalue
    })

granger_sen_lag2_table = pd.DataFrame(granger_sen_lag2_rows)

granger_sen_lag2_table_formatted = granger_sen_lag2_table.copy()
granger_sen_lag2_table_formatted["chi2"] = granger_sen_lag2_table_formatted["chi2"].map(lambda x: f"{x:.4f}")
granger_sen_lag2_table_formatted["Prob > chi2"] = granger_sen_lag2_table_formatted["Prob > chi2"].map(lambda x: f"{x:.3f}")

display(granger_sen_lag2_table_formatted)
# Out:
#        Equation     Excluded     chi2  df Prob > chi2
# 0    r_shanghai     r_nikkei   4.1616   2       0.125
# 1    r_shanghai      r_kospi   0.8503   2       0.654
# 2    r_shanghai   r_hangseng   0.3252   2       0.850
# 3    r_shanghai  r_singapore   2.4210   2       0.298
# 4    r_shanghai          sen   1.6031   2       0.449
# 5    r_shanghai          ALL   8.0630  10       0.623
# 6      r_nikkei   r_shanghai   2.7358   2       0.255
# 7      r_nikkei      r_kospi   1.4015   2       0.496
# 8      r_nikkei   r_hangseng   0.5322   2       0.766
# 9      r_nikkei  r_singapore   0.0218   2       0.989
# 10     r_nikkei          sen   0.1621   2       0.922
# 11     r_nikkei          ALL   9.2868  10       0.505
# 12      r_kospi   r_shanghai   2.1268   2       0.345
# 13      r_kospi     r_nikkei   5.3035   2       0.071
# 14      r_kospi   r_hangseng   2.0115   2       0.366
# 15      r_kospi  r_singapore   1.4655   2       0.481
# 16      r_kospi          sen   2.2206   2       0.329
# 17      r_kospi          ALL  17.8975  10       0.057
# 18   r_hangseng   r_shanghai   5.4114   2       0.067
# 19   r_hangseng     r_nikkei   6.8850   2       0.032
# 20   r_hangseng      r_kospi   8.1715   2       0.017
# 21   r_hangseng  r_singapore   1.8328   2       0.400
# 22   r_hangseng          sen   2.0278   2       0.363
# 23   r_hangseng          ALL  23.9487  10       0.008
# 24  r_singapore   r_shanghai   3.1597   2       0.206
# 25  r_singapore     r_nikkei  11.7666   2       0.003
# 26  r_singapore      r_kospi   1.4645   2       0.481
# 27  r_singapore   r_hangseng   0.1380   2       0.933
# 28  r_singapore          sen   1.0006   2       0.606
# 29  r_singapore          ALL  17.7557  10       0.059
# 30          sen   r_shanghai   7.7924   2       0.020
# 31          sen     r_nikkei   1.1588   2       0.560
# 32          sen      r_kospi   0.0740   2       0.964
# 33          sen   r_hangseng   0.2779   2       0.870
# 34          sen  r_singapore   0.0397   2       0.980
# 35          sen          ALL  18.6762  10       0.045
