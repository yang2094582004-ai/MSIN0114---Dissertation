# %% [markdown]
# # Analysis Extended with S&P 500
#
# This notebook repeats the original analysis and adds the S&P 500 to the return, correlation, VAR, stability, and Granger-causality analyses.

# %% [markdown]
# # 1. Data Preparation
#
# Import packages, merge the included frozen source datasets, and construct monthly market returns. The submitted sample ends in 2023-08; no online download is required. Saved notebook outputs allow the results to be viewed without rerunning the notebook.

# %% [markdown]
# ## 1.1. Package Imports
#
# Load the Python packages used for data handling, plotting, correlation tests, and VAR analysis.

# %%
from pathlib import Path

import numpy as np
import openpyxl
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import scipy
import statsmodels

from IPython.display import display, HTML
from scipy.stats import norm, pearsonr
from sklearn.decomposition import PCA
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller

print("All packages imported successfully.")
# Out:
# All packages imported successfully.

# %% [markdown]
# ## 1.2. Data Merging
#
# Read stock price CSV files and the monthly sentiment Excel file, clean them, merge by month, and export the merged dataset.

# %%
# Locate the repository from the current working directory (portable across computers).
PROJECT_ROOT = next(
    (path for path in (Path.cwd(), *Path.cwd().parents) if (path / "dataset").is_dir()),
    None,
)
if PROJECT_ROOT is None:
    raise FileNotFoundError("Could not locate the project dataset directory. Open this notebook from the repository.")
DATA_DIR = PROJECT_ROOT / "dataset"
STOCK_DIR = DATA_DIR / "stock" / "monthly"
OUTPUT_PATH = PROJECT_ROOT / "dataset" / "outputs" / "stock_sentiment_dataset_sp500.xlsx"

# Input files
def find_sp500_file(stock_dir: Path) -> Path:
    """Find the S&P 500 CSV while allowing common filename variations."""
    name_patterns = ("s&p 500", "s&p500", "sp500", "s_p_500", "s-p-500")
    candidates = [
        path
        for path in stock_dir.glob("*.csv")
        if any(pattern in path.name.lower() for pattern in name_patterns)
    ]

    if not candidates:
        raise FileNotFoundError(
            "No S&P 500 CSV was found in dataset/stock. "
            "Add a CSV whose filename contains S&P 500, S&P500, or SP500."
        )

    if len(candidates) > 1:
        raise ValueError(
            "Multiple possible S&P 500 CSV files were found: "
            + ", ".join(path.name for path in candidates)
        )

    return candidates[0]


SP500_FILE = find_sp500_file(STOCK_DIR)

STOCK_FILES = {
    "shanghai_price": STOCK_DIR / "Shanghai Composite Monthly Historical Results Price Data (1).csv",
    "nikkei_price": STOCK_DIR / "Nikkei 225 Monthly Historical Results Price Data (1).csv",
    "kospi_price": STOCK_DIR / "KOSPI Monthly Historical Results Price Data (1).csv",
    "hang_seng_price": STOCK_DIR / "Hang Seng Monthly Historical Results Price Data (1).csv",
    "singapore_sti_price": STOCK_DIR / "FTSE Straits Times Singapore Monthly Historical Results Price Data (2).csv",
    "sp500_price": SP500_FILE,
}

SENTIMENT_FILE = DATA_DIR / "Investor_Sentiment_Monthly.xlsx.xlsx"

# Settings
CUTOFF_MONTH = "2023-08"
SENTIMENT_COLUMNS = ["month", "DCEF", "RIPO", "NIPO", "NA", "TURN", "CCI", "ISI", "StdISI"]


def load_stock_price(file_path: Path, price_column_name: str) -> pd.DataFrame:
    stock = pd.read_csv(file_path)

    # Parse stock dates as dd/mm/yyyy
    stock["Date"] = pd.to_datetime(stock["Date"], format="%d/%m/%Y")

    # Convert to monthly format YYYY-MM
    stock["month"] = stock["Date"].dt.strftime("%Y-%m")

    # Keep only observations up to 2023-08 and only the Price column
    stock = stock.loc[
        stock["month"] <= CUTOFF_MONTH,
        ["month", "Price"]
    ].copy()

    # Rename Price column
    stock = stock.rename(columns={"Price": price_column_name})

    # Sort by month
    stock = stock.sort_values("month").reset_index(drop=True)

    return stock


def load_sentiment(file_path: Path) -> pd.DataFrame:
    sentiment = pd.read_excel(file_path, sheet_name="sheet1")

    # Remove first two metadata/unit rows
    sentiment = sentiment.iloc[2:].copy()

    # Rename monthly date column
    sentiment = sentiment.rename(columns={"SgnMonth": "month"})

    # Convert to monthly format YYYY-MM
    sentiment["month"] = pd.to_datetime(
        sentiment["month"],
        format="%Y-%m"
    ).dt.strftime("%Y-%m")

    # Keep only required sentiment variables
    sentiment = sentiment[SENTIMENT_COLUMNS].copy()

    # Convert sentiment variables to numeric
    for column in SENTIMENT_COLUMNS[1:]:
        sentiment[column] = pd.to_numeric(sentiment[column], errors="coerce")

    sentiment = sentiment.sort_values("month").reset_index(drop=True)

    return sentiment


# Read and clean stock datasets
stock_dataframes = [
    load_stock_price(file_path, price_column_name)
    for price_column_name, file_path in STOCK_FILES.items()
]

# Merge stock datasets
master_df = stock_dataframes[0]

for stock_df in stock_dataframes[1:]:
    master_df = master_df.merge(stock_df, on="month", how="inner")

# Read and clean sentiment dataset
sentiment_df = load_sentiment(SENTIMENT_FILE)

# Merge stock data with sentiment data
master_df = master_df.merge(sentiment_df, on="month", how="inner")

# Sort final dataset
master_df = master_df.sort_values("month").reset_index(drop=True)

# Export final dataset
OUTPUT_PATH.parent.mkdir(parents=True, exist_ok=True)
master_df.to_excel(OUTPUT_PATH, index=False)

# Notebook outputs
print(f"Exported master dataset to: {OUTPUT_PATH}")

print(f"\nFinal row count: {len(master_df):,}")
print(f"Date range: {master_df['month'].min()} to {master_df['month'].max()}")

print("\nMissing value summary:")
print(master_df.isna().sum())

print("\nColumn names:")
print(list(master_df.columns))

# Show first few rows
master_df.head()
# Out:
# Exported master dataset to: C:\Users\20945\Desktop\data\project\dataset\outputs\stock_sentiment_dataset_sp500.xlsx
#
# Final row count: 248
# Date range: 2003-01 to 2023-08
#
# Missing value summary:
# month                  0
# shanghai_price         0
# nikkei_price           0
# kospi_price            0
# hang_seng_price        0
# singapore_sti_price    0
# sp500_price            0
# DCEF                   0
# RIPO                   0
# NIPO                   0
# NA                     0
# TURN                   0
# CCI                    0
# ISI                    0
# StdISI                 0
# dtype: int64
#
# Column names:
# ['month', 'shanghai_price', 'nikkei_price', 'kospi_price', 'hang_seng_price', 'singapore_sti_price', 'sp500_price', 'DCEF', 'RIPO', 'NIPO', 'NA', 'TURN', 'CCI', 'ISI', 'StdISI']
#      month shanghai_price nikkei_price kospi_price hang_seng_price  \
# 0  2003-01       1,499.82     8,339.94      591.86        9,258.95
# 1  2003-02       1,511.93     8,363.04      575.43        9,122.66
# 2  2003-03       1,510.58     7,972.71      535.70        8,634.45
# 3  2003-04       1,521.44     7,831.42      599.35        8,717.22
# 4  2003-05       1,576.26     8,424.51      633.42        9,487.38
#
#   singapore_sti_price sp500_price    DCEF    RIPO  NIPO    NA    TURN   CCI  \
# 0            1,253.98      855.70 -0.1034  0.9050     5  3.97  0.1054  97.5
# 1            1,236.36      841.10 -0.1117  0.7691     3  2.85  0.1928  97.7
# 2            1,235.25      848.20 -0.0941  0.6831     6  3.26  0.1328  97.8
# 3            1,251.60      916.90 -0.1399  1.1853     5  5.69  0.1218  97.6
# 4            1,324.56      963.60 -0.1892  1.0623     2  4.21  0.3197  88.7
#
#      ISI  StdISI
# 0  26.44   -1.26
# 1  25.30   -1.05
# 2  26.20   -1.27
# 3  27.69   -1.07
# 4  24.05   -0.70

# %% [markdown]
# ## 1.3. Return Construction
#
# Convert stock price columns to numeric values, calculate monthly log returns, and create the analysis dataset.

# %%
# Convert stock price columns from string to numeric
price_vars = [
    "shanghai_price",
    "nikkei_price",
    "kospi_price",
    "hang_seng_price",
    "singapore_sti_price",
    "sp500_price"
]

for col in price_vars:
    master_df[col] = (
        master_df[col]
        .astype(str)
        .str.replace(",", "", regex=False)
        .pipe(pd.to_numeric, errors="coerce")
    )

# Generate monthly log return variables
master_df["r_shanghai"] = np.log(master_df["shanghai_price"] / master_df["shanghai_price"].shift(1)) * 100
master_df["r_nikkei"] = np.log(master_df["nikkei_price"] / master_df["nikkei_price"].shift(1)) * 100
master_df["r_kospi"] = np.log(master_df["kospi_price"] / master_df["kospi_price"].shift(1)) * 100
master_df["r_hangseng"] = np.log(master_df["hang_seng_price"] / master_df["hang_seng_price"].shift(1)) * 100
master_df["r_singapore"] = np.log(master_df["singapore_sti_price"] / master_df["singapore_sti_price"].shift(1)) * 100
master_df["r_sp500"] = np.log(master_df["sp500_price"] / master_df["sp500_price"].shift(1)) * 100

# Create analysis dataset and remove missing values
analysis_vars = [
    "month",
    "shanghai_price",
    "nikkei_price",
    "kospi_price",
    "hang_seng_price",
    "singapore_sti_price",
    "sp500_price",
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "r_sp500",
    "DCEF",
    "RIPO",
    "NIPO",
    "NA",
    "TURN",
    "CCI",
    "ISI",
    "StdISI"
]

analysis_df = master_df[analysis_vars].dropna().copy()
analysis_df["month_dt"] = pd.to_datetime(analysis_df["month"])

print(f"Rows before dropping missing values: {len(master_df)}")
print(f"Rows after dropping missing values: {len(analysis_df)}")
print(f"Date range: {analysis_df['month'].min()} to {analysis_df['month'].max()}")

analysis_df.head()
# Out:
# Rows before dropping missing values: 248
# Rows after dropping missing values: 247
# Date range: 2003-02 to 2023-08
#      month  shanghai_price  nikkei_price  kospi_price  hang_seng_price  \
# 1  2003-02         1511.93       8363.04       575.43          9122.66
# 2  2003-03         1510.58       7972.71       535.70          8634.45
# 3  2003-04         1521.44       7831.42       599.35          8717.22
# 4  2003-05         1576.26       8424.51       633.42          9487.38
# 5  2003-06         1486.02       9083.11       669.93          9577.12
#
#    singapore_sti_price  sp500_price  r_shanghai  r_nikkei    r_kospi  ...  \
# 1              1236.36        841.1    0.804188  0.276598  -2.815253  ...
# 2              1235.25        848.2   -0.089330 -4.779754  -7.154328  ...
# 3              1251.60        916.9    0.716357 -1.788061  11.227143  ...
# 4              1324.56        963.6    3.539770  7.300147   5.528797  ...
# 5              1425.24        974.5   -5.895355  7.527133   5.603952  ...
#
#     r_sp500    DCEF    RIPO  NIPO    NA    TURN   CCI    ISI  StdISI  \
# 1 -1.720929 -0.1117  0.7691     3  2.85  0.1928  97.7  25.30   -1.05
# 2  0.840590 -0.0941  0.6831     6  3.26  0.1328  97.8  26.20   -1.27
# 3  7.788196 -0.1399  1.1853     5  5.69  0.1218  97.6  27.69   -1.07
# 4  4.967786 -0.1892  1.0623     2  4.21  0.3197  88.7  24.05   -0.70
# 5  1.124825 -0.1962  0.8507     7  5.35  0.2558  85.7  25.10   -1.11
#
#     month_dt
# 1 2003-02-01
# 2 2003-03-01
# 3 2003-04-01
# 4 2003-05-01
# 5 2003-06-01
#
# [5 rows x 22 columns]

# %% [markdown]
# # 2. Descriptive and Preliminary Analysis
#
# Summarize the data, visualize the main series, examine correlations, and select candidate lag orders.

# %% [markdown]
# ## 2.1. Descriptive Statistics
#
# Summarize the monthly return variables.

# %%
return_vars = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore"
]

summary_returns = pd.DataFrame({
    "Obs": analysis_df[return_vars].count(),
    "Mean": analysis_df[return_vars].mean(),
    "Std. dev.": analysis_df[return_vars].std(ddof=1),
    "Min": analysis_df[return_vars].min(),
    "Max": analysis_df[return_vars].max()
})

summary_returns = summary_returns.reset_index().rename(columns={"index": "Variable"})

summary_returns
# Out:
#       Variable  Obs      Mean  Std. dev.        Min        Max
# 0   r_shanghai  247  0.296538   7.327552 -28.277937  24.252587
# 1     r_nikkei  247  0.552166   5.332271 -27.216232  14.013731
# 2      r_kospi  247  0.592322   5.402741 -26.311175  13.365158
# 3   r_hangseng  247  0.277646   6.403286 -25.445494  23.604853
# 4  r_singapore  247  0.383474   4.829061 -27.364041  19.300233

# %% [markdown]
# ## 2.2. Stationarity Tests
#
# Use Augmented Dickey-Fuller (ADF) tests with zero lags to examine whether the return and sentiment variables used in the VAR models are stationary, consistent with the Stata `dfuller` specification.

# %%
# Augmented Dickey-Fuller stationarity tests with zero lags, matching Stata dfuller.
def adf_test_table(df, variables):
    rows = []

    for variable in variables:
        series = df[variable].replace([np.inf, -np.inf], np.nan).dropna()
        result = adfuller(
            series,
            maxlag=0,
            regression="c",
            autolag=None
        )

        rows.append({
            "Variable": variable,
            "ADF statistic": result[0],
            "p-value": result[1],
            "Lags used": result[2],
            "Observations": result[3],
            "Stationary at 5%": result[1] < 0.05
        })

    return pd.DataFrame(rows)


adf_vars = return_vars + [col for col in ["r_sp500", "ISI", "StdISI"] if col in analysis_df.columns and col not in return_vars]
adf_results = adf_test_table(analysis_df, adf_vars)
display(adf_results.round({"ADF statistic": 4, "p-value": 4}))
# Out:
#       Variable  ADF statistic  p-value  Lags used  Observations  \
# 0   r_shanghai       -13.9735   0.0000          0           246
# 1     r_nikkei       -13.9964   0.0000          0           246
# 2      r_kospi       -16.1475   0.0000          0           246
# 3   r_hangseng       -16.3855   0.0000          0           246
# 4  r_singapore       -14.0112   0.0000          0           246
# 5      r_sp500       -15.2617   0.0000          0           246
# 6          ISI        -5.0020   0.0000          0           246
# 7       StdISI        -4.2221   0.0006          0           246
#
#    Stationary at 5%
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# 5              True
# 6              True
# 7              True

# %% [markdown]
# ## 2.2. EDA: StdISI Time Series
#
# Plot the standardized investor sentiment index over time.

# %%
plt.figure(figsize=(10, 5))
plt.plot(analysis_df["month_dt"], analysis_df["StdISI"], color="dodgerblue", linewidth=1)
plt.xlabel("month")
plt.ylabel("StdISI")
plt.grid(True, linestyle="--", alpha=0.3)
plt.show()

# %% [markdown]
# ## 2.3. EDA: Shanghai Return and StdISI
#
# Compare Shanghai monthly returns with standardized investor sentiment.

# %%
plt.figure(figsize=(10, 5))
plt.plot(analysis_df["month_dt"], analysis_df["r_shanghai"], label="r_shanghai", color="dodgerblue", linewidth=1)
plt.plot(analysis_df["month_dt"], analysis_df["StdISI"], label="StdISI", color="crimson", linewidth=1)
plt.xlabel("month")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.3)
plt.show()

# %% [markdown]
# ## 2.4. EDA: Shanghai Return and ISI
#
# Compare Shanghai monthly returns with the original investor sentiment index.

# %%
plt.figure(figsize=(10, 5))
plt.plot(analysis_df["month_dt"], analysis_df["r_shanghai"], label="r_shanghai", color="dodgerblue", linewidth=1)
plt.plot(analysis_df["month_dt"], analysis_df["ISI"], label="ISI", color="crimson", linewidth=1)
plt.xlabel("month")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.3)
plt.show()

# %% [markdown]
# ## 2.5. EDA: Shanghai Price and ISI
#
# Compare Shanghai index price with the original investor sentiment index.

# %%
plt.figure(figsize=(10, 5))
plt.plot(analysis_df["month_dt"], analysis_df["shanghai_price"], label="Shanghai_Price", color="dodgerblue", linewidth=1)
plt.plot(analysis_df["month_dt"], analysis_df["ISI"], label="ISI", color="crimson", linewidth=1)
plt.xlabel("month")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.3)
plt.show()

# %% [markdown]
# ## 2.6. Correlation Table Function
#
# Define a reusable HTML correlation table with p-values and significance stars.

# %%
def correlation_table_html(df, variables, star_level=0.05):
    corr_display = pd.DataFrame("", index=variables, columns=variables)

    for row_var in variables:
        for col_var in variables:
            row_index = variables.index(row_var)
            col_index = variables.index(col_var)

            # Only show the lower triangle.
            if col_index > row_index:
                continue

            if row_var == col_var:
                corr_display.loc[row_var, col_var] = "1.0000"
            else:
                temp = df[[row_var, col_var]].dropna()
                corr, p_value = pearsonr(temp[row_var], temp[col_var])

                star = "*" if p_value < star_level else ""
                corr_display.loc[row_var, col_var] = (
                    f"{corr:.4f}{star}<br>"
                    f"{p_value:.4f}"
                )

    html = corr_display.to_html(escape=False)
    display(HTML(html))

    return corr_display

# %% [markdown]
# ## 2.7. Correlation: Returns and StdISI
#
# Compute pairwise correlations between market returns and StdISI.

# %%
corr_vars_stdisi = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "r_sp500",
    "StdISI"
]

corr_stdisi_table = correlation_table_html(
    analysis_df,
    corr_vars_stdisi,
    star_level=0.05
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>r_shanghai</th>
#       <th>r_nikkei</th>
#       <th>r_kospi</th>
#       <th>r_hangseng</th>
#       <th>r_singapore</th>
#       <th>r_sp500</th>
#       <th>StdISI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>r_shanghai</th>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_nikkei</th>
#       <td>0.3477*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_kospi</th>
#       <td>0.4113*<br>0.0000</td>
#       <td>0.6068*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_hangseng</th>
#       <td>0.5592*<br>0.0000</td>
#       <td>0.4680*<br>0.0000</td>
#       <td>0.5589*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_singapore</th>
#       <td>0.4491*<br>0.0000</td>
#       <td>0.6292*<br>0.0000</td>
#       <td>0.6957*<br>0.0000</td>
#       <td>0.7031*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_sp500</th>
#       <td>0.3653*<br>0.0000</td>
#       <td>0.6851*<br>0.0000</td>
#       <td>0.6855*<br>0.0000</td>
#       <td>0.5339*<br>0.0000</td>
#       <td>0.6980*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>StdISI</th>
#       <td>0.1079<br>0.0906</td>
#       <td>-0.0214<br>0.7385</td>
#       <td>0.0271<br>0.6714</td>
#       <td>-0.0108<br>0.8659</td>
#       <td>0.0002<br>0.9972</td>
#       <td>0.0120<br>0.8514</td>
#       <td>1.0000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 2.8. Correlation: Returns and ISI
#
# Compute pairwise correlations between market returns and ISI.

# %%
corr_vars_isi = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "r_sp500",
    "ISI"
]

corr_isi_table = correlation_table_html(
    analysis_df,
    corr_vars_isi,
    star_level=0.05
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>r_shanghai</th>
#       <th>r_nikkei</th>
#       <th>r_kospi</th>
#       <th>r_hangseng</th>
#       <th>r_singapore</th>
#       <th>r_sp500</th>
#       <th>ISI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>r_shanghai</th>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_nikkei</th>
#       <td>0.3477*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_kospi</th>
#       <td>0.4113*<br>0.0000</td>
#       <td>0.6068*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_hangseng</th>
#       <td>0.5592*<br>0.0000</td>
#       <td>0.4680*<br>0.0000</td>
#       <td>0.5589*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_singapore</th>
#       <td>0.4491*<br>0.0000</td>
#       <td>0.6292*<br>0.0000</td>
#       <td>0.6957*<br>0.0000</td>
#       <td>0.7031*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_sp500</th>
#       <td>0.3653*<br>0.0000</td>
#       <td>0.6851*<br>0.0000</td>
#       <td>0.6855*<br>0.0000</td>
#       <td>0.5339*<br>0.0000</td>
#       <td>0.6980*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>ISI</th>
#       <td>0.1824*<br>0.0040</td>
#       <td>-0.0436<br>0.4955</td>
#       <td>0.0513<br>0.4222</td>
#       <td>0.0559<br>0.3814</td>
#       <td>0.0113<br>0.8593</td>
#       <td>0.0268<br>0.6753</td>
#       <td>1.0000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 2.9. EDA: Distribution Diagnostics
#
# Report dissertation-ready descriptive statistics for all extended-model variables, including skewness, excess kurtosis and the Jarque–Bera normality test.

# %%
# Distribution diagnostics include the S&P 500 return omitted from the earlier summary table.
eda_vars = ["r_shanghai", "r_nikkei", "r_kospi", "r_hangseng", "r_singapore", "r_sp500", "StdISI"]
eda_labels = {
    "r_shanghai": "Shanghai Composite return", "r_nikkei": "Nikkei 225 return",
    "r_kospi": "KOSPI return", "r_hangseng": "Hang Seng return",
    "r_singapore": "Singapore STI return", "r_sp500": "S&P 500 return",
    "StdISI": "Chinese investor sentiment (StdISI)"
}
eda_rows = []
for variable in eda_vars:
    series = analysis_df[variable].dropna()
    jb = scipy.stats.jarque_bera(series)
    eda_rows.append({
        "Variable": eda_labels[variable], "N": len(series),
        "Mean": series.mean(), "Std. dev.": series.std(ddof=1),
        "Minimum": series.min(), "Maximum": series.max(),
        "Skewness": series.skew(), "Excess kurtosis": series.kurt(),
        "Jarque-Bera": jb.statistic, "JB p-value": jb.pvalue
    })
eda_descriptive_table_extended = pd.DataFrame(eda_rows).set_index("Variable")
display(eda_descriptive_table_extended.round(4))
# Out:
#                                        N    Mean  Std. dev.  Minimum  Maximum  \
# Variable
# Shanghai Composite return            247  0.2965     7.3276 -28.2779  24.2526
# Nikkei 225 return                    247  0.5522     5.3323 -27.2162  14.0137
# KOSPI return                         247  0.5923     5.4027 -26.3112  13.3652
# Hang Seng return                     247  0.2776     6.4033 -25.4455  23.6049
# Singapore STI return                 247  0.3835     4.8291 -27.3640  19.3002
# S&P 500 return                       247  0.6727     4.2761 -18.5619  11.9421
# Chinese investor sentiment (StdISI)  247  0.0050     1.4646  -2.4800   5.9300
#
#                                      Skewness  Excess kurtosis  Jarque-Bera  \
# Variable
# Shanghai Composite return             -0.5576           2.4545      70.9872
# Nikkei 225 return                     -0.8677           2.5493      93.6023
# KOSPI return                          -0.7262           2.5492      84.4225
# Hang Seng return                      -0.3132           2.1365      48.0569
# Singapore STI return                  -1.0150           6.2247     421.7496
# S&P 500 return                        -0.8280           1.9670      65.1585
# Chinese investor sentiment (StdISI)    1.0085           1.7107      69.4473
#
#                                      JB p-value
# Variable
# Shanghai Composite return                   0.0
# Nikkei 225 return                           0.0
# KOSPI return                                0.0
# Hang Seng return                            0.0
# Singapore STI return                        0.0
# S&P 500 return                              0.0
# Chinese investor sentiment (StdISI)         0.0

# %% [markdown]
# ## 2.10. EDA: Correlation Heatmap
#
# Visualise the extended-model correlation matrix with thesis-ready labels.

# %%
corr_matrix = analysis_df[eda_vars].corr()
short_labels = ["Shanghai", "Nikkei 225", "KOSPI", "Hang Seng", "STI", "S&P 500", "StdISI"]
fig, ax = plt.subplots(figsize=(9, 7.5))
image = ax.imshow(corr_matrix, vmin=-1, vmax=1, cmap="RdBu_r")
ax.set_xticks(range(len(short_labels)), short_labels, rotation=40, ha="right")
ax.set_yticks(range(len(short_labels)), short_labels)
for row in range(len(short_labels)):
    for column in range(len(short_labels)):
        value = corr_matrix.iloc[row, column]
        ax.text(column, row, f"{value:.2f}", ha="center", va="center",
                color="white" if abs(value) > 0.55 else "black", fontsize=8.5)
ax.set_title("Correlation Matrix: Extended Model with S&P 500", pad=14)
fig.colorbar(image, ax=ax, label="Pearson correlation coefficient")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 2.11. EDA: Return Dynamics and Distributions
#
# Plot all six monthly return series and use boxplots to identify heavy tails and extreme observations.

# %%
return_plot_vars = eda_vars[:-1]
return_plot_labels = short_labels[:-1]
fig, axes = plt.subplots(3, 2, figsize=(12, 9), sharex=True)
for ax, variable, label in zip(axes.ravel(), return_plot_vars, return_plot_labels):
    ax.plot(analysis_df["month_dt"], analysis_df[variable], linewidth=0.8, label=label)
    ax.axhline(0, color="black", linewidth=0.6)
    ax.set_title(f"{label} Monthly Log Return")
    ax.set_ylabel("Log return (%)")
    ax.legend(frameon=False, loc="upper right")
fig.suptitle("Monthly Stock-Market Returns, February 2003–August 2023", y=1.01)
fig.supxlabel("Month")
fig.tight_layout()
plt.show()

fig, ax = plt.subplots(figsize=(10, 5))
ax.boxplot([analysis_df[v].dropna() for v in return_plot_vars], tick_labels=return_plot_labels, showfliers=True)
ax.set_title("Distribution of Monthly Stock-Market Returns")
ax.set_xlabel("Market")
ax.set_ylabel("Log return (%)")
ax.tick_params(axis="x", rotation=25)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 2.12. VAR Lag Selection: ISI, Max Lag 4
#
# Select lag order for the VAR model using returns and ISI with maximum lag 4.

# %%
# ISI VAR lag-order selection with maximum lag 4.
var_vars_isi = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "r_sp500",
    "ISI"
]

var_data_isi = analysis_df[var_vars_isi].dropna().copy()
var_model_isi = VAR(var_data_isi)

lag_order_isi_4 = var_model_isi.select_order(maxlags=4)
lag_order_isi_4.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## 2.13. VAR Lag Selection: ISI, Max Lag 6
#
# Repeat lag-order selection for the ISI model with maximum lag 6.

# %%
# ISI VAR lag-order selection with maximum lag 6.
var_vars_isi = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "r_sp500",
    "ISI"
]

var_data_isi = analysis_df[var_vars_isi].dropna().copy()
var_model_isi = VAR(var_data_isi)

lag_order_isi_6 = var_model_isi.select_order(maxlags=6)
lag_order_isi_6.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## 2.14. VAR Lag Selection: StdISI, Max Lag 6
#
# Select lag order for the VAR model using returns and StdISI with maximum lag 6.

# %%
# StdISI VAR lag-order selection with maximum lag 6.
var_vars_stdisi = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "r_sp500",
    "StdISI"
]

var_data_stdisi = analysis_df[var_vars_stdisi].dropna().copy()
var_model_stdisi = VAR(var_data_stdisi)

lag_order_stdisi_6 = var_model_stdisi.select_order(maxlags=6)
lag_order_stdisi_6.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# # 3. Alternative Sentiment Measure: Extended StdISI VAR(2)
#
# Estimate the alternative extended VAR(2) specification using StdISI and the S&P 500 return.

# %% [markdown]
# ## 3.1. Alternative Extended VAR(2) Model with StdISI
#
# Estimate the VAR model with two lags using market returns and StdISI.

# %%
# Estimate the VAR(2) model with StdISI.
var_vars_stdisi = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "r_sp500",
    "StdISI"
]

var_data_stdisi = analysis_df[var_vars_stdisi].dropna().copy()
var_model_stdisi = VAR(var_data_stdisi)

# fit(2) includes lags 1 and 2.
var_results_stdisi_lag2 = var_model_stdisi.fit(2)

print(var_results_stdisi_lag2.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 31, Jul, 2026
# Time:                     23:13:30
# --------------------------------------------------------------------
# No. of Equations:         7.00000    BIC:                    17.9114
# Nobs:                     245.000    HQIC:                   17.0151
# Log likelihood:          -4338.81    FPE:                1.34153e+07
# AIC:                      16.4108    Det(Omega_mle):     8.85010e+06
# --------------------------------------------------------------------
# Results for equation r_shanghai
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.363876         0.477731            0.762           0.446
# L1.r_shanghai          0.102867         0.080148            1.283           0.199
# L1.r_nikkei           -0.057032         0.128344           -0.444           0.657
# L1.r_kospi             0.053680         0.135711            0.396           0.692
# L1.r_hangseng         -0.020332         0.116237           -0.175           0.861
# L1.r_singapore         0.058886         0.176458            0.334           0.739
# L1.r_sp500            -0.054936         0.178028           -0.309           0.758
# L1.StdISI             -0.584052         0.748272           -0.781           0.435
# L2.r_shanghai          0.131591         0.089115            1.477           0.140
# L2.r_nikkei           -0.137393         0.130994           -1.049           0.294
# L2.r_kospi             0.217455         0.134466            1.617           0.106
# L2.r_hangseng         -0.034987         0.111988           -0.312           0.755
# L2.r_singapore         0.345910         0.172174            2.009           0.045
# L2.r_sp500            -0.436237         0.178218           -2.448           0.014
# L2.StdISI              0.303067         0.701417            0.432           0.666
# =================================================================================
#
# Results for equation r_nikkei
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0
# r_hangseng       0.547859  0.471808  0.578358    1.000000     0.720621  0.566633  0.014329
# r_singapore      0.414660  0.608282  0.692732    0.720621     1.000000  0.698616  0.030157
# r_sp500          0.345589  0.677355  0.691115    0.566633     0.698616  1.000000  0.010301
# StdISI           0.194448 -0.008458  0.048808    0.014329     0.030157  0.010301  1.000000

# %% [markdown]
# ## 3.2. Full VAR Coefficient Table
#
# Create a complete coefficient table for the VAR(2) model.

# %%
# Complete coefficient table for the VAR(2) model.
params = var_results_stdisi_lag2.params
stderr = var_results_stdisi_lag2.stderr
zvalues = var_results_stdisi_lag2.tvalues
pvalues = var_results_stdisi_lag2.pvalues

z_crit = norm.ppf(0.975)

base_variables = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "r_sp500",
    "StdISI"
]

ordered_parameters = []
for base_var in base_variables:
    for lag_number in range(1, 3):
        ordered_parameters.append(f"L{lag_number}.{base_var}")
ordered_parameters.append("const")

rows = []

for equation in params.columns:
    for variable in ordered_parameters:
        if variable not in params.index:
            continue

        coef = params.loc[variable, equation]
        se = stderr.loc[variable, equation]
        z = zvalues.loc[variable, equation]
        p = pvalues.loc[variable, equation]
        ci_lower = coef - z_crit * se
        ci_upper = coef + z_crit * se

        if variable == "const":
            lag = "const"
            variable_name = "const"
        else:
            lag, variable_name = variable.split(".", 1)

        rows.append({
            "Equation": equation,
            "Variable": variable_name,
            "Lag": lag,
            "Coefficient": coef,
            "Std. err.": se,
            "z": z,
            "P>|z|": p,
            "95% CI lower": ci_lower,
            "95% CI upper": ci_upper
        })

var_stdisi_lag2_full_table = pd.DataFrame(rows)

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

display(var_stdisi_lag2_full_table)
# Out:
#         Equation     Variable    Lag  Coefficient  Std. err.         z  \
# 0     r_shanghai   r_shanghai     L1     0.102867   0.080148  1.283457
# 1     r_shanghai   r_shanghai     L2     0.131591   0.089115  1.476644
# 2     r_shanghai     r_nikkei     L1    -0.057032   0.128344 -0.444366
# 3     r_shanghai     r_nikkei     L2    -0.137393   0.130994 -1.048849
# 4     r_shanghai      r_kospi     L1     0.053680   0.135711  0.395544
# 5     r_shanghai      r_kospi     L2     0.217455   0.134466  1.617176
# 6     r_shanghai   r_hangseng     L1    -0.020332   0.116237 -0.174914
# 7     r_shanghai   r_hangseng     L2    -0.034987   0.111988 -0.312416
# 8     r_shanghai  r_singapore     L1     0.058886   0.176458  0.333713
# 9     r_shanghai  r_singapore     L2     0.345910   0.172174  2.009076
# 10    r_shanghai      r_sp500     L1    -0.054936   0.178028 -0.308582
# 11    r_shanghai      r_sp500     L2    -0.436237   0.178218 -2.447769
# 12    r_shanghai       StdISI     L1    -0.584052   0.748272 -0.780535
# 13    r_shanghai       StdISI     L2     0.303067   0.701417  0.432079
# 14    r_shanghai        const  const     0.363876   0.477731  0.761675
# 15      r_nikkei   r_shanghai     L1     0.070402   0.058318  1.207209
# 16      r_nikkei   r_shanghai     L2     0.074743   0.064843  1.152680
# 17      r_nikkei     r_nikkei     L1     0.046295   0.093387  0.495729
# 18      r_nikkei     r_nikkei     L2    -0.058532   0.095315 -0.614089
# 19      r_nikkei      r_kospi     L1    -0.028810   0.098747 -0.291760
# 20      r_nikkei      r_kospi     L2     0.156979   0.097841  1.604417
# 21      r_nikkei   r_hangseng     L1     0.070609   0.084578  0.834847
# 22      r_nikkei   r_hangseng     L2     0.023396   0.081486  0.287112
# 23      r_nikkei  r_singapore     L1    -0.025379   0.128396 -0.197660
# 24      r_nikkei  r_singapore     L2     0.077177   0.125279  0.616042
# 25      r_nikkei      r_sp500     L1     0.010147   0.129539  0.078334
# 26      r_nikkei      r_sp500     L2    -0.252169   0.129677 -1.944595
# 27      r_nikkei       StdISI     L1    -0.181997   0.544465 -0.334267
# 28      r_nikkei       StdISI     L2    -0.245558   0.510371 -0.481136
# 29      r_nikkei        const  const     0.576665   0.347611  1.658937
# 30       r_kospi   r_shanghai     L1    -0.052495   0.058426 -0.898481
# 31       r_kospi   r_shanghai     L2     0.054636   0.064962  0.841041
# 32       r_kospi     r_nikkei     L1     0.000986   0.093560  0.010536
# 33       r_kospi     r_nikkei     L2    -0.115380   0.095491 -1.208282
# 34       r_kospi      r_kospi     L1    -0.091658   0.098929 -0.926499
# 35       r_kospi      r_kospi     L2     0.040095   0.098022  0.409043
# 36       r_kospi   r_hangseng     L1     0.029840   0.084734  0.352162
# 37       r_kospi   r_hangseng     L2     0.136434   0.081636  1.671243
# 38       r_kospi  r_singapore     L1     0.113705   0.128633  0.883949
# 39       r_kospi  r_singapore     L2     0.154344   0.125510  1.229736
# 40       r_kospi      r_sp500     L1    -0.008711   0.129778 -0.067126
# 41       r_kospi      r_sp500     L2    -0.303187   0.129916 -2.333712
# 42       r_kospi       StdISI     L1     0.574808   0.545470  1.053785
# 43       r_kospi       StdISI     L2    -0.692380   0.511313 -1.354121
# 44       r_kospi        const  const     0.787931   0.348253  2.262527
# 45    r_hangseng   r_shanghai     L1    -0.044472   0.068943 -0.645063
# 46    r_hangseng   r_shanghai     L2     0.194336   0.076656  2.535182
# 47    r_hangseng     r_nikkei     L1    -0.146396   0.110400 -1.326047
# 48    r_hangseng     r_nikkei     L2    -0.222663   0.112680 -1.976071
# 49    r_hangseng      r_kospi     L1     0.151753   0.116737  1.299954
# 50    r_hangseng      r_kospi     L2     0.335647   0.115666  2.901862
# 51    r_hangseng   r_hangseng     L1    -0.093667   0.099986 -0.936807
# 52    r_hangseng   r_hangseng     L2    -0.157643   0.096331 -1.636474
# 53    r_hangseng  r_singapore     L1     0.053479   0.151787  0.352329
# 54    r_hangseng  r_singapore     L2     0.200654   0.148102  1.354839
# 55    r_hangseng      r_sp500     L1     0.049047   0.153138  0.320280
# 56    r_hangseng      r_sp500     L2    -0.146018   0.153301 -0.952490
# 57    r_hangseng       StdISI     L1    -0.686812   0.643655 -1.067050
# 58    r_hangseng       StdISI     L2     0.264216   0.603351  0.437915
# 59    r_hangseng        const  const     0.221178   0.410938  0.538227
# 60   r_singapore   r_shanghai     L1     0.004171   0.052091  0.080078
# 61   r_singapore   r_shanghai     L2     0.103035   0.057918  1.778972
# 62   r_singapore     r_nikkei     L1     0.106551   0.083414  1.277372
# 63   r_singapore     r_nikkei     L2    -0.210663   0.085136 -2.474420
# 64   r_singapore      r_kospi     L1    -0.023620   0.088202 -0.267797
# 65   r_singapore      r_kospi     L2     0.126439   0.087393  1.446787
# 66   r_singapore   r_hangseng     L1     0.035246   0.075546  0.466552
# 67   r_singapore   r_hangseng     L2    -0.008381   0.072784 -0.115147
# 68   r_singapore  r_singapore     L1     0.046589   0.114685  0.406239
# 69   r_singapore  r_singapore     L2     0.194427   0.111900  1.737501
# 70   r_singapore      r_sp500     L1    -0.049804   0.115705 -0.430437
# 71   r_singapore      r_sp500     L2    -0.176075   0.115829 -1.520136
# 72   r_singapore       StdISI     L1    -0.037118   0.486321 -0.076324
# 73   r_singapore       StdISI     L2    -0.290549   0.455869 -0.637352
# 74   r_singapore        const  const     0.409149   0.310490  1.317753
# 75       r_sp500   r_shanghai     L1     0.047722   0.047674  1.001025
# 76       r_sp500   r_shanghai     L2     0.037476   0.053007  0.706995
# 77       r_sp500     r_nikkei     L1     0.045532   0.076341  0.596429
# 78       r_sp500     r_nikkei     L2    -0.042724   0.077917 -0.548326
# 79       r_sp500      r_kospi     L1    -0.065104   0.080723 -0.806507
# 80       r_sp500      r_kospi     L2     0.057593   0.079983  0.720075
# 81       r_sp500   r_hangseng     L1     0.040870   0.069140  0.591120
# 82       r_sp500   r_hangseng     L2     0.069034   0.066612  1.036353
# 83       r_sp500  r_singapore     L1     0.045764   0.104960  0.436011
# 84       r_sp500  r_singapore     L2    -0.000123   0.102412 -0.001201
# 85       r_sp500      r_sp500     L1    -0.065703   0.105894 -0.620459
# 86       r_sp500      r_sp500     L2    -0.155435   0.106007 -1.466267
# 87       r_sp500       StdISI     L1    -0.169017   0.445084 -0.379742
# 88       r_sp500       StdISI     L2     0.026324   0.417214  0.063095
# 89       r_sp500        const  const     0.758786   0.284162  2.670259
# 90        StdISI   r_shanghai     L1     0.061861   0.006947  8.905003
# 91        StdISI   r_shanghai     L2     0.002691   0.007724  0.348427
# 92        StdISI     r_nikkei     L1    -0.019979   0.011124 -1.796055
# 93        StdISI     r_nikkei     L2    -0.016219   0.011354 -1.428519
# 94        StdISI      r_kospi     L1    -0.013060   0.011763 -1.110342
# 95        StdISI      r_kospi     L2     0.011327   0.011655  0.971853
# 96        StdISI   r_hangseng     L1    -0.008940   0.010075 -0.887373
# 97        StdISI   r_hangseng     L2    -0.003836   0.009706 -0.395183
# 98        StdISI  r_singapore     L1    -0.004479   0.015294 -0.292839
# 99        StdISI  r_singapore     L2     0.008014   0.014923  0.537054
# 100       StdISI      r_sp500     L1     0.020635   0.015430  1.337323
# 101       StdISI      r_sp500     L2    -0.000773   0.015447 -0.050050
# 102       StdISI       StdISI     L1     0.610318   0.064855  9.410445
# 103       StdISI       StdISI     L2     0.243706   0.060794  4.008701
# 104       StdISI        const  const    -0.000812   0.041407 -0.019615
#
#             P>|z|  95% CI lower  95% CI upper
# 0    1.993319e-01     -0.054221      0.259955
# 1    1.397710e-01     -0.043071      0.306253
# 2    6.567783e-01     -0.308582      0.194519
# 3    2.942474e-01     -0.394137      0.119351
# 70   6.668776e-01     -0.276582      0.176974
# 71   1.284767e-01     -0.403096      0.050945
# 72   9.391616e-01     -0.990290      0.916055
# 73   5.238958e-01     -1.184036      0.602938
# 74   1.875864e-01     -0.199400      1.017697
# 75   3.168146e-01     -0.045716      0.141161
# 76   4.795697e-01     -0.066416      0.141368
# 77   5.508889e-01     -0.104094      0.195159
# 78   5.834682e-01     -0.195439      0.109991
# 79   4.199506e-01     -0.223318      0.093111
# 80   4.714787e-01     -0.099170      0.214357
# 81   5.544398e-01     -0.094641      0.176381
# 82   3.000374e-01     -0.061524      0.199592
# 83   6.628289e-01     -0.159954      0.251482
# 84   9.990417e-01     -0.200846      0.200600
# 85   5.349558e-01     -0.273252      0.141846
# 86   1.425757e-01     -0.363205      0.052335
# 87   7.041367e-01     -1.041367      0.703332
# 88   9.496905e-01     -0.791400      0.844049
# 89   7.579280e-03      0.201839      1.315733
# 90   5.338458e-19      0.048245      0.075476
# 91   7.275196e-01     -0.012447      0.017830
# 92   7.248570e-02     -0.041782      0.001823
# 93   1.531425e-01     -0.038472      0.006034
# 94   2.668516e-01     -0.036115      0.009994
# 95   3.311239e-01     -0.011516      0.034169
# 96   3.748783e-01     -0.028686      0.010806
# 97   6.927079e-01     -0.022860      0.015188
# 98   7.696450e-01     -0.034455      0.025497
# 99   5.912301e-01     -0.021234      0.037263
# 100  1.811171e-01     -0.009608      0.050878
# 101  9.600822e-01     -0.031048      0.029502
# 102  4.940390e-21      0.483204      0.737432
# 103  6.105374e-05      0.124551      0.362861
# 104  9.843507e-01     -0.081968      0.080343

# %% [markdown]
# ## 3.3. Key VAR(2) Relationships
#
# Display the two directions of interest separately. A p-value below 0.05 indicates statistical significance.

# %%
# Direction 1: Does investor sentiment predict subsequent market returns?
sentiment_to_returns = var_stdisi_lag2_full_table.loc[
    (var_stdisi_lag2_full_table["Variable"] == "StdISI")
    & (var_stdisi_lag2_full_table["Equation"] != "StdISI"),
    ["Equation", "Coefficient", "P>|z|", "95% CI lower", "95% CI upper"]
].copy()
sentiment_to_returns["Significant at 5%"] = sentiment_to_returns["P>|z|"] < 0.05

print("Direction 1: StdISI -> market returns")
display(sentiment_to_returns)

# Direction 2: Do market returns predict subsequent investor sentiment?
returns_to_sentiment = var_stdisi_lag2_full_table.loc[
    (var_stdisi_lag2_full_table["Equation"] == "StdISI")
    & (~var_stdisi_lag2_full_table["Variable"].isin(["StdISI", "const"])),
    ["Variable", "Coefficient", "P>|z|", "95% CI lower", "95% CI upper"]
].copy()
returns_to_sentiment["Significant at 5%"] = returns_to_sentiment["P>|z|"] < 0.05

print("Direction 2: Market returns -> StdISI")
display(returns_to_sentiment)
# Out:
# Direction 1: StdISI -> market returns
#        Equation  Coefficient     P>|z|  95% CI lower  95% CI upper  \
# 12   r_shanghai    -0.584052  0.435076     -2.050638      0.882533
# 13   r_shanghai     0.303067  0.665684     -1.071684      1.677818
# 27     r_nikkei    -0.181997  0.738178     -1.249128      0.885134
# 28     r_nikkei    -0.245558  0.630420     -1.245868      0.754751
# 42      r_kospi     0.574808  0.291981     -0.494293      1.643909
# 43      r_kospi    -0.692380  0.175698     -1.694536      0.309776
# 57   r_hangseng    -0.686812  0.285949     -1.948352      0.574728
# 58   r_hangseng     0.264216  0.661448     -0.918329      1.446761
# 72  r_singapore    -0.037118  0.939162     -0.990290      0.916055
# 73  r_singapore    -0.290549  0.523896     -1.184036      0.602938
# 87      r_sp500    -0.169017  0.704137     -1.041367      0.703332
# 88      r_sp500     0.026324  0.949691     -0.791400      0.844049
#
#     Significant at 5%
# 12              False
# 13              False
# 27              False
# 28              False
# 42              False
# 43              False
# 57              False
# 58              False
# 72              False
# 73              False
# 87              False
# 88              False
# Direction 2: Market returns -> StdISI
#         Variable  Coefficient         P>|z|  95% CI lower  95% CI upper  \
# 90    r_shanghai     0.061861  5.338458e-19      0.048245      0.075476
# 91    r_shanghai     0.002691  7.275196e-01     -0.012447      0.017830
# 92      r_nikkei    -0.019979  7.248570e-02     -0.041782      0.001823
# 93      r_nikkei    -0.016219  1.531425e-01     -0.038472      0.006034
# 94       r_kospi    -0.013060  2.668516e-01     -0.036115      0.009994
# 95       r_kospi     0.011327  3.311239e-01     -0.011516      0.034169
# 96    r_hangseng    -0.008940  3.748783e-01     -0.028686      0.010806
# 97    r_hangseng    -0.003836  6.927079e-01     -0.022860      0.015188
# 98   r_singapore    -0.004479  7.696450e-01     -0.034455      0.025497
# 99   r_singapore     0.008014  5.912301e-01     -0.021234      0.037263
# 100      r_sp500     0.020635  1.811171e-01     -0.009608      0.050878
# 101      r_sp500    -0.000773  9.600822e-01     -0.031048      0.029502
#
#      Significant at 5%
# 90                True
# 91               False
# 92               False
# 93               False
# 94               False
# 95               False
# 96               False
# 97               False
# 98               False
# 99               False
# 100              False
# 101              False

# %% [markdown]
# ## 3.4. VAR Stability Test
#
# Check whether the estimated VAR model satisfies the stability condition.

# %%
# Stability test using companion-matrix eigenvalues.
# The VAR is stable when all eigenvalue moduli are less than 1.
eigenvalues = 1 / var_results_stdisi_lag2.roots

stability_table = pd.DataFrame({
    "Eigenvalue": eigenvalues,
    "Modulus": np.abs(eigenvalues)
})

stability_table = stability_table.sort_values(
    by="Modulus",
    ascending=False
).reset_index(drop=True)

display(stability_table)

if np.all(stability_table["Modulus"] < 1):
    print("All eigenvalue moduli are less than 1.")
    print("VAR satisfies stability condition.")
else:
    print("At least one eigenvalue modulus is greater than or equal to 1.")
    print("VAR does not satisfy stability condition.")
# Out:
#             Eigenvalue   Modulus
# 0   0.881455+0.000000j  0.881455
# 1  -0.109321-0.561954j  0.572488
# 2  -0.109321+0.561954j  0.572488
# 3   0.461261+0.000000j  0.461261
# 4  -0.435087-0.048701j  0.437804
# 5  -0.435087+0.048701j  0.437804
# 6   0.366820+0.000000j  0.366820
# 7   0.062630+0.287759j  0.294496
# 8   0.062630-0.287759j  0.294496
# 9  -0.290100-0.000000j  0.290100
# 10 -0.103090+0.233284j  0.255047
# 11 -0.103090-0.233284j  0.255047
# 12  0.177818+0.000000j  0.177818
# 13  0.127526+0.000000j  0.127526
# All eigenvalue moduli are less than 1.
# VAR satisfies stability condition.

# %% [markdown]
# ## 3.5. Granger Causality Tests
#
# Run Wald tests for Granger causality among the VAR variables.

# %%
# Granger causality Wald tests using statsmodels.
var_names = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "r_sp500",
    "StdISI"
]

granger_rows = []

for equation in var_names:
    excluded_vars = [var for var in var_names if var != equation]

    # Test each excluded variable one by one.
    for excluded in excluded_vars:
        test_result = var_results_stdisi_lag2.test_causality(
            caused=equation,
            causing=excluded,
            kind="wald"
        )

        granger_rows.append({
            "Equation": equation,
            "Excluded": excluded,
            "chi2": test_result.test_statistic,
            "df": test_result.df,
            "Prob > chi2": test_result.pvalue
        })

    # Test all other variables jointly.
    test_all = var_results_stdisi_lag2.test_causality(
        caused=equation,
        causing=excluded_vars,
        kind="wald"
    )

    granger_rows.append({
        "Equation": equation,
        "Excluded": "ALL",
        "chi2": test_all.test_statistic,
        "df": test_all.df,
        "Prob > chi2": test_all.pvalue
    })

granger_table = pd.DataFrame(granger_rows)

granger_table_formatted = granger_table.copy()
granger_table_formatted["chi2"] = granger_table_formatted["chi2"].map(lambda x: f"{x:.4f}")
granger_table_formatted["Prob > chi2"] = granger_table_formatted["Prob > chi2"].map(lambda x: f"{x:.3f}")

display(granger_table_formatted)
# Out:
#        Equation     Excluded     chi2  df Prob > chi2
# 0    r_shanghai     r_nikkei   1.2993   2       0.522
# 1    r_shanghai      r_kospi   2.6974   2       0.260
# 2    r_shanghai   r_hangseng   0.1183   2       0.943
# 3    r_shanghai  r_singapore   4.1169   2       0.128
# 4    r_shanghai      r_sp500   6.0160   2       0.049
# 5    r_shanghai       StdISI   0.9333   2       0.627
# 6    r_shanghai          ALL  13.9454  12       0.304
# 7      r_nikkei   r_shanghai   2.8531   2       0.240
# 8      r_nikkei      r_kospi   2.7353   2       0.255
# 9      r_nikkei   r_hangseng   0.7384   2       0.691
# 10     r_nikkei  r_singapore   0.4249   2       0.809
# 11     r_nikkei      r_sp500   3.8215   2       0.148
# 12     r_nikkei       StdISI   2.9841   2       0.225
# 13     r_nikkei          ALL  16.3983  12       0.174
# 14      r_kospi   r_shanghai   1.4799   2       0.477
# 15      r_kospi     r_nikkei   1.4600   2       0.482
# 16      r_kospi   r_hangseng   2.8268   2       0.243
# 17      r_kospi  r_singapore   2.2408   2       0.326
# 18      r_kospi      r_sp500   5.4524   2       0.065
# 19      r_kospi       StdISI   1.9392   2       0.379
# 20      r_kospi          ALL  22.9667  12       0.028
# 21   r_hangseng   r_shanghai   6.7700   2       0.034
# 22   r_hangseng     r_nikkei   5.6731   2       0.059
# 23   r_hangseng      r_kospi   9.6434   2       0.008
# 24   r_hangseng  r_singapore   1.9371   2       0.380
# 25   r_hangseng      r_sp500   1.0520   2       0.591
# 26   r_hangseng       StdISI   2.3728   2       0.305
# 27   r_hangseng          ALL  25.5548  12       0.012
# 28  r_singapore   r_shanghai   3.1796   2       0.204
# 29  r_singapore     r_nikkei   7.7426   2       0.021
# 30  r_singapore      r_kospi   2.2277   2       0.328
# 31  r_singapore   r_hangseng   0.2443   2       0.885
# 32  r_singapore      r_sp500   2.4239   2       0.298
# 33  r_singapore       StdISI   2.3649   2       0.307
# 34  r_singapore          ALL  21.8047  12       0.040
# 35      r_sp500   r_shanghai   1.5361   2       0.464
# 36      r_sp500     r_nikkei   0.6552   2       0.721
# 37      r_sp500      r_kospi   1.2535   2       0.534
# 38      r_sp500   r_hangseng   1.3127   2       0.519
# 39      r_sp500  r_singapore   0.1903   2       0.909
# 40      r_sp500       StdISI   0.5011   2       0.778
# 41      r_sp500          ALL   9.7830  12       0.635
# 42       StdISI   r_shanghai  79.6107   2       0.000
# 43       StdISI     r_nikkei   5.2761   2       0.071
# 44       StdISI      r_kospi   2.3344   2       0.311
# 45       StdISI   r_hangseng   0.8815   2       0.644
# 46       StdISI  r_singapore   0.3823   2       0.826
# 47       StdISI      r_sp500   1.8063   2       0.405
# 48       StdISI          ALL  98.0786  12       0.000

# %% [markdown]
# # 4. Lag-Length Robustness Check: Extended StdISI VAR(4)
#
# Assess the lag-length sensitivity of the alternative extended StdISI specification using four lags.

# %% [markdown]
# ## 4.1. VAR(4) Model with StdISI
#
# Estimate the VAR model with four lags using market returns and StdISI.

# %%
# Estimate the VAR(4) model with StdISI.
var_vars_stdisi = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "r_sp500",
    "StdISI"
]

var_data_stdisi = analysis_df[var_vars_stdisi].dropna().copy()
var_model_stdisi = VAR(var_data_stdisi)

# fit(4) includes lags 1 through 4.
var_results_stdisi_lag4 = var_model_stdisi.fit(4)

print(var_results_stdisi_lag4.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 31, Jul, 2026
# Time:                     23:13:31
# --------------------------------------------------------------------
# No. of Equations:         7.00000    BIC:                    19.3800
# Nobs:                     243.000    HQIC:                   17.6373
# Log likelihood:          -4210.74    FPE:                1.42171e+07
# AIC:                      16.4620    Det(Omega_mle):     6.45762e+06
# --------------------------------------------------------------------
# Results for equation r_shanghai
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.257748         0.484030            0.533           0.594
# L1.r_shanghai          0.086242         0.080234            1.075           0.282
# L1.r_nikkei           -0.105128         0.129446           -0.812           0.417
# L1.r_kospi             0.075436         0.141891            0.532           0.595
# L1.r_hangseng         -0.009604         0.121432           -0.079           0.937
# L1.r_singapore         0.024102         0.178141            0.135           0.892
# L1.r_sp500             0.003156         0.185124            0.017           0.986
# L1.StdISI             -0.761419         0.789648           -0.964           0.335
# L2.r_shanghai          0.158075         0.095495            1.655           0.098
# L2.r_nikkei           -0.141110         0.131971           -1.069           0.285
# L2.r_kospi             0.268827         0.138929            1.935           0.053
# L2.r_hangseng         -0.088924         0.120872           -0.736           0.462
# L2.r_singapore         0.340598         0.176570            1.929           0.054
# L2.r_sp500            -0.423583         0.179680           -2.357           0.018
# L2.StdISI              0.230234         0.889707            0.259           0.796
# L3.r_shanghai          0.062206         0.094219            0.660           0.509
# L3.r_nikkei           -0.084775         0.133341           -0.636           0.525
# L3.r_kospi             0.357362         0.139431            2.563           0.010
# L3.r_hangseng         -0.067604         0.118433           -0.571           0.568
# L3.r_singapore        -0.191913         0.177147           -1.083           0.279
# L3.r_sp500            -0.093151         0.180698           -0.516           0.606
# L3.StdISI             -0.990287         0.894306           -1.107           0.268
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -0.024683         0.042003           -0.588           0.557
# L1.r_shanghai          0.064783         0.006963            9.305           0.000
# L1.r_nikkei           -0.018727         0.011233           -1.667           0.095
# L1.r_kospi             0.002283         0.012313            0.185           0.853
# L1.r_hangseng         -0.015582         0.010538           -1.479           0.139
# L1.r_singapore        -0.002768         0.015459           -0.179           0.858
# L1.r_sp500             0.010127         0.016065            0.630           0.528
# L1.StdISI              0.530074         0.068524            7.736           0.000
# L2.r_shanghai          0.013920         0.008287            1.680           0.093
# L2.r_nikkei           -0.014794         0.011452           -1.292           0.196
# L2.r_kospi             0.013371         0.012056            1.109           0.267
# L2.r_hangseng         -0.011828         0.010489           -1.128           0.259
# L2.r_singapore         0.008671         0.015322            0.566           0.571
# L2.r_sp500             0.001798         0.015592            0.115           0.908
# L2.StdISI              0.114629         0.077207            1.485           0.138
# L3.r_shanghai          0.010484         0.008176            1.282           0.200
# L3.r_nikkei            0.006482         0.011571            0.560           0.575
# L3.r_kospi             0.008411         0.012100            0.695           0.487
# L3.r_hangseng         -0.023198         0.010277           -2.257           0.024
# L3.r_singapore        -0.002020         0.015373           -0.131           0.895
# L3.r_sp500             0.003613         0.015681            0.230           0.818
# L3.StdISI              0.110953         0.077606            1.430           0.153
# L4.r_shanghai          0.001747         0.007782            0.224           0.822
# L4.r_nikkei           -0.004854         0.011639           -0.417           0.677
# L4.r_kospi            -0.020923         0.012139           -1.724           0.085
# L4.r_hangseng         -0.006771         0.010116           -0.669           0.503
# L4.r_singapore         0.017412         0.015199            1.146           0.252
# L4.r_sp500             0.032541         0.015573            2.090           0.037
# L4.StdISI              0.103479         0.064371            1.608           0.108
# =================================================================================
#
# Correlation matrix of residuals
#                r_shanghai  r_nikkei   r_kospi  r_hangseng  r_singapore   r_sp500    StdISI
# r_shanghai       1.000000  0.255463  0.365851    0.558324     0.396794  0.323189  0.181955
# r_nikkei         0.255463  1.000000  0.591338    0.460981     0.606872  0.679265 -0.037974
# r_kospi          0.365851  0.591338  1.000000    0.568213     0.695695  0.685776  0.033640
# r_hangseng       0.558324  0.460981  0.568213    1.000000     0.685150  0.544348 -0.007227
# r_singapore      0.396794  0.606872  0.695695    0.685150     1.000000  0.693200 -0.007885
# r_sp500          0.323189  0.679265  0.685776    0.544348     0.693200  1.000000 -0.058569
# StdISI           0.181955 -0.037974  0.033640   -0.007227    -0.007885 -0.058569  1.000000

# %% [markdown]
# ## 4.2. Full VAR(4) Coefficient Table
#
# Create a complete coefficient table for the VAR(4) model.

# %%
# Complete coefficient table for the VAR(4) model.
params = var_results_stdisi_lag4.params
stderr = var_results_stdisi_lag4.stderr
zvalues = var_results_stdisi_lag4.tvalues
pvalues = var_results_stdisi_lag4.pvalues

z_crit = norm.ppf(0.975)

base_variables = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "r_sp500",
    "StdISI"
]

ordered_parameters = []
for base_var in base_variables:
    for lag_number in range(1, 5):
        ordered_parameters.append(f"L{lag_number}.{base_var}")
ordered_parameters.append("const")

rows = []

for equation in params.columns:
    for variable in ordered_parameters:
        if variable not in params.index:
            continue

        coef = params.loc[variable, equation]
        se = stderr.loc[variable, equation]
        z = zvalues.loc[variable, equation]
        p = pvalues.loc[variable, equation]
        ci_lower = coef - z_crit * se
        ci_upper = coef + z_crit * se

        if variable == "const":
            lag = "const"
            variable_name = "const"
        else:
            lag, variable_name = variable.split(".", 1)

        rows.append({
            "Equation": equation,
            "Variable": variable_name,
            "Lag": lag,
            "Coefficient": coef,
            "Std. err.": se,
            "z": z,
            "P>|z|": p,
            "95% CI lower": ci_lower,
            "95% CI upper": ci_upper
        })

var_stdisi_lag4_full_table = pd.DataFrame(rows)

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

display(var_stdisi_lag4_full_table)
# Out:
#         Equation     Variable    Lag  Coefficient  Std. err.         z  \
# 0     r_shanghai   r_shanghai     L1     0.086242   0.080234  1.074882
# 1     r_shanghai   r_shanghai     L2     0.158075   0.095495  1.655321
# 2     r_shanghai   r_shanghai     L3     0.062206   0.094219  0.660223
# 3     r_shanghai   r_shanghai     L4     0.359563   0.089675  4.009621
# 4     r_shanghai     r_nikkei     L1    -0.105128   0.129446 -0.812136
# 5     r_shanghai     r_nikkei     L2    -0.141110   0.131971 -1.069251
# 6     r_shanghai     r_nikkei     L3    -0.084775   0.133341 -0.635776
# 7     r_shanghai     r_nikkei     L4     0.023417   0.134127  0.174587
# 8     r_shanghai      r_kospi     L1     0.075436   0.141891  0.531647
# 9     r_shanghai      r_kospi     L2     0.268827   0.138929  1.934996
# 10    r_shanghai      r_kospi     L3     0.357362   0.139431  2.562991
# 11    r_shanghai      r_kospi     L4    -0.219378   0.139883 -1.568291
# 12    r_shanghai   r_hangseng     L1    -0.009604   0.121432 -0.079093
# 13    r_shanghai   r_hangseng     L2    -0.088924   0.120872 -0.735688
# 14    r_shanghai   r_hangseng     L3    -0.067604   0.118433 -0.570820
# 15    r_shanghai   r_hangseng     L4    -0.108448   0.116573 -0.930305
# 16    r_shanghai  r_singapore     L1     0.024102   0.178141  0.135298
# 17    r_shanghai  r_singapore     L2     0.340598   0.176570  1.928967
# 18    r_shanghai  r_singapore     L3    -0.191913   0.177147 -1.083355
# 19    r_shanghai  r_singapore     L4    -0.163289   0.175147 -0.932295
# 20    r_shanghai      r_sp500     L1     0.003156   0.185124  0.017047
# 21    r_shanghai      r_sp500     L2    -0.423583   0.179680 -2.357428
# 22    r_shanghai      r_sp500     L3    -0.093151   0.180698 -0.515505
# 23    r_shanghai      r_sp500     L4     0.192266   0.179455  1.071386
# 24    r_shanghai       StdISI     L1    -0.761419   0.789648 -0.964251
# 25    r_shanghai       StdISI     L2     0.230234   0.889707  0.258775
# 26    r_shanghai       StdISI     L3    -0.990287   0.894306 -1.107326
# 27    r_shanghai       StdISI     L4     0.714244   0.741789  0.962867
# 28    r_shanghai        const  const     0.257748   0.484030  0.532505
# 29      r_nikkei   r_shanghai     L1     0.050566   0.058172  0.869243
# 30      r_nikkei   r_shanghai     L2     0.066860   0.069237  0.965672
# 31      r_nikkei   r_shanghai     L3     0.065170   0.068312  0.954017
# 32      r_nikkei   r_shanghai     L4     0.187106   0.065017  2.877795
# 33      r_nikkei     r_nikkei     L1     0.024417   0.093852  0.260168
# 34      r_nikkei     r_nikkei     L2    -0.071421   0.095683 -0.746441
# 35      r_nikkei     r_nikkei     L3     0.038647   0.096676  0.399762
# 36      r_nikkei     r_nikkei     L4    -0.138485   0.097246 -1.424069
# 37      r_nikkei      r_kospi     L1    -0.060102   0.102875 -0.584221
# 38      r_nikkei      r_kospi     L2     0.250616   0.100727  2.488064
# 39      r_nikkei      r_kospi     L3     0.239888   0.101092  2.372965
# 40      r_nikkei      r_kospi     L4     0.078479   0.101420  0.773805
# 41      r_nikkei   r_hangseng     L1     0.057264   0.088042  0.650418
# 42      r_nikkei   r_hangseng     L2    -0.020327   0.087636 -0.231949
# 43      r_nikkei   r_hangseng     L3    -0.148673   0.085868 -1.731425
# 44      r_nikkei   r_hangseng     L4    -0.020224   0.084519 -0.239284
# 45      r_nikkei  r_singapore     L1    -0.008541   0.129158 -0.066127
# 46      r_nikkei  r_singapore     L2     0.037991   0.128018  0.296760
# 47      r_nikkei  r_singapore     L3    -0.039706   0.128437 -0.309150
# 48      r_nikkei  r_singapore     L4    -0.253020   0.126987 -1.992490
# 49      r_nikkei      r_sp500     L1     0.057505   0.134220  0.428441
# 50      r_nikkei      r_sp500     L2    -0.256131   0.130273 -1.966100
# 51      r_nikkei      r_sp500     L3    -0.068993   0.131011 -0.526616
# 52      r_nikkei      r_sp500     L4     0.252916   0.130110  1.943861
# 53      r_nikkei       StdISI     L1    -0.098141   0.572518 -0.171420
# 54      r_nikkei       StdISI     L2    -0.028305   0.645064 -0.043879
# 55      r_nikkei       StdISI     L3    -1.495568   0.648398 -2.306559
# 56      r_nikkei       StdISI     L4     0.838855   0.537819  1.559737
# 57      r_nikkei        const  const     0.366791   0.350936  1.045178
# 58       r_kospi   r_shanghai     L1    -0.066809   0.059151 -1.129453
# 59       r_kospi   r_shanghai     L2     0.053732   0.070402  0.763209
# 60       r_kospi   r_shanghai     L3     0.086614   0.069462  1.246929
# 61       r_kospi   r_shanghai     L4     0.113517   0.066112  1.717048
# 62       r_kospi     r_nikkei     L1    -0.005822   0.095433 -0.061003
# 63       r_kospi     r_nikkei     L2    -0.140083   0.097294 -1.439792
# 64       r_kospi     r_nikkei     L3    -0.080094   0.098304 -0.814757
# 65       r_kospi     r_nikkei     L4    -0.038492   0.098884 -0.389267
# 66       r_kospi      r_kospi     L1    -0.063210   0.104607 -0.604258
# 67       r_kospi      r_kospi     L2     0.139047   0.102424  1.357573
# 68       r_kospi      r_kospi     L3     0.297401   0.102794  2.893173
# 69       r_kospi      r_kospi     L4     0.072727   0.103127  0.705221
# 70       r_kospi   r_hangseng     L1     0.001797   0.089524  0.020078
# 71       r_kospi   r_hangseng     L2     0.069961   0.089111  0.785102
# 72       r_kospi   r_hangseng     L3    -0.163911   0.087314 -1.877273
# 73       r_kospi   r_hangseng     L4    -0.105287   0.085942 -1.225095
# 74       r_kospi  r_singapore     L1     0.093295   0.131333  0.710375
# 75       r_kospi  r_singapore     L2     0.163336   0.130174  1.254749
# 76       r_kospi  r_singapore     L3    -0.045194   0.130600 -0.346051
# 77       r_kospi  r_singapore     L4    -0.074919   0.129125 -0.580209
# 78       r_kospi      r_sp500     L1    -0.017564   0.136480 -0.128692
# 79       r_kospi      r_sp500     L2    -0.295497   0.132467 -2.230720
# 80       r_kospi      r_sp500     L3    -0.045443   0.133217 -0.341122
# 81       r_kospi      r_sp500     L4     0.105833   0.132301  0.799939
# 82       r_kospi       StdISI     L1     0.506336   0.582158  0.869757
# 83       r_kospi       StdISI     L2    -0.544145   0.655926 -0.829583
# 84       r_kospi       StdISI     L3    -0.915211   0.659316 -1.388123
# 85       r_kospi       StdISI     L4     0.553406   0.546874  1.011944
# 86       r_kospi        const  const     0.566212   0.356845  1.586715
# 87    r_hangseng   r_shanghai     L1    -0.060272   0.067941 -0.887124
# 88    r_hangseng   r_shanghai     L2     0.216743   0.080864  2.680348
# 89    r_hangseng   r_shanghai     L3     0.005520   0.079783  0.069187
# 90    r_hangseng   r_shanghai     L4     0.261332   0.075935  3.441509
# 91    r_hangseng     r_nikkei     L1    -0.157233   0.109613 -1.434441
# 92    r_hangseng     r_nikkei     L2    -0.269817   0.111751 -2.414454
# 93    r_hangseng     r_nikkei     L3    -0.105573   0.112911 -0.935009
# 94    r_hangseng     r_nikkei     L4    -0.047848   0.113577 -0.421279
# 95    r_hangseng      r_kospi     L1     0.152671   0.120151  1.270660
# 96    r_hangseng      r_kospi     L2     0.451778   0.117643  3.840250
# 97    r_hangseng      r_kospi     L3     0.331845   0.118068  2.810620
# 98    r_hangseng      r_kospi     L4     0.202751   0.118451  1.711682
# 99    r_hangseng   r_hangseng     L1    -0.129410   0.102827 -1.258517
# 100   r_hangseng   r_hangseng     L2    -0.299157   0.102352 -2.922816
# 101   r_hangseng   r_hangseng     L3    -0.163875   0.100288 -1.634056
# 102   r_hangseng   r_hangseng     L4    -0.368108   0.098712 -3.729106
# 103   r_hangseng  r_singapore     L1     0.050337   0.150847  0.333693
# 104   r_hangseng  r_singapore     L2     0.201229   0.149517  1.345864
# 105   r_hangseng  r_singapore     L3     0.152275   0.150006  1.015130
# 106   r_hangseng  r_singapore     L4     0.193978   0.148312  1.307903
# 107   r_hangseng      r_sp500     L1     0.000431   0.156760  0.002747
# 108   r_hangseng      r_sp500     L2    -0.076518   0.152150 -0.502910
# 109   r_hangseng      r_sp500     L3    -0.116700   0.153012 -0.762684
# 110   r_hangseng      r_sp500     L4    -0.070237   0.151960 -0.462206
# 111   r_hangseng       StdISI     L1    -1.214660   0.668662 -1.816554
# 112   r_hangseng       StdISI     L2     0.704262   0.753391  0.934791
# 113   r_hangseng       StdISI     L3    -1.633776   0.757284 -2.157415
# 114   r_hangseng       StdISI     L4     1.329313   0.628135  2.116284
# 115   r_hangseng        const  const     0.027438   0.409869  0.066942
# 116  r_singapore   r_shanghai     L1    -0.008816   0.051067 -0.172643
# 117  r_singapore   r_shanghai     L2     0.144655   0.060780  2.379983
# 118  r_singapore   r_shanghai     L3     0.084800   0.059968  1.414095
# 119  r_singapore   r_shanghai     L4     0.228354   0.057075  4.000905
# 120  r_singapore     r_nikkei     L1     0.106641   0.082389  1.294363
# 121  r_singapore     r_nikkei     L2    -0.255087   0.083995 -3.036917
# 122  r_singapore     r_nikkei     L3    -0.081650   0.084868 -0.962086
# 123  r_singapore     r_nikkei     L4    -0.044124   0.085368 -0.516866
# 124  r_singapore      r_kospi     L1    -0.011731   0.090309 -0.129899
# 125  r_singapore      r_kospi     L2     0.229449   0.088424  2.594875
# 126  r_singapore      r_kospi     L3     0.162599   0.088744  1.832230
# 127  r_singapore      r_kospi     L4     0.177250   0.089032  1.990865
# 128  r_singapore   r_hangseng     L1     0.016649   0.077288  0.215409
# 129  r_singapore   r_hangseng     L2    -0.127571   0.076931 -1.658247
# 130  r_singapore   r_hangseng     L3    -0.162816   0.075379 -2.159958
# 131  r_singapore   r_hangseng     L4    -0.286384   0.074195 -3.859880
# 132  r_singapore  r_singapore     L1     0.045225   0.113382  0.398876
# 133  r_singapore  r_singapore     L2     0.206993   0.112382  1.841878
# 134  r_singapore  r_singapore     L3     0.081168   0.112749  0.719897
# 135  r_singapore  r_singapore     L4     0.055020   0.111476  0.493563
# 136  r_singapore      r_sp500     L1    -0.109107   0.117826 -0.926004
# 137  r_singapore      r_sp500     L2    -0.140464   0.114361 -1.228251
# 138  r_singapore      r_sp500     L3     0.011238   0.115009  0.097711
# 139  r_singapore      r_sp500     L4     0.025052   0.114218  0.219332
# 140  r_singapore       StdISI     L1    -0.569240   0.502588 -1.132618
# 141  r_singapore       StdISI     L2    -0.442161   0.566273 -0.780826
# 142  r_singapore       StdISI     L3    -1.054602   0.569199 -1.852783
# 143  r_singapore       StdISI     L4     1.367538   0.472127  2.896550
# 144  r_singapore        const  const     0.216306   0.308071  0.702130
# 145      r_sp500   r_shanghai     L1     0.043713   0.047503  0.920223
# 146      r_sp500   r_shanghai     L2     0.052177   0.056538  0.922865
# 147      r_sp500   r_shanghai     L3     0.038592   0.055783  0.691820
# 148      r_sp500   r_shanghai     L4     0.121444   0.053092  2.287417
# 149      r_sp500     r_nikkei     L1     0.053310   0.076639  0.695605
# 150      r_sp500     r_nikkei     L2    -0.057708   0.078134 -0.738579
# 151      r_sp500     r_nikkei     L3     0.034800   0.078945  0.440812
# 152      r_sp500     r_nikkei     L4    -0.071345   0.079410 -0.898438
# 153      r_sp500      r_kospi     L1    -0.007161   0.084007 -0.085242
# 154      r_sp500      r_kospi     L2     0.118538   0.082253  1.441133
# 155      r_sp500      r_kospi     L3     0.183367   0.082551  2.221263
# 156      r_sp500      r_kospi     L4     0.018593   0.082818  0.224502
# 157      r_sp500   r_hangseng     L1    -0.000443   0.071894 -0.006161
# 158      r_sp500   r_hangseng     L2     0.016550   0.071562  0.231272
# 159      r_sp500   r_hangseng     L3    -0.181336   0.070119 -2.586128
# 160      r_sp500   r_hangseng     L4    -0.074151   0.069017 -1.074389
# 161      r_sp500  r_singapore     L1     0.048062   0.105469  0.455696
# 162      r_sp500  r_singapore     L2    -0.039571   0.104539 -0.378529
# 163      r_sp500  r_singapore     L3     0.086529   0.104880  0.825022
# 164      r_sp500  r_singapore     L4     0.072790   0.103696  0.701957
# 165      r_sp500      r_sp500     L1    -0.101614   0.109603 -0.927111
# 166      r_sp500      r_sp500     L2    -0.117172   0.106380 -1.101448
# 167      r_sp500      r_sp500     L3    -0.035808   0.106983 -0.334713
# 168      r_sp500      r_sp500     L4     0.071814   0.106247  0.675913
# 169      r_sp500       StdISI     L1    -0.391267   0.467513 -0.836912
# 170      r_sp500       StdISI     L2    -0.147486   0.526754 -0.279991
# 171      r_sp500       StdISI     L3    -0.611075   0.529476 -1.154114
# 172      r_sp500       StdISI     L4     0.864930   0.439178  1.969429
# 173      r_sp500        const  const     0.516724   0.286571  1.803125
# 174       StdISI   r_shanghai     L1     0.064783   0.006963  9.304526
# 175       StdISI   r_shanghai     L2     0.013920   0.008287  1.679803
# 176       StdISI   r_shanghai     L3     0.010484   0.008176  1.282262
# 177       StdISI   r_shanghai     L4     0.001747   0.007782  0.224490
# 178       StdISI     r_nikkei     L1    -0.018727   0.011233 -1.667109
# 179       StdISI     r_nikkei     L2    -0.014794   0.011452 -1.291791
# 180       StdISI     r_nikkei     L3     0.006482   0.011571  0.560225
# 181       StdISI     r_nikkei     L4    -0.004854   0.011639 -0.417049
# 182       StdISI      r_kospi     L1     0.002283   0.012313  0.185383
# 183       StdISI      r_kospi     L2     0.013371   0.012056  1.109111
# 184       StdISI      r_kospi     L3     0.008411   0.012100  0.695167
# 185       StdISI      r_kospi     L4    -0.020923   0.012139 -1.723636
# 186       StdISI   r_hangseng     L1    -0.015582   0.010538 -1.478658
# 187       StdISI   r_hangseng     L2    -0.011828   0.010489 -1.127618
# 188       StdISI   r_hangseng     L3    -0.023198   0.010277 -2.257217
# 189       StdISI   r_hangseng     L4    -0.006771   0.010116 -0.669349
# 190       StdISI  r_singapore     L1    -0.002768   0.015459 -0.179052
# 191       StdISI  r_singapore     L2     0.008671   0.015322  0.565879
# 192       StdISI  r_singapore     L3    -0.002020   0.015373 -0.131432
# 193       StdISI  r_singapore     L4     0.017412   0.015199  1.145596
# 194       StdISI      r_sp500     L1     0.010127   0.016065  0.630408
# 195       StdISI      r_sp500     L2     0.001798   0.015592  0.115324
# 196       StdISI      r_sp500     L3     0.003613   0.015681  0.230411
# 197       StdISI      r_sp500     L4     0.032541   0.015573  2.089578
# 198       StdISI       StdISI     L1     0.530074   0.068524  7.735544
# 199       StdISI       StdISI     L2     0.114629   0.077207  1.484683
# 200       StdISI       StdISI     L3     0.110953   0.077606  1.429692
# 201       StdISI       StdISI     L4     0.103479   0.064371  1.607528
# 202       StdISI        const  const    -0.024683   0.042003 -0.587636
#
#             P>|z|  95% CI lower  95% CI upper
# 0    2.824277e-01     -0.071014      0.243497
# 1    9.785940e-02     -0.029092      0.345241
# 2    5.091108e-01     -0.122460      0.246871
# 3    6.081633e-05      0.183803      0.535322
# 4    4.167133e-01     -0.358838      0.148582
# 5    2.849565e-01     -0.399768      0.117548
# 6    5.249227e-01     -0.346119      0.176569
# 7    8.614042e-01     -0.239467      0.286301
# 8    5.949707e-01     -0.202665      0.353536
# 9    5.299076e-02     -0.003469      0.541122
    "Modulus": np.abs(eigenvalues_lag4)
})

stability_table_lag4 = stability_table_lag4.sort_values(
    by="Modulus",
    ascending=False
).reset_index(drop=True)

display(stability_table_lag4)

if np.all(stability_table_lag4["Modulus"] < 1):
    print("All eigenvalue moduli are less than 1.")
    print("VAR(4) satisfies stability condition.")
else:
    print("At least one eigenvalue modulus is greater than or equal to 1.")
    print("VAR(4) does not satisfy stability condition.")
# Out:
#             Eigenvalue   Modulus
# 0   0.862759+0.000000j  0.862759
# 1  -0.400203-0.679722j  0.788786
# 2  -0.400203+0.679722j  0.788786
# 3   0.755152+0.000000j  0.755152
# 4   0.006163-0.715992j  0.716018
# 5   0.006163+0.715992j  0.716018
# 6   0.062358-0.692507j  0.695309
# 7   0.062358+0.692507j  0.695309
# 8   0.635217+0.243147j  0.680163
# 9   0.635217-0.243147j  0.680163
# 10  0.282132+0.612356j  0.674224
# 11  0.282132-0.612356j  0.674224
# 12 -0.649116-0.000000j  0.649116
# 13 -0.367327-0.527771j  0.643017
# 14 -0.367327+0.527771j  0.643017
# 15 -0.613460-0.185450j  0.640878
# 16 -0.613460+0.185450j  0.640878
# 17  0.531082-0.283077j  0.601814
# 18  0.531082+0.283077j  0.601814
# 19 -0.448930-0.256320j  0.516951
# 20 -0.448930+0.256320j  0.516951
# 21 -0.510901-0.000000j  0.510901
# 22 -0.190395-0.470482j  0.507547
# 23 -0.190395+0.470482j  0.507547
# 24  0.360875-0.296827j  0.467266
# 25  0.360875+0.296827j  0.467266
# 26  0.389391+0.000000j  0.389391
# 27 -0.170582-0.000000j  0.170582
# All eigenvalue moduli are less than 1.
# VAR(4) satisfies stability condition.

# %% [markdown]
# ## 4.4. VAR(4) Granger Causality Tests
#
# Run Wald tests for Granger causality using the VAR(4) model.

# %%
# Granger causality Wald tests using the VAR(4) model.
var_names = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "r_sp500",
    "StdISI"
]

granger_lag4_rows = []

for equation in var_names:
    excluded_vars = [var for var in var_names if var != equation]

    # Test each excluded variable one by one.
    for excluded in excluded_vars:
        test_result = var_results_stdisi_lag4.test_causality(
            caused=equation,
            causing=excluded,
            kind="wald"
        )

        granger_lag4_rows.append({
            "Equation": equation,
            "Excluded": excluded,
            "chi2": test_result.test_statistic,
            "df": test_result.df,
            "Prob > chi2": test_result.pvalue
        })

    # Test all other variables jointly.
    test_all = var_results_stdisi_lag4.test_causality(
        caused=equation,
        causing=excluded_vars,
        kind="wald"
    )

    granger_lag4_rows.append({
        "Equation": equation,
        "Excluded": "ALL",
        "chi2": test_all.test_statistic,
        "df": test_all.df,
        "Prob > chi2": test_all.pvalue
    })

granger_lag4_table = pd.DataFrame(granger_lag4_rows)

granger_lag4_table_formatted = granger_lag4_table.copy()
granger_lag4_table_formatted["chi2"] = granger_lag4_table_formatted["chi2"].map(lambda x: f"{x:.4f}")
granger_lag4_table_formatted["Prob > chi2"] = granger_lag4_table_formatted["Prob > chi2"].map(lambda x: f"{x:.3f}")

display(granger_lag4_table_formatted)
# Out:
#        Equation     Excluded      chi2  df Prob > chi2
# 0    r_shanghai     r_nikkei    2.1788   4       0.703
# 1    r_shanghai      r_kospi   13.6335   4       0.009
# 2    r_shanghai   r_hangseng    1.3608   4       0.851
# 3    r_shanghai  r_singapore    5.4232   4       0.247
# 4    r_shanghai      r_sp500    6.7487   4       0.150
# 5    r_shanghai       StdISI    5.7506   4       0.219
# 6    r_shanghai          ALL   34.0207  24       0.084
# 7      r_nikkei   r_shanghai   11.2439   4       0.024
# 8      r_nikkei      r_kospi   11.6152   4       0.020
# 9      r_nikkei   r_hangseng    3.9335   4       0.415
# 10     r_nikkei  r_singapore    4.0814   4       0.395
# 11     r_nikkei      r_sp500    7.9288   4       0.094
# 12     r_nikkei       StdISI   12.8242   4       0.012
# 13     r_nikkei          ALL   42.4263  24       0.012
# 14      r_kospi   r_shanghai    5.9755   4       0.201
# 15      r_kospi     r_nikkei    2.9142   4       0.572
# 16      r_kospi   r_hangseng    6.1962   4       0.185
# 17      r_kospi  r_singapore    2.3353   4       0.674
# 18      r_kospi      r_sp500    5.5629   4       0.234
# 19      r_kospi       StdISI    5.5142   4       0.238
# 20      r_kospi          ALL   35.9573  24       0.055
# 21   r_hangseng   r_shanghai   18.9831   4       0.001
# 22   r_hangseng     r_nikkei    8.9481   4       0.062
# 23   r_hangseng      r_kospi   23.2679   4       0.000
# 24   r_hangseng  r_singapore    5.1306   4       0.274
# 25   r_hangseng      r_sp500    0.9777   4       0.913
# 26   r_hangseng       StdISI   12.9312   4       0.012
# 27   r_hangseng          ALL   60.7332  24       0.000
# 28  r_singapore   r_shanghai   23.1696   4       0.000
# 29  r_singapore     r_nikkei   12.2467   4       0.016
# 30  r_singapore      r_kospi   11.8915   4       0.018
# 31  r_singapore   r_hangseng   18.8774   4       0.001
# 32  r_singapore      r_sp500    2.2718   4       0.686
# 33  r_singapore       StdISI   16.2613   4       0.003
# 34  r_singapore          ALL   58.8621  24       0.000
# 35      r_sp500   r_shanghai    7.7050   4       0.103
# 36      r_sp500     r_nikkei    2.0477   4       0.727
# 37      r_sp500      r_kospi    6.6051   4       0.158
# 38      r_sp500   r_hangseng    8.0163   4       0.091
# 39      r_sp500  r_singapore    1.5714   4       0.814
# 40      r_sp500       StdISI    5.3645   4       0.252
# 41      r_sp500          ALL   31.8643  24       0.130
# 42       StdISI   r_shanghai   92.3764   4       0.000
# 43       StdISI     r_nikkei    4.9727   4       0.290
# 44       StdISI      r_kospi    5.2605   4       0.262
# 45       StdISI   r_hangseng    6.9128   4       0.141
# 46       StdISI  r_singapore    1.8309   4       0.767
# 47       StdISI      r_sp500    4.7733   4       0.311
# 48       StdISI          ALL  122.8325  24       0.000

# %% [markdown]
# # 5. PCA Sentiment Index Construction
#
# Construct an alternative investor sentiment index from the six sentiment proxy variables.

# %% [markdown]
# ## 5.1. Descriptive Statistics and Standardisation
#
# Report descriptive statistics for the six sentiment proxies, then standardise them for PCA.

# %%
# Descriptive statistics for the six sentiment proxies used in PCA.
sentiment_pca_vars = ["DCEF", "RIPO", "NIPO", "NA", "TURN", "CCI"]

summary_sentiment = pd.DataFrame({
    "N": master_df[sentiment_pca_vars].count(),
    "Mean": master_df[sentiment_pca_vars].mean(),
    "Std. dev.": master_df[sentiment_pca_vars].std(ddof=1),
    "Minimum": master_df[sentiment_pca_vars].min(),
    "Maximum": master_df[sentiment_pca_vars].max()
})

summary_sentiment.index.name = "Variable"
display(summary_sentiment.round(4))
# Out:
#             N      Mean  Std. dev.  Minimum   Maximum
# Variable
# DCEF      248   -0.1211     0.1301  -0.3321    0.4414
# RIPO      248    0.6191     0.6737  -0.0521    6.2674
# NIPO      248   17.3185    15.8620   0.0000   82.0000
# NA        248   40.2921    41.6088   2.3000  297.4700
# TURN      248    0.2562     0.1226   0.0852    0.8247
# CCI       248  104.0109    11.1870  85.5000  127.0000

# %%
# Sentiment variables used for PCA.
sentiment_pca_vars = ["DCEF", "RIPO", "NIPO", "NA", "TURN", "CCI"]

# Use the full merged monthly dataset for PCA because these sentiment variables
# do not lose the first return observation.
pca_df = master_df[["month"] + sentiment_pca_vars].copy()

for col in sentiment_pca_vars:
    pca_df[f"z_{col}"] = (
        pca_df[col] - pca_df[col].mean()
    ) / pca_df[col].std(ddof=1)

z_sentiment_vars = [f"z_{col}" for col in sentiment_pca_vars]

print(f"PCA observations: {len(pca_df)}")
print("Standardized variables:")
print(z_sentiment_vars)

pca_df[["month"] + z_sentiment_vars].head()
# Out:
# PCA observations: 248
# Standardized variables:
# ['z_DCEF', 'z_RIPO', 'z_NIPO', 'z_NA', 'z_TURN', 'z_CCI']
#      month    z_DCEF    z_RIPO    z_NIPO      z_NA    z_TURN     z_CCI
# 0  2003-01  0.135937  0.424325 -0.776608 -0.872941 -1.230155 -0.582007
# 1  2003-02  0.072138  0.222611 -0.902696 -0.899858 -0.517233 -0.564129
# 2  2003-03  0.207424  0.094962 -0.713564 -0.890005 -1.006653 -0.555190
# 3  2003-04 -0.144628  0.840370 -0.776608 -0.831604 -1.096380 -0.573068
# 4  2003-05 -0.523585  0.657803 -0.965740 -0.867173  0.517891 -1.368638

# %% [markdown]
# ## 5.2. PCA for Sentiment Variables
#
# Run PCA using the standardized sentiment variables and report eigenvalues, explained variance, and loadings.

# %%
# PCA on standardized sentiment variables.
X_pca = pca_df[z_sentiment_vars].dropna().copy()

pca_model = PCA()
pca_scores = pca_model.fit_transform(X_pca)

component_names = [f"Comp{i}" for i in range(1, len(z_sentiment_vars) + 1)]

eigenvalues = pca_model.explained_variance_
proportion = pca_model.explained_variance_ratio_
cumulative = np.cumsum(proportion)
difference = np.r_[eigenvalues[:-1] - eigenvalues[1:], np.nan]

pca_summary = pd.DataFrame({
    "Component": component_names,
    "Eigenvalue": eigenvalues,
    "Difference": difference,
    "Proportion": proportion,
    "Cumulative": cumulative
})

loadings = pd.DataFrame(
    pca_model.components_.T,
    index=z_sentiment_vars,
    columns=component_names
)

print(f"Number of obs: {len(X_pca)}")
print(f"Number of components: {len(component_names)}")
print(f"Trace: {eigenvalues.sum():.4f}")

print("\nPCA summary:")
display(pca_summary)

print("\nPCA loadings:")
display(loadings)
# Out:
# Number of obs: 248
# Number of components: 6
# Trace: 6.0000
#
# PCA summary:
#   Component  Eigenvalue  Difference  Proportion  Cumulative
# 0     Comp1    2.011522    0.386965    0.335254    0.335254
# 1     Comp2    1.624557    0.753347    0.270759    0.606013
# 2     Comp3    0.871209    0.157553    0.145202    0.751215
# 3     Comp4    0.713657    0.291885    0.118943    0.870157
# 4     Comp5    0.421772    0.064488    0.070295    0.940453
# 5     Comp6    0.357284         NaN    0.059547    1.000000
# PCA loadings:
#            Comp1     Comp2     Comp3     Comp4     Comp5     Comp6
# z_DCEF  0.341958 -0.511647 -0.378379 -0.254048 -0.569954 -0.297866
# z_RIPO  0.382240  0.288762  0.590574 -0.570780 -0.005691 -0.309692
# z_NIPO  0.492592 -0.380654 -0.175388 -0.148589  0.726318  0.179107
# z_NA    0.519818  0.377823 -0.109996  0.061359 -0.335532  0.677195
# z_TURN  0.325851  0.512176 -0.420775  0.343762  0.154014 -0.559064
# z_CCI   0.343398 -0.323824  0.536786  0.682388 -0.106211 -0.110190

# %% [markdown]
# ## 5.3. Scree Plot
#
# Plot PCA eigenvalues and add a reference line at eigenvalue 1.

# %%
# Scree plot for PCA eigenvalues.
component_numbers = np.arange(1, len(eigenvalues) + 1)

plt.figure(figsize=(8, 5))
plt.plot(
    component_numbers,
    eigenvalues,
    marker="o",
    color="dodgerblue",
    linewidth=1.5
)

plt.axhline(
    y=1,
    color="crimson",
    linestyle="--",
    linewidth=1,
    label="Eigenvalue = 1"
)

plt.xticks(component_numbers)
plt.xlabel("Principal component")
plt.ylabel("Eigenvalue")
plt.title("Scree Plot")
plt.grid(True, linestyle="--", alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# ## 5.4. PCA Loadings
#
# Display the PCA loading matrix for the standardized sentiment variables.

# %%
# Display PCA loadings separately.
loadings
# Out:
#            Comp1     Comp2     Comp3     Comp4     Comp5     Comp6
# z_DCEF  0.341958 -0.511647 -0.378379 -0.254048 -0.569954 -0.297866
# z_RIPO  0.382240  0.288762  0.590574 -0.570780 -0.005691 -0.309692
# z_NIPO  0.492592 -0.380654 -0.175388 -0.148589  0.726318  0.179107
# z_NA    0.519818  0.377823 -0.109996  0.061359 -0.335532  0.677195
# z_TURN  0.325851  0.512176 -0.420775  0.343762  0.154014 -0.559064
# z_CCI   0.343398 -0.323824  0.536786  0.682388 -0.106211 -0.110190

# %% [markdown]
# ## 5.5. Generate PCA1 and PCA2
#
# Create the first two principal component score variables.

# %%
# Recreate raw PCA results so repeated execution always gives the same signs.
raw_pca_scores = pca_model.transform(X_pca)
raw_loadings = pd.DataFrame(
    pca_model.components_.T,
    index=z_sentiment_vars,
    columns=component_names
)

# Use positive z_DCEF loadings as the fixed orientation for PCA1 and PCA2.
comp1_sign = 1 if raw_loadings.loc["z_DCEF", "Comp1"] >= 0 else -1
comp2_sign = 1 if raw_loadings.loc["z_DCEF", "Comp2"] >= 0 else -1

loadings = raw_loadings.copy()
loadings["Comp1"] = comp1_sign * raw_loadings["Comp1"]
loadings["Comp2"] = comp2_sign * raw_loadings["Comp2"]

pca_df["pca1"] = comp1_sign * raw_pca_scores[:, 0]
pca_df["pca2"] = comp2_sign * raw_pca_scores[:, 1]

pca_df[["month", "pca1", "pca2"]].head()
# Out:
#      month      pca1      pca2
# 0  2003-01 -1.228350  0.422810
# 1  2003-02 -1.164926  0.051236
# 2  2003-03 -1.225578  0.479150
# 3  2003-04 -1.097114  0.077882
# 4  2003-05 -1.155325 -1.206262

# %% [markdown]
# ## 5.6. Construct Final Sentiment Index
#
# Construct the final sentiment index using the first two PCA components weighted by their explained variance shares.

# %%
# Recreate deterministically aligned PCA1 and PCA2 if this cell is run separately.
raw_pca_scores = pca_model.transform(X_pca)
comp1_sign = 1 if pca_model.components_[0, z_sentiment_vars.index("z_DCEF")] >= 0 else -1
comp2_sign = 1 if pca_model.components_[1, z_sentiment_vars.index("z_DCEF")] >= 0 else -1
pca_df["pca1"] = comp1_sign * raw_pca_scores[:, 0]
pca_df["pca2"] = comp2_sign * raw_pca_scores[:, 1]

# Construct final sentiment index using PCA1 and PCA2.
pca1_weight = proportion[0]
pca2_weight = proportion[1]
total_weight = pca1_weight + pca2_weight

pca_df["sen"] = (
    (pca1_weight / total_weight) * pca_df["pca1"]
    + (pca2_weight / total_weight) * pca_df["pca2"]
)

# Remove previous PCA columns so this cell can be run repeatedly without suffixes.
analysis_df = analysis_df.drop(
    columns=[
        "pca1", "pca2", "sen",
        "pca1_x", "pca1_y", "pca2_x", "pca2_y",
        "sen_x", "sen_y"
    ],
    errors="ignore"
)

analysis_df = analysis_df.merge(
    pca_df[["month", "pca1", "pca2", "sen"]],
    on="month",
    how="left"
)

print(f"PCA1 weight: {pca1_weight / total_weight:.4f}")
print(f"PCA2 weight: {pca2_weight / total_weight:.4f}")

analysis_df[["month", "pca1", "pca2", "sen"]].head()
# Out:
# PCA1 weight: 0.5532
# PCA2 weight: 0.4468
#      month      pca1      pca2       sen
# 0  2003-02 -1.164926  0.051236 -0.621559
# 1  2003-03 -1.225578  0.479150 -0.463925
# 2  2003-04 -1.097114  0.077882 -0.572140
# 3  2003-05 -1.155325 -1.206262 -1.178083
# 4  2003-06 -1.386193 -0.853339 -1.148120

# %% [markdown]
# ## 5.7. Descriptive Statistics of Sentiment Indices
#
# Summarise StdISI and the PCA-constructed sentiment index using the common return-analysis sample.

# %%
# Descriptive statistics for the original and PCA-constructed sentiment indices.
sentiment_index_vars = ["StdISI", "sen"]

sentiment_index_summary = pd.DataFrame({
    "N": analysis_df[sentiment_index_vars].count(),
    "Mean": analysis_df[sentiment_index_vars].mean(),
    "Std. dev.": analysis_df[sentiment_index_vars].std(ddof=1),
    "Minimum": analysis_df[sentiment_index_vars].min(),
    "Maximum": analysis_df[sentiment_index_vars].max()
})

sentiment_index_summary.index.name = "Variable"
display(sentiment_index_summary.round(4))
# Out:
#             N   Mean  Std. dev.  Minimum  Maximum
# Variable
# StdISI    247  0.005     1.4646  -2.4800   5.9300
# sen       247  0.002     0.9710  -1.7175   2.9189

# %% [markdown]
# ## 5.8. Stationarity Test for Constructed Sentiment Index
#
# Apply the ADF test to the PCA-constructed sentiment index using zero lags, consistent with the Stata `dfuller sen` specification.

# %%
# ADF test for sen with zero lags, matching Stata: dfuller sen.
sen_series = analysis_df["sen"].replace([np.inf, -np.inf], np.nan).dropna()
sen_adf = adfuller(
    sen_series,
    maxlag=0,
    regression="c",
    autolag=None
)

adf_sen_results = pd.DataFrame([{
    "Variable": "sen",
    "ADF statistic": sen_adf[0],
    "p-value": sen_adf[1],
    "Lags used": sen_adf[2],
    "Observations": sen_adf[3],
    "Stationary at 5%": sen_adf[1] < 0.05
}])

display(adf_sen_results.round({"ADF statistic": 4, "p-value": 4}))
# Out:
#   Variable  ADF statistic  p-value  Lags used  Observations  Stationary at 5%
# 0      sen         -3.156   0.0227          0           246              True

# %% [markdown]
# ## 5.9. Dissertation Figure: Shanghai Return and SEN
#
# Plot the Shanghai Composite monthly return together with the PCA-constructed sentiment index used in the main VAR and Granger-causality models.

# %%
# Dissertation figure: Shanghai monthly return and PCA-based SEN.
import matplotlib.dates as mdates
plt.style.use("default")
# Separate y-axes are used because returns and SEN have different units and scales.
fig, ax_return = plt.subplots(figsize=(10, 5.4), facecolor="white")
ax_sen = ax_return.twinx()
ax_return.set_facecolor("white")
ax_sen.set_facecolor("none")

return_line = ax_return.plot(
    analysis_df["month_dt"],
    analysis_df["r_shanghai"],
    color="#0072B2",
    linewidth=1.15,
    label="Shanghai monthly return"
)
sen_line = ax_sen.plot(
    analysis_df["month_dt"],
    analysis_df["sen"],
    color="#D55E00",
    linewidth=1.65,
    label="SEN"
)

ax_return.axhline(0, color="#666666", linewidth=0.7, linestyle="--")
ax_sen.axhline(0, color="#D55E00", linewidth=0.6, linestyle=":", alpha=0.55)
ax_return.set_xlabel("Month")
ax_return.set_ylabel("Shanghai monthly log return (%)", color="#0072B2")
ax_sen.set_ylabel("PCA-based sentiment index (SEN)", color="#D55E00")
ax_return.tick_params(axis="both", colors="#222222", labelsize=10)
ax_sen.tick_params(axis="y", colors="#222222", labelsize=10)
ax_return.xaxis.set_major_locator(mdates.YearLocator(4))
ax_return.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))
ax_return.grid(axis="both", color="#D9D9D9", linewidth=0.6, alpha=0.75)
ax_return.set_axisbelow(True)
for axis in (ax_return, ax_sen):
    for spine in axis.spines.values():
        spine.set_color("#444444")
        spine.set_linewidth(0.8)

lines = return_line + sen_line
legend = ax_return.legend(
    lines,
    [line.get_label() for line in lines],
    loc="upper right",
    frameon=True,
    facecolor="white",
    edgecolor="#B0B0B0"
)
for text in legend.get_texts():
    text.set_color("#222222")
fig.tight_layout()

figure_path = PROJECT_ROOT / "dataset" / "outputs" / "figure_4_1_shanghai_return_sen.png"
fig.savefig(figure_path, dpi=300, bbox_inches="tight", facecolor="white")
plt.show()

print(f"Saved dissertation figure to: {figure_path}")
# Out:
# Saved dissertation figure to: C:\Users\20945\Desktop\data\project\dataset\outputs\figure_4_1_shanghai_return_sen.png

# %% [markdown]
# ## 5.10. Dissertation Figure: Correlations between Asian Market Returns and SEN
#
# Display the contemporaneous Pearson correlations between the five Asian monthly return series and the PCA-constructed sentiment index used in the main models.

# %%
# Dissertation heatmap: baseline monthly returns and PCA-based SEN.
plt.style.use("default")
heatmap_vars = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "sen"
]
heatmap_labels = ["Shanghai", "Nikkei 225", "KOSPI", "Hang Seng", "STI", "SEN"]
sen_corr_matrix = analysis_df[heatmap_vars].corr()

fig, ax = plt.subplots(figsize=(8.2, 6.7), facecolor="white")
ax.set_facecolor("white")
image = ax.imshow(sen_corr_matrix, vmin=-1, vmax=1, cmap="RdBu_r")
ax.set_xticks(range(len(heatmap_labels)), heatmap_labels, rotation=35, ha="right")
ax.set_yticks(range(len(heatmap_labels)), heatmap_labels)

for row in range(len(heatmap_labels)):
    for column in range(len(heatmap_labels)):
        value = sen_corr_matrix.iloc[row, column]
        ax.text(
            column,
            row,
            f"{value:.2f}",
            ha="center",
            va="center",
            fontsize=10,
            color="white" if abs(value) >= 0.55 else "black"
        )

ax.tick_params(axis="both", colors="#222222", labelsize=10)
for spine in ax.spines.values():
    spine.set_color("#555555")
    spine.set_linewidth(0.8)
colorbar = fig.colorbar(image, ax=ax, fraction=0.046, pad=0.04)
colorbar.set_label("Pearson correlation coefficient", color="#222222")
colorbar.ax.tick_params(colors="#222222", labelsize=9)
fig.tight_layout()

heatmap_path = PROJECT_ROOT / "dataset" / "outputs" / "figure_4_2_returns_sen_heatmap.png"
fig.savefig(heatmap_path, dpi=300, bbox_inches="tight", facecolor="white")
plt.show()

print(f"Saved dissertation heatmap to: {heatmap_path}")
# Out:
# Saved dissertation heatmap to: C:\Users\20945\Desktop\data\project\dataset\outputs\figure_4_2_returns_sen_heatmap.png

# %% [markdown]
# # 6. Main Extended VAR Analysis: PCA-Based SEN and S&P 500
#
# Estimate the main extended correlation, VAR and Granger-causality analysis using the PCA-constructed sentiment index (SEN) and the S&P 500 return.

# %% [markdown]
# ## 6.1. Main Extended-Model Correlation: Returns and SEN
#
# Compute pairwise correlations between market returns and the constructed sentiment index.

# %%
corr_vars_sen = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "r_sp500",
    "sen"
]

corr_sen_table = correlation_table_html(
    analysis_df,
    corr_vars_sen,
    star_level=0.05
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>r_shanghai</th>
#       <th>r_nikkei</th>
#       <th>r_kospi</th>
#       <th>r_hangseng</th>
#       <th>r_singapore</th>
#       <th>r_sp500</th>
#       <th>sen</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>r_shanghai</th>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_nikkei</th>
#       <td>0.3477*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_kospi</th>
#       <td>0.4113*<br>0.0000</td>
#       <td>0.6068*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_hangseng</th>
#       <td>0.5592*<br>0.0000</td>
#       <td>0.4680*<br>0.0000</td>
#       <td>0.5589*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_singapore</th>
#       <td>0.4491*<br>0.0000</td>
#       <td>0.6292*<br>0.0000</td>
#       <td>0.6957*<br>0.0000</td>
#       <td>0.7031*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>r_sp500</th>
#       <td>0.3653*<br>0.0000</td>
#       <td>0.6851*<br>0.0000</td>
#       <td>0.6855*<br>0.0000</td>
#       <td>0.5339*<br>0.0000</td>
#       <td>0.6980*<br>0.0000</td>
#       <td>1.0000</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>sen</th>
#       <td>-0.0207<br>0.7464</td>
#       <td>-0.0141<br>0.8257</td>
#       <td>-0.0625<br>0.3277</td>
#       <td>-0.0928<br>0.1459</td>
#       <td>-0.0334<br>0.6016</td>
#       <td>0.0342<br>0.5927</td>
#       <td>1.0000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 6.2. Main Extended-Model VAR Lag Selection: SEN, Max Lag 6
#
# Select lag order for the VAR model using returns and the constructed sentiment index.

# %%
# sen VAR lag-order selection with maximum lag 6.
var_vars_sen = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "r_sp500",
    "sen"
]

var_data_sen = analysis_df[var_vars_sen].dropna().copy()
var_model_sen = VAR(var_data_sen)

lag_order_sen_6 = var_model_sen.select_order(maxlags=6)
lag_order_sen_6.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## 6.3. Main Extended VAR(2) Model with SEN and S&P 500
#
# Estimate the VAR model with two lags using market returns and the constructed sentiment index. Although the information criteria favor lag 1 in the extended model, lag 2 is used to maintain comparability with the baseline specification.

# %%
# Estimate the VAR(2) model with sen.
var_vars_sen = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "r_sp500",
    "sen"
]

var_data_sen = analysis_df[var_vars_sen].dropna().copy()
var_model_sen = VAR(var_data_sen)

# fit(2) includes lags 1 and 2.
var_results_sen_lag2 = var_model_sen.fit(2)

print(var_results_sen_lag2.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 31, Jul, 2026
# Time:                     23:13:37
# --------------------------------------------------------------------
# No. of Equations:         7.00000    BIC:                    16.8016
# Nobs:                     245.000    HQIC:                   15.9053
# Log likelihood:          -4202.86    FPE:                4.42205e+06
# AIC:                      15.3010    Det(Omega_mle):     2.91724e+06
# --------------------------------------------------------------------
# Results for equation r_shanghai
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.356055         0.477924            0.745           0.456
# L1.r_shanghai          0.093033         0.079621            1.168           0.243
# L1.r_nikkei           -0.049355         0.127977           -0.386           0.700
# L1.r_kospi             0.035628         0.135779            0.262           0.793
# L1.r_hangseng         -0.025960         0.117609           -0.221           0.825
# L1.r_singapore         0.063334         0.177517            0.357           0.721
# L1.r_sp500            -0.034832         0.179331           -0.194           0.846
# L1.sen                -0.491585         1.304279           -0.377           0.706
# L2.r_shanghai          0.097783         0.079230            1.234           0.217
# L2.r_nikkei           -0.123344         0.129899           -0.950           0.342
# L2.r_kospi             0.211467         0.134688            1.570           0.116
# L2.r_hangseng         -0.037796         0.112787           -0.335           0.738
# L2.r_singapore         0.353549         0.172307            2.052           0.040
# L2.r_sp500            -0.427401         0.179214           -2.385           0.017
# L2.sen                 0.036964         1.302305            0.028           0.977
# =================================================================================
#
# Results for equation r_nikkei
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.577447         0.349899            1.650           0.099
# L1.r_shanghai          0.070166         0.058292            1.204           0.229
# L1.r_nikkei            0.059711         0.093694            0.637           0.524
# L1.r_kospi            -0.044826         0.099407           -0.451           0.652
# L1.r_hangseng          0.069122         0.086104            0.803           0.422
# L1.r_singapore        -0.017159         0.129964           -0.132           0.895
# L1.r_sp500             0.011195         0.131292            0.085           0.932
# L1.sen                -0.247022         0.954892           -0.259           0.796
# L2.r_shanghai          0.051313         0.058006            0.885           0.376
# L2.r_nikkei           -0.047032         0.095102           -0.495           0.621
# L2.r_kospi             0.153634         0.098608            1.558           0.119
# L2.r_hangseng          0.034270         0.082574            0.415           0.678
# L2.r_singapore         0.079838         0.126150            0.633           0.527
# L2.r_sp500            -0.258943         0.131207           -1.974           0.048
# L2.sen                 0.250213         0.953447            0.262           0.793
# =================================================================================
#
# Results for equation r_kospi
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.765683         0.283516            2.701           0.007
# L1.r_shanghai          0.033268         0.047233            0.704           0.481
# L1.r_nikkei            0.056059         0.075919            0.738           0.460
# L1.r_kospi            -0.062182         0.080547           -0.772           0.440
# L1.r_hangseng          0.057154         0.069769            0.819           0.413
# L1.r_singapore         0.032457         0.105308            0.308           0.758
# L1.r_sp500            -0.072792         0.106384           -0.684           0.494
# L1.sen                 0.993108         0.773730            1.284           0.199
# L2.r_shanghai          0.019970         0.047001            0.425           0.671
# L2.r_nikkei           -0.038097         0.077059           -0.494           0.621
# L2.r_kospi             0.056760         0.079900            0.710           0.477
# L2.r_hangseng          0.066904         0.066908            1.000           0.317
# L2.r_singapore         0.010308         0.102217            0.101           0.920
# L2.r_sp500            -0.170562         0.106314           -1.604           0.109
# L2.sen                -0.868968         0.772559           -1.125           0.261
# =================================================================================
#
# Results for equation sen
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 -0.003854         0.023779           -0.162           0.871
# L1.r_shanghai          0.010281         0.003962            2.595           0.009
# L1.r_nikkei            0.004543         0.006368            0.714           0.476
# L1.r_kospi            -0.002525         0.006756           -0.374           0.709
# L1.r_hangseng          0.002053         0.005852            0.351           0.726
# L1.r_singapore        -0.002119         0.008832           -0.240           0.810
# L1.r_sp500             0.007109         0.008923            0.797           0.426
# L1.sen                 0.687302         0.064895           10.591           0.000
# L2.r_shanghai         -0.005543         0.003942           -1.406           0.160
# L2.r_nikkei           -0.000013         0.006463           -0.002           0.998
# L2.r_kospi             0.001482         0.006701            0.221           0.825
# L2.r_hangseng          0.001916         0.005612            0.341           0.733
# L2.r_singapore        -0.001798         0.008573           -0.210           0.834
# L2.r_sp500             0.000967         0.008917            0.108           0.914
# L2.sen                 0.258036         0.064797            3.982           0.000
# =================================================================================
#
# Correlation matrix of residuals
#                r_shanghai  r_nikkei   r_kospi  r_hangseng  r_singapore   r_sp500       sen
# r_shanghai       1.000000  0.311038  0.388782    0.548040     0.414069  0.351937  0.151832
# r_nikkei         0.311038  1.000000  0.607535    0.477742     0.613591  0.681154 -0.010845
# r_kospi          0.388782  0.607535  1.000000    0.572040     0.691957  0.690322  0.029205
# r_hangseng       0.548040  0.477742  0.572040    1.000000     0.720336  0.575559 -0.016208
# r_singapore      0.414069  0.613591  0.691957    0.720336     1.000000  0.702898  0.068531
# r_sp500          0.351937  0.681154  0.690322    0.575559     0.702898  1.000000  0.050165
# sen              0.151832 -0.010845  0.029205   -0.016208     0.068531  0.050165  1.000000

# %% [markdown]
# ## 6.4. Full Main Extended VAR(2) Coefficient Table with SEN
#
# Create a complete coefficient table for the VAR(2) model using sen.

# %%
# Complete coefficient table for the VAR(2) model with sen.
params = var_results_sen_lag2.params
stderr = var_results_sen_lag2.stderr
zvalues = var_results_sen_lag2.tvalues
pvalues = var_results_sen_lag2.pvalues

z_crit = norm.ppf(0.975)

base_variables = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "r_sp500",
    "sen"
]

ordered_parameters = []
for base_var in base_variables:
    for lag_number in range(1, 3):
        ordered_parameters.append(f"L{lag_number}.{base_var}")
ordered_parameters.append("const")

rows = []

for equation in params.columns:
    for variable in ordered_parameters:
        if variable not in params.index:
            continue

        coef = params.loc[variable, equation]
        se = stderr.loc[variable, equation]
        z = zvalues.loc[variable, equation]
        p = pvalues.loc[variable, equation]
        ci_lower = coef - z_crit * se
        ci_upper = coef + z_crit * se

        if variable == "const":
            lag = "const"
            variable_name = "const"
        else:
            lag, variable_name = variable.split(".", 1)

        rows.append({
            "Equation": equation,
            "Variable": variable_name,
            "Lag": lag,
            "Coefficient": coef,
            "Std. err.": se,
            "z": z,
            "P>|z|": p,
            "95% CI lower": ci_lower,
            "95% CI upper": ci_upper
        })

var_sen_lag2_full_table = pd.DataFrame(rows)

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

display(var_sen_lag2_full_table)
# Out:
#         Equation     Variable    Lag  Coefficient  Std. err.          z  \
# 0     r_shanghai   r_shanghai     L1     0.093033   0.079621   1.168440
# 1     r_shanghai   r_shanghai     L2     0.097783   0.079230   1.234162
# 2     r_shanghai     r_nikkei     L1    -0.049355   0.127977  -0.385654
# 3     r_shanghai     r_nikkei     L2    -0.123344   0.129899  -0.949540
# 4     r_shanghai      r_kospi     L1     0.035628   0.135779   0.262400
# 5     r_shanghai      r_kospi     L2     0.211467   0.134688   1.570048
# 6     r_shanghai   r_hangseng     L1    -0.025960   0.117609  -0.220730
# 7     r_shanghai   r_hangseng     L2    -0.037796   0.112787  -0.335113
# 8     r_shanghai  r_singapore     L1     0.063334   0.177517   0.356775
# 9     r_shanghai  r_singapore     L2     0.353549   0.172307   2.051849
# 10    r_shanghai      r_sp500     L1    -0.034832   0.179331  -0.194231
# 11    r_shanghai      r_sp500     L2    -0.427401   0.179214  -2.384864
# 12    r_shanghai          sen     L1    -0.491585   1.304279  -0.376902
# 13    r_shanghai          sen     L2     0.036964   1.302305   0.028383
# 14    r_shanghai        const  const     0.356055   0.477924   0.745003
# 15      r_nikkei   r_shanghai     L1     0.070166   0.058292   1.203694
# 16      r_nikkei   r_shanghai     L2     0.051313   0.058006   0.884610
# 17      r_nikkei     r_nikkei     L1     0.059711   0.093694   0.637290
# 18      r_nikkei     r_nikkei     L2    -0.047032   0.095102  -0.494540
# 19      r_nikkei      r_kospi     L1    -0.044826   0.099407  -0.450939
# 20      r_nikkei      r_kospi     L2     0.153634   0.098608   1.558024
# 21      r_nikkei   r_hangseng     L1     0.069122   0.086104   0.802768
# 22      r_nikkei   r_hangseng     L2     0.034270   0.082574   0.415022
# 23      r_nikkei  r_singapore     L1    -0.017159   0.129964  -0.132026
# 24      r_nikkei  r_singapore     L2     0.079838   0.126150   0.632883
# 25      r_nikkei      r_sp500     L1     0.011195   0.131292   0.085264
# 26      r_nikkei      r_sp500     L2    -0.258943   0.131207  -1.973553
# 27      r_nikkei          sen     L1    -0.247022   0.954892  -0.258691
# 28      r_nikkei          sen     L2     0.250213   0.953447   0.262430
# 29      r_nikkei        const  const     0.577447   0.349899   1.650326
# 30       r_kospi   r_shanghai     L1    -0.047828   0.058056  -0.823827
# 31       r_kospi   r_shanghai     L2     0.076032   0.057771   1.316090
# 32       r_kospi     r_nikkei     L1     0.007227   0.093315   0.077442
# 33       r_kospi     r_nikkei     L2    -0.127940   0.094716  -1.350767
# 34       r_kospi      r_kospi     L1    -0.104230   0.099004  -1.052788
# 35       r_kospi      r_kospi     L2     0.022818   0.098209   0.232340
# 36       r_kospi   r_hangseng     L1     0.029227   0.085755   0.340820
# 37       r_kospi   r_hangseng     L2     0.125491   0.082239   1.525922
# 38       r_kospi  r_singapore     L1     0.105142   0.129438   0.812298
# 39       r_kospi  r_singapore     L2     0.157127   0.125639   1.250622
# 40       r_kospi      r_sp500     L1     0.005235   0.130760   0.040037
# 41       r_kospi      r_sp500     L2    -0.281006   0.130675  -2.150424
# 42       r_kospi          sen     L1     0.641355   0.951022   0.674384
# 43       r_kospi          sen     L2    -1.001236   0.949583  -1.054395
# 44       r_kospi        const  const     0.781642   0.348481   2.242997
# 45    r_hangseng   r_shanghai     L1    -0.056619   0.068564  -0.825781
# 46    r_hangseng   r_shanghai     L2     0.151080   0.068228   2.214344
# 47    r_hangseng     r_nikkei     L1    -0.133968   0.110205  -1.215628
# 48    r_hangseng     r_nikkei     L2    -0.204865   0.111860  -1.831434
# 49    r_hangseng      r_kospi     L1     0.126605   0.116924   1.082799
# 50    r_hangseng      r_kospi     L2     0.326371   0.115985   2.813912
# 51    r_hangseng   r_hangseng     L1    -0.099874   0.101277  -0.986143
# 52    r_hangseng   r_hangseng     L2    -0.160348   0.097125  -1.650950
# 53    r_hangseng  r_singapore     L1     0.058687   0.152866   0.383911
# 54    r_hangseng  r_singapore     L2     0.211009   0.148380   1.422089
# 55    r_hangseng      r_sp500     L1     0.074175   0.154428   0.480322
# 56    r_hangseng      r_sp500     L2    -0.135324   0.154327  -0.876865
# 57    r_hangseng          sen     L1    -0.521323   1.123159  -0.464157
# 58    r_hangseng          sen     L2    -0.048373   1.121460  -0.043134
# 59    r_hangseng        const  const     0.211728   0.411557   0.514456
# 60   r_singapore   r_shanghai     L1     0.003718   0.051938   0.071581
# 61   r_singapore   r_shanghai     L2     0.090458   0.051683   1.750233
# 62   r_singapore     r_nikkei     L1     0.117169   0.083481   1.403542
# 63   r_singapore     r_nikkei     L2    -0.205722   0.084735  -2.427829
# 64   r_singapore      r_kospi     L1    -0.041145   0.088570  -0.464547
# 65   r_singapore      r_kospi     L2     0.117068   0.087859   1.332451
# 66   r_singapore   r_hangseng     L1     0.032067   0.076718   0.417978
# 67   r_singapore   r_hangseng     L2    -0.007373   0.073573  -0.100216
# 68   r_singapore  r_singapore     L1     0.049505   0.115797   0.427511
# 69   r_singapore  r_singapore     L2     0.198342   0.112399   1.764628
# 70   r_singapore      r_sp500     L1    -0.038683   0.116980  -0.330677
# 71   r_singapore      r_sp500     L2    -0.168666   0.116904  -1.442777
# 72   r_singapore          sen     L1    -0.072709   0.850801  -0.085459
# 73   r_singapore          sen     L2    -0.179267   0.849514  -0.211023
# 74   r_singapore        const  const     0.404942   0.311757   1.298903
# 75       r_sp500   r_shanghai     L1     0.033268   0.047233   0.704335
# 76       r_sp500   r_shanghai     L2     0.019970   0.047001   0.424885
# 77       r_sp500     r_nikkei     L1     0.056059   0.075919   0.738413
# 78       r_sp500     r_nikkei     L2    -0.038097   0.077059  -0.494386
# 79       r_sp500      r_kospi     L1    -0.062182   0.080547  -0.771999
# 97   7.328312e-01     -0.009083      0.012915
# 98   8.104041e-01     -0.019430      0.015192
# 99   8.338981e-01     -0.018601      0.015005
# 100  4.255809e-01     -0.010379      0.024598
# 101  9.136534e-01     -0.016510      0.018444
# 102  3.281733e-26      0.560110      0.814494
# 103  6.827247e-05      0.131036      0.385036
# 104  8.712429e-01     -0.050461      0.042753

# %% [markdown]
# ## 6.5. Main Extended VAR(2) Stability Test with SEN
#
# Check whether the VAR(2) model with sen satisfies the stability condition.

# %%
# Stability test using companion-matrix eigenvalues.
# The VAR is stable when all eigenvalue moduli are less than 1.
eigenvalues_sen_lag2 = 1 / var_results_sen_lag2.roots

stability_table_sen_lag2 = pd.DataFrame({
    "Eigenvalue": eigenvalues_sen_lag2,
    "Modulus": np.abs(eigenvalues_sen_lag2)
})

stability_table_sen_lag2 = stability_table_sen_lag2.sort_values(
    by="Modulus",
    ascending=False
).reset_index(drop=True)

display(stability_table_sen_lag2)

if np.all(stability_table_sen_lag2["Modulus"] < 1):
    print("All eigenvalue moduli are less than 1.")
    print("VAR(2) with sen satisfies stability condition.")
else:
    print("At least one eigenvalue modulus is greater than or equal to 1.")
    print("VAR(2) with sen does not satisfy stability condition.")
# Out:
#             Eigenvalue   Modulus
# 0   0.951682+0.000000j  0.951682
# 1  -0.101026-0.564677j  0.573643
# 2  -0.101026+0.564677j  0.573643
# 3   0.455566+0.000000j  0.455566
# 4  -0.417588-0.000000j  0.417588
# 5  -0.361873-0.000000j  0.361873
# 6   0.356295+0.000000j  0.356295
# 7   0.069555-0.298114j  0.306121
# 8   0.069555+0.298114j  0.306121
# 9  -0.285677-0.080477j  0.296796
# 10 -0.285677+0.080477j  0.296796
# 11  0.060204-0.163299j  0.174043
# 12  0.060204+0.163299j  0.174043
# 13  0.142458+0.000000j  0.142458
# All eigenvalue moduli are less than 1.
# VAR(2) with sen satisfies stability condition.

# %% [markdown]
# ## 6.6. Main Extended VAR(2) Granger Causality Tests with SEN
#
# Run Wald tests for Granger causality using the VAR(2) model with sen.

# %%
# Granger causality Wald tests using the VAR(2) model with sen.
var_names_sen = [
    "r_shanghai",
    "r_nikkei",
    "r_kospi",
    "r_hangseng",
    "r_singapore",
    "r_sp500",
    "sen"
]

granger_sen_lag2_rows = []

for equation in var_names_sen:
    excluded_vars = [var for var in var_names_sen if var != equation]

    # Test each excluded variable one by one.
    for excluded in excluded_vars:
        test_result = var_results_sen_lag2.test_causality(
            caused=equation,
            causing=excluded,
            kind="wald"
        )

        granger_sen_lag2_rows.append({
            "Equation": equation,
            "Excluded": excluded,
            "chi2": test_result.test_statistic,
            "df": test_result.df,
            "Prob > chi2": test_result.pvalue
        })

    # Test all other variables jointly.
    test_all = var_results_sen_lag2.test_causality(
        caused=equation,
        causing=excluded_vars,
        kind="wald"
    )

    granger_sen_lag2_rows.append({
        "Equation": equation,
        "Excluded": "ALL",
        "chi2": test_all.test_statistic,
        "df": test_all.df,
        "Prob > chi2": test_all.pvalue
    })

granger_sen_lag2_table = pd.DataFrame(granger_sen_lag2_rows)

granger_sen_lag2_table_formatted = granger_sen_lag2_table.copy()
granger_sen_lag2_table_formatted["chi2"] = granger_sen_lag2_table_formatted["chi2"].map(lambda x: f"{x:.4f}")
granger_sen_lag2_table_formatted["Prob > chi2"] = granger_sen_lag2_table_formatted["Prob > chi2"].map(lambda x: f"{x:.3f}")

display(granger_sen_lag2_table_formatted)
# Out:
#        Equation     Excluded     chi2  df Prob > chi2
# 0    r_shanghai     r_nikkei   1.0592   2       0.589
# 1    r_shanghai      r_kospi   2.4888   2       0.288
# 2    r_shanghai   r_hangseng   0.1486   2       0.928
# 3    r_shanghai  r_singapore   4.3124   2       0.116
# 4    r_shanghai      r_sp500   5.6877   2       0.058
# 5    r_shanghai          sen   0.8702   2       0.647
# 6    r_shanghai          ALL  13.8788  12       0.309
# 7      r_nikkei   r_shanghai   2.5299   2       0.282
# 8      r_nikkei      r_kospi   2.7410   2       0.254
# 9      r_nikkei   r_hangseng   0.7617   2       0.683
# 10     r_nikkei  r_singapore   0.4211   2       0.810
# 11     r_nikkei      r_sp500   3.9521   2       0.139
# 12     r_nikkei          sen   0.0706   2       0.965
# 13     r_nikkei          ALL  13.3170  12       0.346
# 14      r_kospi   r_shanghai   2.1780   2       0.337
# 15      r_kospi     r_nikkei   1.8283   2       0.401
# 16      r_kospi   r_hangseng   2.3688   2       0.306
# 17      r_kospi  r_singapore   2.1880   2       0.335
# 18      r_kospi      r_sp500   4.6674   2       0.097
# 19      r_kospi          sen   1.7595   2       0.415
# 20      r_kospi          ALL  22.7707  12       0.030
# 21   r_hangseng   r_shanghai   5.2158   2       0.074
# 22   r_hangseng     r_nikkei   4.8856   2       0.087
# 23   r_hangseng      r_kospi   8.7109   2       0.013
# 24   r_hangseng  r_singapore   2.1508   2       0.341
# 25   r_hangseng      r_sp500   1.0714   2       0.585
# 26   r_hangseng          sen   1.7994   2       0.407
# 27   r_hangseng          ALL  24.9243  12       0.015
# 28  r_singapore   r_shanghai   3.1462   2       0.207
# 29  r_singapore     r_nikkei   7.7843   2       0.020
# 30  r_singapore      r_kospi   2.0868   2       0.352
# 31  r_singapore   r_hangseng   0.1941   2       0.907
# 32  r_singapore      r_sp500   2.1297   2       0.345
# 33  r_singapore          sen   0.6030   2       0.740
# 34  r_singapore          ALL  19.8953  12       0.069
# 35      r_sp500   r_shanghai   0.7613   2       0.683
# 36      r_sp500     r_nikkei   0.7811   2       0.677
# 37      r_sp500      r_kospi   1.1821   2       0.554
# 38      r_sp500   r_hangseng   1.5328   2       0.465
# 39      r_sp500  r_singapore   0.1041   2       0.949
# 40      r_sp500          sen   1.6769   2       0.432
# 41      r_sp500          ALL  11.0062  12       0.528
# 42          sen   r_shanghai   7.9371   2       0.019
# 43          sen     r_nikkei   0.5092   2       0.775
# 44          sen      r_kospi   0.2009   2       0.904
# 45          sen   r_hangseng   0.2193   2       0.896
# 46          sen  r_singapore   0.0998   2       0.951
# 47          sen      r_sp500   0.6370   2       0.727
# 48          sen          ALL  19.2035  12       0.084
